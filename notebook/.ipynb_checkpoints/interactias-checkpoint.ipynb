# %% [markdown]
# # Interactias Geo Selected Network
#
# One way of examining the impact of invasive species is to look at all their interactions and the interations those organisms have with each other. This full interaction network gives you an idication of whether a species might be a "keystone" species and therefore have a disproportionatly large impact.
#
# In this step of the evolution of this script it will be adapted to quantify species by their occupancy.
#
# I will harvest species interactions data from GLOBI (https://www.globalbioticinteractions.org/) to discover the species that interact with an invasive species.
# I will then harvest all the interactions for those species to create two tiers of interactions.
# I will then count all the occurences of these in species in the Belgian datacube.
# I will then create a network diagram to visualize this.
#
# This notebook takes considerable insperation and code from Yikang Li's project on GLoBI (https://curiositydata.org/part1_globi_access/).

# %%
import sys
print(sys.version)

#Python 3.7.4 (default, Aug 9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
#pygbif 0.3.0
# Out:
# 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from pygbif import species
from pygbif import occurrences as occ
import sqlite3
from sqlite3 import Error

# %% [markdown]
# ### Setting up some parameters

# %%
# There is no point accepting all the species that have more than one record.
# There are too many casual records of plants and birds
thresholdForOccNum = 5
# If you want to exclude the interactions list them comma seperated here
interactionsToExclude = "interactsWith"
#interactionsToExclude = ""

# %%
## Define the country of interest
country  = 'BE'

## Define the year from where to consider records for the occupancy
year = 2000

## Define the place to find the data cube for occupancy data
## Currently the cube contains only Belgian data so that is all that can be used
database = r"..\data\cube.db" 

## Define the place to find the interaction data
globiDB = r"..\data\globi.db"

# %% [markdown]
# ### Define the key taxon for the notebook for which to find all interactions

# %%
#taxon = "Oxalis corniculata"
#taxon = "Oxalis pes-caprae"
#taxon = "Abramis brama"
#taxon = "Dikerogammarus villosus" # killer shrimp
#taxon = "Lantanophaga pusillidactyla"
#taxon = "Lantana camara"
#taxon = "Cirsium vulgare"
#taxon = "Solenopsis invicta"
#taxon = "Linepithema humile" #Argentine ant
#taxon = "Procyon lotor" # raccoon
#taxon = "Carpobrotus edulis"
#taxon = "not exist"
#taxon = "Sciurus carolinensis" # Eastern grey squirrel
taxon = "Pipistrellus pipistrellus" # Common Pipistrelle
#taxon = "Triturus carnifex"
#taxon = "Triturus"
#taxon = "Xenopus laevis"
#taxon = "Rhinella marina"
#taxon = "Cynops pyrrhogaster"
#taxon = "Pachytriton labiatus"
#taxon = "Pleurodeles waltl"
#taxon = "Podarcis sicula"

# %% [markdown]
# ## Check to see if the taxon exits in GBIF

# %%
try:
    #NOTE: The function method name_suggest has a different behavior with regards to the gender of Latin names to name_backbone
    # If name_backbone is given a name in one gender it can still return the best match from the GBIF backbone if that
    # name is spelled as if it was another gender.
    #key = species.name_suggest(q=taxon, limit = 1)
    match = species.name_backbone(name=taxon, limit = 1)
    #print(key)
    
    # if there is no match this is returned form .name_backbone {'confidence': 100, 'matchType': 'NONE', 'synonym': False}
    if match['matchType'] == 'NONE':
        raise ValueError("TAXON NOT FOUND ON GBIF!")
    else:
        key = match['usageKey']
except ValueError as ve:
    print(ve)
    exit(1)

# %%
print('The taxon to be studied is ' + match['scientificName'])
# Out:
# The taxon to be studied is Pipistrellus pipistrellus (Schreber, 1774)

# %% [markdown]
# ### Take a look at the interactions that the taxon has

# %%
# What are all the types of interactions involving taxon as source taxon?
#data[data['sourceTaxonName'] == taxon]['interactionTypeName'].unique()
try:
    connGlobi = sqlite3.connect(globiDB)
except Error as e:
    print(e)

# %%
curGlobi = connGlobi.cursor()
curGlobi.execute("SELECT interactionTypeName from globi  WHERE sourceTaxonName = ? GROUP BY interactionTypeName;", (taxon,))
interactDataTaxon = curGlobi.fetchall()

# %%
interactDataTaxon
# Out:
# [('interactsWith',)]

# %%
curGlobi = connGlobi.cursor()
curGlobi.execute("SELECT interactionTypeName from globi  WHERE targetTaxonName = ? GROUP BY interactionTypeName;", (taxon,))
interactDataTaxon = curGlobi.fetchall()
interactDataTaxon
# Out:
# [('ectoparasiteOf',),
#  ('hasHost',),
#  ('interactsWith',),
#  ('parasiteOf',),
#  ('pathogenOf',)]

# %% [markdown]
# ## Get the primary interation data for the species in question

# %%
curGlobi = connGlobi.cursor()
curGlobi.execute("SELECT * from globi  WHERE targetTaxonName = ? and interactionTypeName NOT IN (?);", \
                 (taxon,interactionsToExclude,))
interactDataTaxon = curGlobi.fetchall()

# %%
curGlobi = connGlobi.cursor()
curGlobi.execute("SELECT * from globi  WHERE sourceTaxonName = ? and interactionTypeName NOT IN (?);", \
                 (taxon,interactionsToExclude,))
sources = curGlobi.fetchall()

# %%
interactDataTaxon.extend(sources)
len(interactDataTaxon)
# Out:
# 222

# %%
# Convert to a Pandas dataframe
interactDataTaxon = pd.DataFrame(interactDataTaxon)

# %%
# Add column names
interactDataTaxon
interactDataTaxon.columns = ['sourceTaxonId', \
                                'sourceTaxonIds','sourceTaxonName','sourceTaxonRank','sourceTaxonPathNames', \
                                'sourceTaxonPathIds','sourceTaxonPathRankNames','sourceTaxonSpeciesName','sourceTaxonSpeciesId',\
                                'sourceTaxonGenusName','sourceTaxonGenusId','sourceTaxonFamilyName','sourceTaxonFamilyId',\
                                'sourceTaxonOrderName','sourceTaxonOrderId','sourceTaxonClassName','sourceTaxonClassId',\
                                'sourceTaxonPhylumName','sourceTaxonPhylumId','sourceTaxonKingdomName','sourceTaxonKingdomId',\
                                'sourceId','sourceOccurrenceId','sourceCatalogNumber','sourceBasisOfRecordId',\
                                'sourceBasisOfRecordName','sourceLifeStageId','sourceLifeStageName','sourceBodyPartId',\
                                'sourceBodyPartName','sourcePhysiologicalStateId','sourcePhysiologicalStateName', \
                                'sourceSexId', 'sourceSexName','interactionTypeName',\
                                'interactionTypeId','targetTaxonId','targetTaxonIds','targetTaxonName',\
                                'targetTaxonRank','targetTaxonPathNames','targetTaxonPathIds','targetTaxonPathRankNames',\
                                'targetTaxonSpeciesName','targetTaxonSpeciesId','targetTaxonGenusName','targetTaxonGenusId',\
                                'targetTaxonFamilyName','targetTaxonFamilyId','targetTaxonOrderName','targetTaxonOrderId',\
                                'targetTaxonClassName','targetTaxonClassId','targetTaxonPhylumName','targetTaxonPhylumId',\
                                'targetTaxonKingdomName','targetTaxonKingdomId','targetId','targetOccurrenceId',\
                                'targetCatalogNumber','targetBasisOfRecordId','targetBasisOfRecordName','targetLifeStageId',\
                                'targetLifeStageName','targetBodyPartId','targetBodyPartName','targetPhysiologicalStateId',\
                                'targetPhysiologicalStateName', 'targetSexId', 'targetSexName',\
                                'decimalLatitude','decimalLongitude','localityId',\
                                'localityName','eventDateUnixEpoch','argumentTypeId','referenceCitation',\
                                'referenceDoi','referenceUrl','sourceCitation','sourceNamespace',\
                                'sourceArchiveURI','sourceDOI','sourceLastSeenAtUnixEpoch']

# %% [markdown]
# ## Get a list of all the primary interacting species

# %%
interactingTaxaData = interactDataTaxon.drop_duplicates()

# %%
primaryInteractingTaxa = interactingTaxaData['sourceTaxonName'].drop_duplicates()
len(primaryInteractingTaxa)
# Out:
# 27

# %%
primaryInteractingTaxa = (primaryInteractingTaxa.append(interactingTaxaData['targetTaxonName']).drop_duplicates())
len(primaryInteractingTaxa)
# Out:
# 28

# %%
primaryInteractingTaxa
# Out:
# 0                                      Cimex pipistrelli
# 1                                           Basilia nana
# 2                                   Nycteribia kolenatii
# 3                              Pipistrellus pipistrellus
# 8                              Phthiridium biarticulatum
# 13                                         Ischnopsyllus
# 15                             Nycteridopsylla longiceps
# 61                               Nycteridopsylla eusarca
# 138    Betacoronavirus Coronavirus P.pipi/VM314/2008/NLD
# 139    Betacoronavirus Coronavirus P.pipi/VM312/2008/NLD
# 140     Alphacoronavirus Alphacoronavirus Pip3_M_FR_2014
# 141    Alphacoronavirus Alphacoronavirus Pip2_Cr_FR_2014
# 142    Alphacoronavirus Alphacoronavirus Pip1_Cr_FR_2014
# 143          Alphacoronavirus Coronavirus PREDICT CoV-61
# 144           Betacoronavirus Coronavirus PREDICT CoV-57
# 146    Betacoronavirus Pipistrellus bat coronavirus HKU5
# 149          Alphacoronavirus Coronavirus PREDICT CoV-60
# 154                Alphacoronavirus Alphacoronavirus sp.
# 159                                      Bat coronavirus
# 164                                        Sokoluk virus
# 165                             Cripavirus NB-1/2011/HUN
# 166                                     Bat adenovirus 2
# 171                                         Litomosoides
# 172                               Pycnoporus heteroporus
# 173                                Pasteurella multocida
# 204                             Lecithodendrium linstowi
# 206                              Yersinia enterocolitica
# 207                                              no name
# dtype: object

# %% [markdown]
# ## A function to query the globi database

# %%
def secondaryDataInGlobi(conn, intaxon):
    cur = conn.cursor()
    cur.execute("SELECT * from globi where (targetTaxonName = ? OR sourceTaxonName = ?) and interactionTypeName NOT IN (?);", \
                (intaxon,intaxon,interactionsToExclude,))
    return(cur.fetchall())

# %% [markdown]
# ## Get all the secondary interactions

# %%
try:
    conn = sqlite3.connect(globiDB)
except Error as e:
    print(e)

# %%
secondarylist = []

for name in primaryInteractingTaxa:
    temp = secondaryDataInGlobi(conn, name)
    secondarylist.extend(temp)

# %%
# Convert to a Pandas dataframe
secondarylist = pd.DataFrame(secondarylist)

# %%
secondarylist.columns = ['sourceTaxonId', \
                                'sourceTaxonIds','sourceTaxonName','sourceTaxonRank','sourceTaxonPathNames', \
                                'sourceTaxonPathIds','sourceTaxonPathRankNames','sourceTaxonSpeciesName','sourceTaxonSpeciesId',\
                                'sourceTaxonGenusName','sourceTaxonGenusId','sourceTaxonFamilyName','sourceTaxonFamilyId',\
                                'sourceTaxonOrderName','sourceTaxonOrderId','sourceTaxonClassName','sourceTaxonClassId',\
                                'sourceTaxonPhylumName','sourceTaxonPhylumId','sourceTaxonKingdomName','sourceTaxonKingdomId',\
                                'sourceId','sourceOccurrenceId','sourceCatalogNumber','sourceBasisOfRecordId',\
                                'sourceBasisOfRecordName','sourceLifeStageId','sourceLifeStageName','sourceBodyPartId',\
                                'sourceBodyPartName','sourcePhysiologicalStateId','sourcePhysiologicalStateName',\
                                'sourceSexId', 'sourceSexName', 'interactionTypeName',\
                                'interactionTypeId','targetTaxonId','targetTaxonIds','targetTaxonName',\
                                'targetTaxonRank','targetTaxonPathNames','targetTaxonPathIds','targetTaxonPathRankNames',\
                                'targetTaxonSpeciesName','targetTaxonSpeciesId','targetTaxonGenusName','targetTaxonGenusId',\
                                'targetTaxonFamilyName','targetTaxonFamilyId','targetTaxonOrderName','targetTaxonOrderId',\
                                'targetTaxonClassName','targetTaxonClassId','targetTaxonPhylumName','targetTaxonPhylumId',\
                                'targetTaxonKingdomName','targetTaxonKingdomId','targetId','targetOccurrenceId',\
                                'targetCatalogNumber','targetBasisOfRecordId','targetBasisOfRecordName','targetLifeStageId',\
                                'targetLifeStageName','targetBodyPartId','targetBodyPartName','targetPhysiologicalStateId',\
                                'targetPhysiologicalStateName', 'targetSexId', 'targetSexName', \
                                'decimalLatitude','decimalLongitude','localityId',\
                                'localityName','eventDateUnixEpoch','argumentTypeId','referenceCitation',\
                                'referenceDoi','referenceUrl','sourceCitation','sourceNamespace',\
                                'sourceArchiveURI','sourceDOI','sourceLastSeenAtUnixEpoch']

# %%
allInteractionsData = interactingTaxaData.append(secondarylist)

# %%
allInteractionsData = allInteractionsData.drop_duplicates()

# %%
    cleanInteractDataTaxon = allInteractionsData[['sourceTaxonId', 'sourceTaxonName', 'sourceTaxonRank',
       'sourceTaxonFamilyName', 'interactionTypeName',
       'targetTaxonName','targetTaxonRank', 'sourceCitation', 'sourceDOI'
        ]].dropna(subset=['targetTaxonName','sourceTaxonName'])

# %%
allSourceInteractingTaxa = cleanInteractDataTaxon['sourceTaxonName'].drop_duplicates()
allTargetInteractingTaxa = cleanInteractDataTaxon['targetTaxonName'].drop_duplicates()

# %%
allInteractingTaxa = allSourceInteractingTaxa.append(allTargetInteractingTaxa).drop_duplicates()
allInteractingTaxa.count()
# Out:
# 3526

# %%
allInteractingTaxa.head()
# Out:
# 0            Cimex pipistrelli
# 1                 Basilia nana
# 2         Nycteribia kolenatii
# 3    Pipistrellus pipistrellus
# 8    Phthiridium biarticulatum
# dtype: object

# %%
# How many different sort of interaction do I have left?
# Checking out all the interaction types
cleanInteractDataTaxon.groupby(cleanInteractDataTaxon['interactionTypeName']).size().sort_values(ascending = False)
# Out:
# interactionTypeName
# interactsWith      21995
# hasHost             2330
# preysOn             1305
# pathogenOf           694
# ectoparasiteOf       276
# eats                 216
# parasiteOf            42
# visitsFlowersOf       13
# endoparasiteOf         1
# dtype: int64

# %% [markdown]
# ### This function takes a name string and checks on GBIF to see if the name exists there.

# %%
def speciesExistsInGBIF(name, rank):
    try:
        match = species.name_backbone(name=name, rank=rank, limit = 1)

        # if there is no match this is returned from .name_backbone {'confidence': 100, 'matchType': 'NONE', 'synonym': False}
        if match['matchType'] == 'NONE':
            return False
        else:
            return match
    except ValueError as ve:
        print(ve)
        exit(1)

# %% [markdown]
# ### Check that the species in question is actually found on GBIF

# %%
if(speciesExistsInGBIF(taxon, "species") == False):
    print("##### {0} has not been found on GBIF #####".format(taxon))

# %% [markdown]
# ### Check to see which taxa in the interaction network are found in GBIF and list those ones that are not

# %%
taxaFound = {}

print('Taxa from GLoBI, but not found in GBIF')
for name in allInteractingTaxa.items():
    GBIFName = speciesExistsInGBIF(name[1], "species")
    if GBIFName == False:
        taxaFound[name[1]] = False
        print(name[1])
    else:
        taxaFound[name[1]] = GBIFName['usageKey']
# Out:
# Taxa from GLoBI, but not found in GBIF
# Betacoronavirus Coronavirus P.pipi/VM314/2008/NLD
# Betacoronavirus Coronavirus P.pipi/VM312/2008/NLD
# Alphacoronavirus Alphacoronavirus Pip3_M_FR_2014
# Alphacoronavirus Alphacoronavirus Pip2_Cr_FR_2014
# Alphacoronavirus Alphacoronavirus Pip1_Cr_FR_2014
# Alphacoronavirus Coronavirus PREDICT CoV-61
# Betacoronavirus Coronavirus PREDICT CoV-57
# Betacoronavirus Pipistrellus bat coronavirus HKU5
# Alphacoronavirus Coronavirus PREDICT CoV-60
# Alphacoronavirus Alphacoronavirus sp.
# Bat coronavirus
# Sokoluk virus
# Cripavirus NB-1/2011/HUN
# Bat adenovirus 2
# Yersinia phage vB_YenP_ISAO8
# Yersinia phage vB_YenP_AP5
# Yersinia phage vB_YenP_AP10
# Yersinia phage vB_YenM_TG1
# Yersinia phage PY54
# Yersinia phage phiYeO3-12
# Yersinia phage phiR201
# Yersinia phage phiR1-RT
# Yersinia phage phiR1-37
# Eucoilinae gen. H sp. 1 MB404
# no name
# Sternorrhyncha
# Auchenorrhyncha
# Crustacea
# Salix longifolia
# Erica
# Salix ambigua
# Salix rubra
# Sida spinosa
# Papilionoideae
# Yeast
# Acetic acid bacteria
# Phytoplasma sp.
# Virus (most likely)
# Ribeiro
# Cowpea mosaic vVirus
# Alfamovirus
# Tobamovirus
# Rhabdovirus
# Arhar mosaic virus
# Actinobacteria
# Bacteria
# Sida
# Eriopterini
# Hexatomini
# marine invertebrates
# Echiura
# Polychaeta
# Urochordata
# Neoloricata
# Cirripedia
# Brachyura
# Caridea
# Zooplankton
# Gorgonacea
# Unknown host
# Hylaeinae
# Colletinae
# Sphecinae
# Tortricidae
# Polistinae
# Stellaria
# Salix
# Sphex
# Phytoplasma
# Xylocopini
# Xylocopinae
# Bombini
# Osmiini
# Megachilini
# Halictinae
# Acari
# Trypanosoma
# Nitzschia
# Wheat streak mosaic virus--wild rice
# Diseases of Bedding Plants
# Ulmus
# Trees and shrubs
# Calamus
# Detritus
# Gnathostomata

# %%
# Convert to a Pandas dataframe
taxaFound = pd.DataFrame.from_dict(taxaFound, orient='index')

# %%
len(taxaFound)
# Out:
# 3526

# %%
taxaFound
# Out:
#                                                          0
# Cimex pipistrelli                                  4487133
# Basilia nana                                       1638644
# Nycteribia kolenatii                               1639169
# Pipistrellus pipistrellus                          5218465
# Phthiridium biarticulatum                          1638184
# Ischnopsyllus                                      1417597
# Nycteridopsylla longiceps                          1417549
# Nycteridopsylla eusarca                            1417563
# Betacoronavirus Coronavirus P.pipi/VM314/2008/NLD    False
# Betacoronavirus Coronavirus P.pipi/VM312/2008/NLD    False
# Alphacoronavirus Alphacoronavirus Pip3_M_FR_2014     False
# Alphacoronavirus Alphacoronavirus Pip2_Cr_FR_2014    False
# Alphacoronavirus Alphacoronavirus Pip1_Cr_FR_2014    False
# Alphacoronavirus Coronavirus PREDICT CoV-61          False
# Betacoronavirus Coronavirus PREDICT CoV-57           False
# Betacoronavirus Pipistrellus bat coronavirus HKU5    False
# Alphacoronavirus Coronavirus PREDICT CoV-60          False
# Alphacoronavirus Alphacoronavirus sp.                False
# Bat coronavirus                                      False
# Sokoluk virus                                        False
# Cripavirus NB-1/2011/HUN                             False
# Bat adenovirus 2                                     False
# Litomosoides                                       4630900
# Pycnoporus heteroporus                             8144113
# Pasteurella multocida                              3222236
# Lecithodendrium linstowi                           4415240
# Yersinia enterocolitica                            5427626
# Nyctalus noctula                                   5218524
# Eptesicus serotinus                                2432359
# Myotis bechsteini                                  2432427
# ...                                                    ...
# Lepidochelys olivacea                              2442153
# Eretmochelys imbricata                             8841716
# Chelonia mydas                                     2442225
# Corallina officinalis                              5276013
# Lobatus gigas                                      4963453
# Tagelus plebeius                                   2287055
# Collisella limatula                                2297880
# Lottia gigantea                                    2297856
# Modiolus modiolus                                  2285656
# Mytilus edulis                                     8288896
# Geukensia demissa                                  2285800
# Rimapenaeus constrictus                            2223463
# Rangia cuneata                                     5188971
# Terebratalia transversa                            2252850
# Allonautilus scrobiculatus                         2289209
# Nautilus pompilius                                 2289202
# Jasus frontalis                                    5178284
# Ommastrephes bartramii                             2290475
# Crangon                                            2222161
# Scomber                                            2374148
# Astarte arctica                                    5189183
# Urophycis chuss                                    2415718
# Gadidae                                               3701
# Urophycis regia                                    2415740
# Urophycis tenuis                                   2415734
# Pandalidae                                            8658
# Decapoda                                               637
# Mysidae                                               5404
# Pycnanthemum flexuosum                             2927351
# Mentha verticillata                                8172952
#
# [3526 rows x 1 columns]

# %% [markdown]
# ### This function takes a GBIF species key and counts how many occurences exist in the data cube

# %%
def speciesCountInCube(conn, key):
    cur = conn.cursor()
    cur.execute("SELECT COUNT(taxonKey) from (SELECT taxonKey FROM cube WHERE year > ? and taxonKey = ? GROUP BY eea_cell_code)", (year, key,))
    return(cur.fetchall())

# %% [markdown]
# ### Loop over all the taxa that are in the interaction network and are in GBIF to find the ones that have been found in the country

# %%
taxaFoundInCountry = []

try:
    conn = sqlite3.connect(database)
except Error as e:
    print(e)

# %%
year
# Out:
# 2000

# %%
for GBIFtaxon in taxaFound.iterrows():
    GBIFOccCount = speciesCountInCube(conn, GBIFtaxon[1][0])
    if GBIFOccCount[0][0] > thresholdForOccNum: # The threshold for observations is not greater than one, due to all the casual records
        taxaFoundInCountry.append({'key': GBIFtaxon[1][0], 'species': GBIFtaxon[0], 'count': GBIFOccCount[0][0]})
        print('{0} with key {1} occurs in {2} km squares.'.format(GBIFtaxon[0],GBIFtaxon[1][0],GBIFOccCount[0][0]))
# Out:
# Pipistrellus pipistrellus with key 5218465 occurs in 14 km squares.
# Myotis nattereri with key 2432389 occurs in 9 km squares.
# Plecotus auritus with key 5218507 occurs in 6 km squares.
# Myotis daubentoni with key 2432439 occurs in 6 km squares.
# Bucephala clangula with key 2498326 occurs in 3386 km squares.
# Aythya affinis with key 2498257 occurs in 59 km squares.
# Aythya collaris with key 2498264 occurs in 192 km squares.
# Anas discors with key 2498073 occurs in 177 km squares.
# Clupea harengus with key 8351946 occurs in 366 km squares.
# Erigeron canadensis with key 3146791 occurs in 6797 km squares.
# Populus deltoides with key 3040232 occurs in 10 km squares.
# Cichorium intybus with key 5392252 occurs in 1387 km squares.
# Populus alba with key 3040233 occurs in 1527 km squares.
# Quercus palustris with key 8313153 occurs in 311 km squares.
# Potentilla indica with key 8591421 occurs in 1720 km squares.
# Dolichotis patagonum with key 2437619 occurs in 7 km squares.
# Branta canadensis with key 5232437 occurs in 11316 km squares.
# Platichthys flesus with key 2409330 occurs in 501 km squares.
# Myoxocephalus scorpius with key 2333785 occurs in 181 km squares.
# Larus canus with key 7982160 occurs in 9729 km squares.
# Tringa totanus with key 2481714 occurs in 6031 km squares.
# Pluvialis squatarola with key 2480327 occurs in 1642 km squares.
# Charadrius hiaticula with key 9566659 occurs in 3252 km squares.
# Haematopus ostralegus with key 7788295 occurs in 10448 km squares.
# Hediste diversicolor with key 2316416 occurs in 8 km squares.
# Crepidula fornicata with key 5192789 occurs in 186 km squares.
# Sterna forsteri with key 5229247 occurs in 29 km squares.
# Larus delawarensis with key 2481134 occurs in 103 km squares.
# Larus argentatus with key 2481139 occurs in 11216 km squares.
# Lophodytes cucullatus with key 2498408 occurs in 85 km squares.
# Circus cyaneus with key 2480487 occurs in 8469 km squares.
# Haliaeetus leucocephalus with key 2480446 occurs in 13 km squares.
# Mergus serrator with key 2498375 occurs in 1175 km squares.
# Phalacrocorax carbo with key 2481890 occurs in 13119 km squares.
# Gavia immer with key 2481962 occurs in 671 km squares.
# Agabus bipustulatus with key 4469860 occurs in 28 km squares.
# Enallagma cyathigerum with key 5051273 occurs in 67 km squares.
# Lestes sponsa with key 1424038 occurs in 9 km squares.
# Lumbriculus variegatus with key 2308023 occurs in 9 km squares.
# Corixa dentipes with key 5156066 occurs in 20 km squares.
# Notonecta glauca with key 2020522 occurs in 755 km squares.
# Hesperocorixa sahlbergi with key 4485375 occurs in 266 km squares.
# Holocentropus picicornis with key 1437589 occurs in 25 km squares.
# Corixa punctata with key 5156063 occurs in 382 km squares.
# Limnephilus marmoratus with key 1442615 occurs in 462 km squares.
# Sympetrum danae with key 1428334 occurs in 16 km squares.
# Argyroneta aquatica with key 2179068 occurs in 6 km squares.
# Tropocyclops prasinus with key 2116884 occurs in 8 km squares.
# Daphnia pulex with key 2234840 occurs in 48 km squares.
# Alona affinis with key 5180060 occurs in 6 km squares.
# Macrocyclops albidus with key 2117023 occurs in 22 km squares.
# Eucyclops serrulatus with key 2116800 occurs in 29 km squares.
# Bosmina longirostris with key 2234694 occurs in 12 km squares.
# Lepomis gibbosus with key 2394486 occurs in 689 km squares.
# Cryptomonas erosa with key 3202440 occurs in 24 km squares.
# Cryptomonas ovata with key 3202416 occurs in 8 km squares.
# Elymus repens with key 5290299 occurs in 4817 km squares.
# Festuca rubra with key 2704922 occurs in 6676 km squares.
# Arytaina genistae with key 2014262 occurs in 29 km squares.
# Orthotylus virescens with key 4488119 occurs in 6 km squares.
# Heterocordylus tibialis with key 4488141 occurs in 25 km squares.
# Cytisus scoparius with key 5354656 occurs in 5672 km squares.
# Cyanistes caeruleus with key 2487879 occurs in 14359 km squares.
# Parus major with key 9705453 occurs in 15012 km squares.
# Propylaea quatuordecimpunctata with key 1043572 occurs in 2076 km squares.
# Adalia decempunctata with key 4452227 occurs in 970 km squares.
# Chrysoperla carnea with key 2105360 occurs in 1311 km squares.
# Ectobius lapponicus with key 1998104 occurs in 64 km squares.
# Anthocoris nemoralis with key 2020846 occurs in 52 km squares.
# Forficula auricularia with key 1419845 occurs in 1331 km squares.
# Anatis ocellata with key 5749359 occurs in 401 km squares.
# Anthocoris nemorum with key 2020855 occurs in 415 km squares.
# Adalia bipunctata with key 1043097 occurs in 1725 km squares.
# Coccinella septempunctata with key 4990191 occurs in 3810 km squares.
# Fringilla coelebs with key 2494422 occurs in 15535 km squares.
# Prunella modularis with key 5231763 occurs in 13755 km squares.
# Salmo trutta with key 8215487 occurs in 159 km squares.
# Nitzschia palea with key 8140167 occurs in 10 km squares.
# Salmo salar with key 7595433 occurs in 9 km squares.
# Phoxinus phoxinus with key 4409653 occurs in 32 km squares.
# Plectrocnemia conspersa with key 1438067 occurs in 59 km squares.
# Baetis rhodani with key 4481106 occurs in 7 km squares.
# Sialis fuliginosa with key 5101327 occurs in 8 km squares.
# Prodiamesa olivacea with key 1447598 occurs in 8 km squares.
# Cepaea nemoralis with key 2294280 occurs in 50 km squares.
# Quercus robur with key 2878688 occurs in 8701 km squares.
# Andricus curvator with key 1309593 occurs in 277 km squares.
# Agelena labyrinthica with key 2139576 occurs in 95 km squares.
# Linyphia triangularis with key 2136609 occurs in 290 km squares.
# Paracalanus parvus with key 2114242 occurs in 60 km squares.
# Potamopyrgus antipodarum with key 5192470 occurs in 827 km squares.
# Buteo jamaicensis with key 2480542 occurs in 9 km squares.
# Hydropsyche instabilis with key 5054177 occurs in 7 km squares.
# Psychomyia pusilla with key 4482345 occurs in 16 km squares.
# Cynips longiventris with key 4496917 occurs in 812 km squares.
# Cynips divisa with key 1309671 occurs in 366 km squares.
# Glycine max with key 5359660 occurs in 21 km squares.
# Oxybelus uniglumis with key 4494793 occurs in 319 km squares.
# Crossocerus wesmaeli with key 4494895 occurs in 34 km squares.
# Formica fusca with key 1314881 occurs in 1816 km squares.
# Falco sparverius with key 9685907 occurs in 9 km squares.
# Apodemus sylvaticus with key 2437760 occurs in 13 km squares.
# Lissotriton vulgaris with key 5218405 occurs in 109 km squares.
# Bufo bufo with key 5217160 occurs in 145 km squares.
# Catabrosa aquatica with key 2705315 occurs in 59 km squares.
# Wisteria sinensis with key 2977331 occurs in 23 km squares.
# Torilis japonica with key 3034820 occurs in 2108 km squares.
# Oenanthe crocata with key 6027319 occurs in 38 km squares.
# Triticum aestivum with key 7795888 occurs in 376 km squares.
# Vitis vinifera with key 5372392 occurs in 144 km squares.
# Eudorina elegans with key 5271384 occurs in 8 km squares.
# Angelica sylvestris with key 5371818 occurs in 5831 km squares.
# Brassica rapa with key 7903057 occurs in 973 km squares.
# Sus scrofa with key 7705930 occurs in 35 km squares.
# Martes martes with key 5218878 occurs in 8 km squares.
# Gastrodes grossipes with key 5758915 occurs in 100 km squares.
# Kerria japonica with key 5371450 occurs in 155 km squares.
# Physocarpus opulifolius with key 2988354 occurs in 28 km squares.
# Scrophularia nodosa with key 3170886 occurs in 4314 km squares.
# Vinca minor with key 3169707 occurs in 2151 km squares.
# Vinca major with key 3169708 occurs in 677 km squares.
# Amelanchier lamarckii with key 3024109 occurs in 1149 km squares.
# Tanacetum vulgare with key 3118274 occurs in 7715 km squares.
# Lapsana communis with key 3134857 occurs in 6252 km squares.
# Solanum tuberosum with key 2930262 occurs in 246 km squares.
# Crepis capillaris with key 5403304 occurs in 6114 km squares.
# Hypochaeris radicata with key 3093702 occurs in 7633 km squares.
# Gastrophysa polygoni with key 1048335 occurs in 6 km squares.
# Muscari armeniacum with key 8152187 occurs in 92 km squares.
# Aquilegia vulgaris with key 3033191 occurs in 343 km squares.
# Talpa europaea with key 7872906 occurs in 19 km squares.
# Buxus sempervirens with key 2984671 occurs in 43 km squares.
# Caltha palustris with key 5371685 occurs in 4917 km squares.
# Oryctolagus cuniculus with key 2436940 occurs in 7643 km squares.
# Crataegus laevigata with key 8252683 occurs in 911 km squares.
# Populus nigra with key 3040227 occurs in 354 km squares.
# Piscicola geometra with key 5193997 occurs in 232 km squares.
# Hemiclepsis marginata with key 4308093 occurs in 93 km squares.
# Rutilus rutilus with key 2359706 occurs in 2096 km squares.
# Helianthemum nummularium with key 8890062 occurs in 171 km squares.
# Proasellus meridianus with key 2206086 occurs in 175 km squares.
# Sisymbrium officinale with key 3046890 occurs in 5285 km squares.
# Prunus persica with key 8149923 occurs in 84 km squares.
# Laurus nobilis with key 3034015 occurs in 25 km squares.
# Quercus ilex with key 2879098 occurs in 53 km squares.
# Ilex aquifolium with key 5414222 occurs in 5857 km squares.
# Clematis vitalba with key 3033558 occurs in 1807 km squares.
# Buddleja davidii with key 3173338 occurs in 3548 km squares.
# Conium maculatum with key 3034807 occurs in 1742 km squares.
# Pyrus communis with key 5362573 occurs in 259 km squares.
# Sturnus vulgaris with key 9809229 occurs in 14454 km squares.
# Erpobdella octoculata with key 2308846 occurs in 12 km squares.
# Planorbarius corneus with key 2290946 occurs in 42 km squares.
# Cygnus olor with key 2498343 occurs in 9240 km squares.
# Lotus corniculatus with key 5357013 occurs in 4864 km squares.
# Iris pseudacorus with key 5298231 occurs in 7143 km squares.
# Phragmites australis with key 5290149 occurs in 6811 km squares.
# Dioscorea communis with key 2755063 occurs in 193 km squares.
# Vicia faba with key 2974832 occurs in 59 km squares.
# Pisum sativum with key 5347845 occurs in 115 km squares.
# Muntiacus reevesi with key 2440946 occurs in 152 km squares.
# Fatsia japonica with key 3039046 occurs in 19 km squares.
# Nerium oleander with key 3169756 occurs in 8 km squares.
# Pilophorus cinnamopterus with key 5759170 occurs in 15 km squares.
# Leymus arenarius with key 2706368 occurs in 251 km squares.
# Adiantum capillus-veneris with key 2651816 occurs in 13 km squares.
# Artemisia vulgaris with key 3120946 occurs in 7482 km squares.
# Viburnum opulus with key 2888605 occurs in 4230 km squares.
# Viburnum tinus with key 2888585 occurs in 43 km squares.
# Atriplex portulacoides with key 3083765 occurs in 99 km squares.
# Atriplex prostrata with key 3083786 occurs in 2331 km squares.
# Atriplex patula with key 3083728 occurs in 2524 km squares.
# Beta vulgaris with key 8971274 occurs in 174 km squares.
# Vaccinium myrtillus with key 2882833 occurs in 2579 km squares.
# Salix repens with key 9148812 occurs in 1069 km squares.
# Circaea lutetiana with key 3188794 occurs in 3310 km squares.
# Pinus sylvestris with key 5285637 occurs in 2593 km squares.
# Lycopus europaeus with key 5341478 occurs in 6838 km squares.
# Origanum vulgare with key 2926612 occurs in 2223 km squares.
# Persicaria maculosa with key 6391194 occurs in 5552 km squares.
# Salix purpurea with key 5372800 occurs in 336 km squares.
# Alnus glutinosa with key 2876213 occurs in 6903 km squares.
# Myosotis scorpioides with key 5341184 occurs in 3008 km squares.
# Raphanus raphanistrum with key 3040983 occurs in 1817 km squares.
# Brassica oleracea with key 3042845 occurs in 202 km squares.
# Sinapis alba with key 3047621 occurs in 435 km squares.
# Brassica nigra with key 3042658 occurs in 1035 km squares.
# Sinapis arvensis with key 3047598 occurs in 3796 km squares.
# Syritta pipiens with key 1544431 occurs in 8 km squares.
# Glechoma hederacea with key 2926557 occurs in 8719 km squares.
# Betula pendula with key 5331916 occurs in 5880 km squares.
# Betula pubescens with key 9118014 occurs in 2751 km squares.
# Gleditsia triacanthos with key 2959443 occurs in 45 km squares.
# Fagus sylvatica with key 2882316 occurs in 3569 km squares.
# Acer campestre with key 3189863 occurs in 2891 km squares.
# Thymelicus sylvestris with key 8273661 occurs in 887 km squares.
# Colotois pennaria with key 1968867 occurs in 6 km squares.
# Ectemnius cavifrons with key 4494969 occurs in 37 km squares.
# Leucanthemum vulgare with key 8848598 occurs in 6156 km squares.
# Asparagus officinalis with key 2768885 occurs in 1049 km squares.
# Centaurium littorale with key 5414469 occurs in 171 km squares.
# Ballota nigra with key 2926894 occurs in 986 km squares.
# Lamium galeobdolon with key 2927324 occurs in 5429 km squares.
# Bombus lapidarius with key 1340301 occurs in 8485 km squares.
# Prunella vulgaris with key 5341297 occurs in 5642 km squares.
# Polygonum aviculare with key 7821030 occurs in 6357 km squares.
# Althaea officinalis with key 3152520 occurs in 216 km squares.
# Plantago maritima with key 3189755 occurs in 104 km squares.
# Plantago coronopus with key 3189739 occurs in 2521 km squares.
# Antirrhinum majus with key 3172001 occurs in 275 km squares.
# Cymbalaria muralis with key 8200663 occurs in 2829 km squares.
# Fraxinus excelsior with key 3172358 occurs in 6416 km squares.
# Pagurus bernhardus with key 2224231 occurs in 416 km squares.
# Vicia cracca with key 2975287 occurs in 5781 km squares.
# Tilia cordata with key 3152047 occurs in 457 km squares.
# Carpinus betulus with key 2875818 occurs in 3205 km squares.
# Ribes nigrum with key 2986192 occurs in 1290 km squares.
# Acer pseudoplatanus with key 3189870 occurs in 6125 km squares.
# Convolvulus arvensis with key 2928390 occurs in 4024 km squares.
# Corylus avellana with key 2875979 occurs in 6780 km squares.
# Rhamnus cathartica with key 3039491 occurs in 302 km squares.
# Vicia tetrasperma with key 2975083 occurs in 2193 km squares.
# Vicia hirsuta with key 2975328 occurs in 5488 km squares.
# Capsicum annuum with key 2932944 occurs in 8 km squares.
# Solanum nigrum with key 9150405 occurs in 4599 km squares.
# Andromeda polifolia with key 5333413 occurs in 158 km squares.
# Halictus confusus with key 1353363 occurs in 105 km squares.
# Apis mellifera with key 1341976 occurs in 7053 km squares.
# Eristalis tenax with key 1541217 occurs in 54 km squares.
# Pastinaca sativa with key 8262702 occurs in 2163 km squares.
# Melilotus officinalis with key 2971024 occurs in 1606 km squares.
# Amorpha fruticosa with key 5357407 occurs in 22 km squares.
# Helianthus annuus with key 9206251 occurs in 441 km squares.
# Rudbeckia hirta with key 3114225 occurs in 85 km squares.
# Solidago canadensis with key 5389029 occurs in 1260 km squares.
# Pontederia cordata with key 2766030 occurs in 120 km squares.
# Erigeron annuus with key 3117449 occurs in 1419 km squares.
# Anthemis cotula with key 8035698 occurs in 102 km squares.
# Alisma plantago-aquatica with key 2865100 occurs in 4020 km squares.
# Arctium lappa with key 7353729 occurs in 1688 km squares.
# Cirsium arvense with key 3113414 occurs in 8954 km squares.
# Achillea millefolium with key 3120060 occurs in 9248 km squares.
# Symphoricarpos orbiculatus with key 2888636 occurs in 11 km squares.
# Sagittaria latifolia with key 5328909 occurs in 52 km squares.
# Asclepias syriaca with key 3170247 occurs in 17 km squares.
# Mentha arvensis with key 2927192 occurs in 929 km squares.
# Melilotus albus with key 2971095 occurs in 3769 km squares.
# Hydrangea arborescens with key 2985986 occurs in 6 km squares.
# Symphoricarpos albus with key 7523753 occurs in 1956 km squares.
# Bidens cernua with key 5391710 occurs in 684 km squares.
# Rosa carolina with key 3006171 occurs in 7 km squares.
# Trifolium repens with key 5358748 occurs in 8349 km squares.
# Robinia pseudoacacia with key 5352251 occurs in 4235 km squares.
# Prunus serotina with key 3021850 occurs in 5680 km squares.
# Trifolium pratense with key 8324121 occurs in 8061 km squares.
# Capsella bursa-pastoris with key 5375388 occurs in 6541 km squares.
# Aesculus hippocastanum with key 3189815 occurs in 1857 km squares.
# Salix eriocephala with key 5372614 occurs in 20 km squares.
# Potentilla norvegica with key 5365305 occurs in 225 km squares.
# Ipomoea hederacea with key 2928538 occurs in 14 km squares.
# Cucurbita pepo with key 2874508 occurs in 95 km squares.
# Calystegia sepium with key 2928441 occurs in 7008 km squares.
# Ipomoea purpurea with key 2928576 occurs in 24 km squares.
# Stellaria media with key 5384604 occurs in 7185 km squares.
# Nepeta cataria with key 5341499 occurs in 49 km squares.
# Cirsium vulgare with key 3112801 occurs in 7746 km squares.
# Helianthus tuberosus with key 3119175 occurs in 268 km squares.
# Abutilon theophrasti with key 3152614 occurs in 234 km squares.
# Verbesina alternifolia with key 3147815 occurs in 6 km squares.
# Verbena hastata with key 2925527 occurs in 36 km squares.
# Verbascum thapsus with key 3171949 occurs in 2512 km squares.
# Lobelia siphilitica with key 5409120 occurs in 6 km squares.
# Rudbeckia laciniata with key 3114229 occurs in 36 km squares.
# Parthenocissus quinquefolia with key 3039194 occurs in 122 km squares.
# Solidago gigantea with key 5389017 occurs in 2828 km squares.
# Oxalis dillenii with key 2891677 occurs in 11 km squares.
# Arctium minus with key 5393103 occurs in 2932 km squares.
# Symphyotrichum novae-angliae with key 3151618 occurs in 14 km squares.
# Crepis tectorum with key 5403508 occurs in 31 km squares.
# Stachys palustris with key 2927245 occurs in 3220 km squares.
# Linaria vulgaris with key 5415020 occurs in 5552 km squares.
# Oenothera biennis with key 3188924 occurs in 1193 km squares.
# Barbarea vulgaris with key 5708780 occurs in 13 km squares.
# Acer negundo with key 3189866 occurs in 419 km squares.
# Medicago sativa with key 9151957 occurs in 2463 km squares.
# Malus pumila with key 3001093 occurs in 571 km squares.
# Meles meles with key 2433875 occurs in 20 km squares.
# Fulmarus glacialis with key 2481433 occurs in 280 km squares.
# Falco peregrinus with key 2481047 occurs in 10256 km squares.
# Martes foina with key 5218887 occurs in 21 km squares.
# Poa pratensis with key 2704178 occurs in 3638 km squares.
# Deschampsia cespitosa with key 8059811 occurs in 3528 km squares.
# Calamagrostis canescens with key 4108861 occurs in 1633 km squares.
# Genista tinctoria with key 5347612 occurs in 28 km squares.
# Paris quadrifolia with key 5295911 occurs in 1403 km squares.
# Leonurus cardiaca with key 5341389 occurs in 326 km squares.
# Tilia platyphyllos with key 3152048 occurs in 842 km squares.
# Euonymus europaeus with key 3169131 occurs in 2308 km squares.
# Galium aparine with key 2913548 occurs in 8160 km squares.
# Chenopodium album with key 3083838 occurs in 5743 km squares.
# Cerastium fontanum with key 3085458 occurs in 7416 km squares.
# Tussilago farfara with key 3149879 occurs in 5711 km squares.
# Eupatorium cannabinum with key 5402943 occurs in 6993 km squares.
# Lythrum portula with key 3188743 occurs in 1272 km squares.
# Pteridium aquilinum with key 5275012 occurs in 4370 km squares.
# Viola odorata with key 5331181 occurs in 2200 km squares.
# Viola canina with key 5331258 occurs in 525 km squares.
# Viola tricolor with key 5331347 occurs in 1433 km squares.
# Geranium robertianum with key 2890668 occurs in 6893 km squares.
# Geranium sanguineum with key 2890920 occurs in 38 km squares.
# Geranium sylvaticum with key 2891147 occurs in 32 km squares.
# Crepis paludosa with key 5403296 occurs in 435 km squares.
# Scorzoneroides autumnalis with key 3133512 occurs in 3530 km squares.
# Leontodon hispidus with key 3137498 occurs in 457 km squares.
# Sonchus arvensis with key 3105813 occurs in 3331 km squares.
# Bellis perennis with key 3117424 occurs in 7791 km squares.
# Salix pentandra with key 5372647 occurs in 78 km squares.
# Ranunculus repens with key 3033339 occurs in 9065 km squares.
# Populus tremula with key 3040249 occurs in 2722 km squares.
# Galium odoratum with key 2914642 occurs in 471 km squares.
# Jacobaea vulgaris with key 5388602 occurs in 7293 km squares.
# Adoxa moschatellina with key 2888794 occurs in 3370 km squares.
# Ribes uva-crispa with key 2986185 occurs in 1206 km squares.
# Ribes rubrum with key 2986097 occurs in 4674 km squares.
# Athyrium filix-femina with key 5275044 occurs in 3575 km squares.
# Persicaria amphibia with key 6391648 occurs in 4923 km squares.
# Pseudomalus auratus with key 4494208 occurs in 47 km squares.
# Nomada marshamella with key 1343878 occurs in 197 km squares.
# Anthoxanthum odoratum with key 2705975 occurs in 6571 km squares.
# Sambucus nigra with key 2888728 occurs in 8457 km squares.
# Picea abies with key 5284884 occurs in 1738 km squares.
# Menyanthes trifoliata with key 5341511 occurs in 1032 km squares.
# Tripleurospermum inodorum with key 3104179 occurs in 2502 km squares.
# Glebionis segetum with key 3141101 occurs in 854 km squares.
# Medicago lupulina with key 2965201 occurs in 5705 km squares.
# Lotus pedunculatus with key 5356854 occurs in 6155 km squares.
# Senecio nemorensis with key 3107839 occurs in 218 km squares.
# Silene dioica with key 5384795 occurs in 5131 km squares.
# Tringa flavipes with key 2481721 occurs in 136 km squares.
# Balanus glandula with key 2115706 occurs in 9 km squares.
# Chlidonias niger with key 2481119 occurs in 2215 km squares.
# Esox lucius with key 2346633 occurs in 1413 km squares.
# Mya arenaria with key 7791733 occurs in 63 km squares.
# Galium palustre with key 2913130 occurs in 5067 km squares.
# Galium verum with key 9063248 occurs in 1192 km squares.
# Daucus carota with key 3034742 occurs in 6756 km squares.
# Torilis arvensis with key 3034823 occurs in 32 km squares.
# Setaria verticillata with key 5289686 occurs in 1289 km squares.
# Vaccinium corymbosum with key 2882849 occurs in 37 km squares.
# Viola hirta with key 5664290 occurs in 61 km squares.
# Seseli libanotis with key 3034133 occurs in 8 km squares.
# Neuroterus quercusbaccarum with key 1309692 occurs in 1170 km squares.
# Andricus kollari with key 1309600 occurs in 1102 km squares.
# Andricus quercuscalicis with key 4497124 occurs in 247 km squares.
# Phytolacca americana with key 3084015 occurs in 214 km squares.
# Brassica juncea with key 3042751 occurs in 71 km squares.
# Campsis radicans with key 7613490 occurs in 18 km squares.
# Trifolium hybridum with key 6109535 occurs in 1761 km squares.
# Impatiens capensis with key 2891774 occurs in 42 km squares.
# Cynoglossum officinale with key 2925815 occurs in 409 km squares.
# Physostegia virginiana with key 2926572 occurs in 23 km squares.
# Solanum dulcamara with key 2932737 occurs in 5897 km squares.
# Oxalis corniculata with key 8427624 occurs in 2923 km squares.
# Veronica peregrina with key 3172104 occurs in 1001 km squares.
# Lindernia dubia with key 3171888 occurs in 79 km squares.
# Lepidium virginicum with key 5376648 occurs in 1105 km squares.
# Rorippa palustris with key 3053168 occurs in 3144 km squares.
# Myosurus minimus with key 3033605 occurs in 810 km squares.
# Erigeron strigosus with key 3146632 occurs in 109 km squares.
# Berteroa incana with key 3053522 occurs in 901 km squares.
# Veronica arvensis with key 3172048 occurs in 4702 km squares.
# Plantago major with key 3189767 occurs in 7688 km squares.
# Potentilla recta with key 5367294 occurs in 463 km squares.
# Hibiscus trionum with key 3152560 occurs in 24 km squares.
# Marrubium vulgare with key 2927069 occurs in 15 km squares.
# Bidens connata with key 5392083 occurs in 123 km squares.
# Phleum pratense with key 9014945 occurs in 4214 km squares.
# Salix fragilis with key 5372829 occurs in 1514 km squares.
# Salix atrocinerea with key 5582546 occurs in 193 km squares.
# Salix aurita with key 5372876 occurs in 1158 km squares.
# Rubus idaeus with key 2993094 occurs in 1919 km squares.
# Mentha aquatica with key 2927208 occurs in 5363 km squares.
# Filipendula ulmaria with key 2987999 occurs in 6932 km squares.
# Geum rivale with key 5369701 occurs in 9 km squares.
# Juncus gerardii with key 2701297 occurs in 532 km squares.
# Alliaria petiolata with key 5376075 occurs in 6138 km squares.
# Rumex obtusifolius with key 2889011 occurs in 8136 km squares.
# Prunus spinosa with key 3023221 occurs in 5074 km squares.
# Lonicera tatarica with key 5334242 occurs in 17 km squares.
# Lathyrus tuberosus with key 5356522 occurs in 797 km squares.
# Lathyrus pratensis with key 5356701 occurs in 4829 km squares.
# Ulmus glabra with key 5361866 occurs in 1014 km squares.
# Ulex europaeus with key 2951984 occurs in 1374 km squares.
# Viscum album with key 2889828 occurs in 2006 km squares.
# Jasione montana with key 8366345 occurs in 2766 km squares.
# Salix cinerea with key 5372605 occurs in 2883 km squares.
# Salix caprea with key 5372952 occurs in 5310 km squares.
# Artemisia absinthium with key 3121319 occurs in 236 km squares.
# Seriphidium maritimum with key 3089922 occurs in 55 km squares.
# Myrmica scabrinodis with key 1318887 occurs in 1481 km squares.
# Formica rufa with key 1315132 occurs in 571 km squares.
# Ammophila arenaria with key 5289845 occurs in 405 km squares.
# Melampyrum pratense with key 7693914 occurs in 1132 km squares.
# Centaurea nigra with key 3128225 occurs in 108 km squares.
# Lactuca serriola with key 3140490 occurs in 4803 km squares.
# Solidago virgaurea with key 6446462 occurs in 1031 km squares.
# Eriosoma lanigerum with key 2075983 occurs in 22 km squares.
# Pilosella officinarum with key 9458333 occurs in 3534 km squares.
# Castanea sativa with key 5333294 occurs in 3841 km squares.
# Calluna vulgaris with key 2882482 occurs in 4592 km squares.
# Malva sylvestris with key 3152374 occurs in 3570 km squares.
# Urtica urens with key 5361815 occurs in 2928 km squares.
# Ononis spinosa with key 2977149 occurs in 1223 km squares.
# Trifolium fragiferum with key 5358935 occurs in 709 km squares.
# Rumex acetosella with key 2888995 occurs in 5430 km squares.
# Blackstonia perfoliata with key 6366886 occurs in 507 km squares.
# Centaurium erythraea with key 5414457 occurs in 2936 km squares.
# Medicago falcata with key 2965354 occurs in 330 km squares.
# Himacerus apterus with key 2021041 occurs in 568 km squares.
# Xysticus cristatus with key 2165052 occurs in 710 km squares.
# Glyceria fluitans with key 2705495 occurs in 3936 km squares.
# Dactylis glomerata with key 2705308 occurs in 7590 km squares.
# Lythrum salicaria with key 3188736 occurs in 6375 km squares.
# Humulus lupulus with key 2984535 occurs in 5464 km squares.
# Campanula trachelium with key 5412014 occurs in 546 km squares.
# Galeopsis tetrahit with key 5341300 occurs in 4182 km squares.
# Galeopsis angustifolia with key 5341306 occurs in 46 km squares.
# Stachys sylvatica with key 2927282 occurs in 4853 km squares.
# Lamium album with key 2926683 occurs in 7130 km squares.
# Sparganium erectum with key 7679536 occurs in 2893 km squares.
# Charadrius morinellus with key 2480281 occurs in 701 km squares.
# Chrysoteuchia culmella with key 1887290 occurs in 10 km squares.
# Apis mellifera scutellata with key 1341976 occurs in 7053 km squares.
# Pinus strobus with key 5284982 occurs in 170 km squares.
# Spinacia oleracea with key 3083647 occurs in 23 km squares.
# Myrica gale with key 5414202 occurs in 1305 km squares.
# Eremophila alpestris with key 9415596 occurs in 339 km squares.
# Bidens pilosa with key 5391845 occurs in 8 km squares.
# Myotis daubentonii with key 2432439 occurs in 6 km squares.
# Asio flammeus with key 2497295 occurs in 2802 km squares.
# Phoca vitulina with key 2434793 occurs in 9 km squares.
# Dama dama with key 5220136 occurs in 771 km squares.
# Cervus nippon with key 2440954 occurs in 21 km squares.
# Cervus elaphus with key 2440958 occurs in 11 km squares.
# Canis lupus with key 5219173 occurs in 14 km squares.
# Gallus gallus with key 9326020 occurs in 346 km squares.
# Meleagris gallopavo with key 9606290 occurs in 17 km squares.
# Anas platyrhynchos with key 9761484 occurs in 14221 km squares.
# Felis catus with key 2435035 occurs in 2370 km squares.
# Melopsittacus undulatus with key 2479798 occurs in 292 km squares.
# Mus musculus with key 7429082 occurs in 6 km squares.
# Vulpes vulpes with key 5219243 occurs in 43 km squares.
# Felis silvestris with key 7964291 occurs in 9 km squares.
# Rattus norvegicus with key 2439261 occurs in 3819 km squares.
# Laburnum anagyroides with key 5356345 occurs in 247 km squares.
# Aruncus dioicus with key 5362136 occurs in 23 km squares.
# Dryopteris filix-mas with key 5275132 occurs in 5534 km squares.
# Portulaca oleracea with key 3084719 occurs in 683 km squares.
# Persicaria hydropiper with key 8323622 occurs in 3896 km squares.
# Malva pusilla with key 3152372 occurs in 73 km squares.
# Lonicera periclymenum with key 5334277 occurs in 6013 km squares.
# Sorbus aucuparia with key 3012167 occurs in 6329 km squares.
# Nicotiana tabacum with key 2928774 occurs in 16 km squares.
# Fragaria ananassa with key 3029912 occurs in 71 km squares.
# Sorghum bicolor with key 2705181 occurs in 51 km squares.
# Carthamus tinctorius with key 3138327 occurs in 63 km squares.
# Secale cereale with key 2705966 occurs in 60 km squares.
# Allium cepa with key 2857697 occurs in 16 km squares.
# Avena sativa with key 2705290 occurs in 235 km squares.
# Lens culinaris with key 5350010 occurs in 9 km squares.
# Anemone coronaria with key 3033261 occurs in 9 km squares.
# Hordeum vulgare with key 2706056 occurs in 222 km squares.
# Phaseolus vulgaris with key 5350452 occurs in 6 km squares.
# Juglans nigra with key 3054357 occurs in 98 km squares.
# Apium graveolens with key 5371879 occurs in 259 km squares.
# Zea mays with key 5290052 occurs in 173 km squares.
# Phoenix dactylifera with key 6109699 occurs in 17 km squares.
# Juglans regia with key 3054368 occurs in 3582 km squares.
# Linum usitatissimum with key 2873861 occurs in 860 km squares.
# Cannabis sativa with key 5361880 occurs in 208 km squares.
# Syngnathus acus with key 2332927 occurs in 104 km squares.
# Pimephales promelas with key 2367742 occurs in 29 km squares.
# Lampetra fluviatilis with key 2421365 occurs in 39 km squares.
# Cottus gobio with key 7807208 occurs in 135 km squares.
# Gasterosteus aculeatus with key 4286327 occurs in 2396 km squares.
# Trachurus trachurus with key 5210473 occurs in 228 km squares.
# Neogobius melanostomus with key 2379089 occurs in 210 km squares.
# Pomatoschistus microps with key 2379280 occurs in 146 km squares.
# Pomatoschistus minutus with key 2379300 occurs in 477 km squares.
# Pleuronectes platessa with key 7700106 occurs in 530 km squares.
# Limanda limanda with key 5213960 occurs in 466 km squares.
# Sander lucioperca with key 2382155 occurs in 617 km squares.
# Pholis gunnellus with key 5210421 occurs in 45 km squares.
# Osmerus eperlanus with key 2410854 occurs in 229 km squares.
# Zoarces viviparus with key 2381013 occurs in 35 km squares.
# Carassius auratus with key 4286942 occurs in 92 km squares.
# Pungitius pungitius with key 5739510 occurs in 1777 km squares.
# Pseudorasbora parva with key 2362868 occurs in 960 km squares.
# Oncorhynchus mykiss with key 5204019 occurs in 82 km squares.
# Cyprinus carpio with key 4286975 occurs in 1485 km squares.
# Barbatula barbatula with key 5204862 occurs in 889 km squares.
# Misgurnus fossilis with key 2367936 occurs in 10 km squares.
# Perca fluviatilis with key 8140485 occurs in 2032 km squares.
# Lota lota with key 2415460 occurs in 62 km squares.
# Scomber scombrus with key 2374149 occurs in 39 km squares.
# Ctenopharyngodon idella with key 2362030 occurs in 79 km squares.
# Mola mola with key 5213725 occurs in 7 km squares.
# Gadus morhua with key 8084280 occurs in 232 km squares.
# Cyclopterus lumpus with key 5962255 occurs in 16 km squares.
# Ammodytes tobianus with key 2389991 occurs in 341 km squares.
# Anguilla anguilla with key 5212973 occurs in 1834 km squares.
# Chelon labrosus with key 2400863 occurs in 79 km squares.
# Dicentrarchus labrax with key 2394622 occurs in 282 km squares.
# Merlangius merlangus with key 2415788 occurs in 420 km squares.
# Trisopterus luscus with key 2415916 occurs in 207 km squares.
# Taurulus bubalis with key 2334227 occurs in 27 km squares.
# Trisopterus minutus with key 2415906 occurs in 83 km squares.
# Sprattus sprattus with key 2413452 occurs in 368 km squares.
# Microstomus kitt with key 5214022 occurs in 125 km squares.
# Scophthalmus rhombus with key 2409403 occurs in 128 km squares.
# Solea solea with key 5214139 occurs in 507 km squares.
# Callionymus lyra with key 2386906 occurs in 323 km squares.
# Belone belone with key 2369178 occurs in 20 km squares.
# Scophthalmus maximus with key 2409418 occurs in 164 km squares.
# Hyperoplus lanceolatus with key 2390014 occurs in 277 km squares.
# Leuciscus leuciscus with key 4409641 occurs in 190 km squares.
# Leucaspius delineatus with key 2362881 occurs in 329 km squares.
# Centropages hamatus with key 2114723 occurs in 64 km squares.
# Sterna paradisaea with key 5229230 occurs in 697 km squares.
# Ensis ensis with key 2287248 occurs in 7 km squares.
# Limnodrilus hoffmeisteri with key 2308543 occurs in 7 km squares.
# Pleurobrachia pileus with key 2501136 occurs in 52 km squares.
# Mnemiopsis leidyi with key 2501248 occurs in 52 km squares.
# Sepiola atlantica with key 2289177 occurs in 248 km squares.
# Loligo vulgaris with key 2290374 occurs in 192 km squares.
# Sepia officinalis with key 2290849 occurs in 141 km squares.
# Alloteuthis subulata with key 2290388 occurs in 188 km squares.
# Ruditapes philippinarum with key 4372686 occurs in 32 km squares.
# Stercorarius pomarinus with key 2481609 occurs in 371 km squares.
# Mytilus edulis with key 8288896 occurs in 249 km squares.
# Mentha verticillata with key 8172952 occurs in 48 km squares.

# %%
# Convert to a Pandas dataframe
taxaFoundInCountry = pd.DataFrame(taxaFoundInCountry)

# %%
print("The number of species left in the network is {0}".format(len(taxaFoundInCountry)))
# Out:
# The number of species left in the network is 541

# %%
taxaFoundInCountry
# Out:
#      count      key                    species
# 0       14  5218465  Pipistrellus pipistrellus
# 1        9  2432389           Myotis nattereri
# 2        6  5218507           Plecotus auritus
# 3        6  2432439          Myotis daubentoni
# 4     3386  2498326         Bucephala clangula
# 5       59  2498257             Aythya affinis
# 6      192  2498264            Aythya collaris
# 7      177  2498073               Anas discors
# 8      366  8351946            Clupea harengus
# 9     6797  3146791        Erigeron canadensis
# 10      10  3040232          Populus deltoides
# 11    1387  5392252          Cichorium intybus
# 12    1527  3040233               Populus alba
# 13     311  8313153          Quercus palustris
# 14    1720  8591421          Potentilla indica
# 15       7  2437619       Dolichotis patagonum
# 16   11316  5232437          Branta canadensis
# 17     501  2409330         Platichthys flesus
# 18     181  2333785     Myoxocephalus scorpius
# 19    9729  7982160                Larus canus
# 20    6031  2481714             Tringa totanus
# 21    1642  2480327       Pluvialis squatarola
# 22    3252  9566659       Charadrius hiaticula
# 23   10448  7788295      Haematopus ostralegus
# 24       8  2316416       Hediste diversicolor
# 25     186  5192789        Crepidula fornicata
# 26      29  5229247            Sterna forsteri
# 27     103  2481134         Larus delawarensis
# 28   11216  2481139           Larus argentatus
# 29      85  2498408      Lophodytes cucullatus
# ..     ...      ...                        ...
# 511     79  2400863            Chelon labrosus
# 512    282  2394622       Dicentrarchus labrax
# 513    420  2415788       Merlangius merlangus
# 514    207  2415916         Trisopterus luscus
# 515     27  2334227           Taurulus bubalis
# 516     83  2415906        Trisopterus minutus
# 517    368  2413452          Sprattus sprattus
# 518    125  5214022           Microstomus kitt
# 519    128  2409403       Scophthalmus rhombus
# 520    507  5214139                Solea solea
# 521    323  2386906           Callionymus lyra
# 522     20  2369178              Belone belone
# 523    164  2409418       Scophthalmus maximus
# 524    277  2390014     Hyperoplus lanceolatus
# 525    190  4409641        Leuciscus leuciscus
# 526    329  2362881      Leucaspius delineatus
# 527     64  2114723        Centropages hamatus
# 528    697  5229230          Sterna paradisaea
# 529      7  2287248                Ensis ensis
# 530      7  2308543   Limnodrilus hoffmeisteri
# 531     52  2501136       Pleurobrachia pileus
# 532     52  2501248          Mnemiopsis leidyi
# 533    248  2289177          Sepiola atlantica
# 534    192  2290374            Loligo vulgaris
# 535    141  2290849          Sepia officinalis
# 536    188  2290388       Alloteuthis subulata
# 537     32  4372686    Ruditapes philippinarum
# 538    371  2481609     Stercorarius pomarinus
# 539    249  8288896             Mytilus edulis
# 540     48  8172952        Mentha verticillata
#
# [541 rows x 3 columns]

# %% [markdown]
# ## Drawing a network of the interactions
#
# Now that I have a list of all the species in the country I can use this as my nodes list for the network diagram.

# %%
#networkx seems to be a leading network tool in Python
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create graphic object
G = nx.DiGraph()

# %%
# Match colours to interactions to distinguish them on the graph
colorInteractions = {'interaction':['pollinates', 'mutualistOf', 'eats', 'visitsFlowersOf', 'hasHost', 'parasiteOf', 'pathogenOf'],
        'colour':['r', 'g', 'b', 'y', 'm', 'w', 'c']}  

colorInteractionsDf = pd.DataFrame(colorInteractions)

#len(list(G.nodes))

# %% [markdown]
# ## A quick look at the interaction data to see if it is what is expected

# %%
#cleanInteractDataTaxon.loc[(cleanInteractDataTaxon["sourceTaxonName"] == 'Apis mellifera') & (cleanInteractDataTaxon["targetTaxonName"] == 'Procyon lotor')]
cleanInteractDataTaxon.loc[(cleanInteractDataTaxon["targetTaxonName"] == 'Sonchus tenerrimus')]
# Out:
# Empty DataFrame
# Columns: [sourceTaxonId, sourceTaxonName, sourceTaxonRank, sourceTaxonFamilyName, interactionTypeName, targetTaxonName, targetTaxonRank, sourceCitation, sourceDOI]
# Index: []

# %% [markdown]
# ## Figure out which node has the most records. This is so that the graphic can be scaled.

# %%
if len(taxaFoundInCountry) > 0:
    maxRecords = taxaFoundInCountry.max()["count"]
    print(maxRecords)
# Out:
# 15535

# %% [markdown]
# ### Add the nodes to the graph

# %%
dictOfNodeSizes = {}

for index, row in taxaFoundInCountry.iterrows():
     # access data using column names
    print('A: ', row['species'], row['count'], row['key'])
    G.add_node(row['species'], gbifkey=row['key'])
    dictOfNodeSizes[row['species']] = int(row['count']/maxRecords*100)
# Out:
# A:  Pipistrellus pipistrellus 14 5218465
# A:  Myotis nattereri 9 2432389
# A:  Plecotus auritus 6 5218507
# A:  Myotis daubentoni 6 2432439
# A:  Bucephala clangula 3386 2498326
# A:  Aythya affinis 59 2498257
# A:  Aythya collaris 192 2498264
# A:  Anas discors 177 2498073
# A:  Clupea harengus 366 8351946
# A:  Erigeron canadensis 6797 3146791
# A:  Populus deltoides 10 3040232
# A:  Cichorium intybus 1387 5392252
# A:  Populus alba 1527 3040233
# A:  Quercus palustris 311 8313153
# A:  Potentilla indica 1720 8591421
# A:  Dolichotis patagonum 7 2437619
# A:  Branta canadensis 11316 5232437
# A:  Platichthys flesus 501 2409330
# A:  Myoxocephalus scorpius 181 2333785
# A:  Larus canus 9729 7982160
# A:  Tringa totanus 6031 2481714
# A:  Pluvialis squatarola 1642 2480327
# A:  Charadrius hiaticula 3252 9566659
# A:  Haematopus ostralegus 10448 7788295
# A:  Hediste diversicolor 8 2316416
# A:  Crepidula fornicata 186 5192789
# A:  Sterna forsteri 29 5229247
# A:  Larus delawarensis 103 2481134
# A:  Larus argentatus 11216 2481139
# A:  Lophodytes cucullatus 85 2498408
# A:  Circus cyaneus 8469 2480487
# A:  Zoarces viviparus 35 2381013
# A:  Carassius auratus 92 4286942
# A:  Pungitius pungitius 1777 5739510
# A:  Pseudorasbora parva 960 2362868
# A:  Oncorhynchus mykiss 82 5204019
# A:  Cyprinus carpio 1485 4286975
# A:  Barbatula barbatula 889 5204862
# A:  Misgurnus fossilis 10 2367936
# A:  Perca fluviatilis 2032 8140485
# A:  Lota lota 62 2415460
# A:  Scomber scombrus 39 2374149
# A:  Ctenopharyngodon idella 79 2362030
# A:  Mola mola 7 5213725
# A:  Gadus morhua 232 8084280
# A:  Cyclopterus lumpus 16 5962255
# A:  Ammodytes tobianus 341 2389991
# A:  Anguilla anguilla 1834 5212973
# A:  Chelon labrosus 79 2400863
# A:  Dicentrarchus labrax 282 2394622
# A:  Merlangius merlangus 420 2415788
# A:  Trisopterus luscus 207 2415916
# A:  Taurulus bubalis 27 2334227
# A:  Trisopterus minutus 83 2415906
# A:  Sprattus sprattus 368 2413452
# A:  Microstomus kitt 125 5214022
# A:  Scophthalmus rhombus 128 2409403
# A:  Solea solea 507 5214139
# A:  Callionymus lyra 323 2386906
# A:  Belone belone 20 2369178
# A:  Scophthalmus maximus 164 2409418
# A:  Hyperoplus lanceolatus 277 2390014
# A:  Leuciscus leuciscus 190 4409641
# A:  Leucaspius delineatus 329 2362881
# A:  Centropages hamatus 64 2114723
# A:  Sterna paradisaea 697 5229230
# A:  Ensis ensis 7 2287248
# A:  Limnodrilus hoffmeisteri 7 2308543
# A:  Pleurobrachia pileus 52 2501136
# A:  Mnemiopsis leidyi 52 2501248
# A:  Sepiola atlantica 248 2289177
# A:  Loligo vulgaris 192 2290374
# A:  Sepia officinalis 141 2290849
# A:  Alloteuthis subulata 188 2290388
# A:  Ruditapes philippinarum 32 4372686
# A:  Stercorarius pomarinus 371 2481609
# A:  Mytilus edulis 249 8288896
# A:  Mentha verticillata 48 8172952

# %% [markdown]
# ### Add edges to the graph

# %%
# iterate over the interacting species that are in GBIF and in the country with iterrows()

taxaFoundInCountry_copy = taxaFoundInCountry.copy()

for index, row in taxaFoundInCountry.iterrows():
    # loop over all the taxa finding if any of them are mentioned in the sourceTaxonName field
    for edge in cleanInteractDataTaxon.iterrows():
        if row['species'] == edge[1]['sourceTaxonName']:
            #print('B: ', edge[1]['sourceTaxonName'], edge[1]['targetTaxonName'])
            # Some of the target species will not be in GBIF of in the country, so only add an edge where they are.
            for index2, row2 in taxaFoundInCountry_copy.iterrows():
                #print('E: ', row2['species'], edge[1]['targetTaxonName'])
                if (row2['species']).strip() == (edge[1]['targetTaxonName']).strip(): 
                    print('C: ', edge[1]['targetTaxonName'], edge[1]['sourceTaxonName'], row2['species'])
                    G.add_edge(edge[1]['targetTaxonName'], row2['species'], label = edge[1]['interactionTypeName'])
                    
#len(list(G.nodes))
# Out:
# C:  Pipistrellus pipistrellus Pipistrellus pipistrellus Pipistrellus pipistrellus
# C:  Pipistrellus pipistrellus Pipistrellus pipistrellus Pipistrellus pipistrellus
# C:  Pipistrellus pipistrellus Pipistrellus pipistrellus Pipistrellus pipistrellus

# F:  no name Callionymus lyra
# F:  no name Callionymus lyra
# F:  no name Belone belone
# F:  no name Scophthalmus maximus
# F:  no name Hyperoplus lanceolatus
# F:  no name Leuciscus leuciscus
# F:  no name Leuciscus leuciscus
# F:  no name Leuciscus leuciscus
# F:  no name Leuciscus leuciscus
# F:  no name Leuciscus leuciscus
# F:  no name Leuciscus leuciscus
# F:  no name Leucaspius delineatus
# F:  no name Leucaspius delineatus
# F:  no name Leucaspius delineatus
# F:  no name Centropages hamatus
# F:  no name Sterna paradisaea
# F:  no name Ensis ensis
# F:  no name Limnodrilus hoffmeisteri
# F:  no name Pleurobrachia pileus
# F:  no name Mnemiopsis leidyi
# F:  no name Sepiola atlantica
# F:  no name Loligo vulgaris
# F:  no name Sepia officinalis
# F:  no name Sepia officinalis
# F:  no name Sepia officinalis
# F:  no name Sepia officinalis
# F:  no name Alloteuthis subulata
# F:  no name Ruditapes philippinarum
# F:  no name Ruditapes philippinarum
# F:  no name Stercorarius pomarinus
# F:  no name Mytilus edulis
# F:  no name Mentha verticillata

# %%
print("Number of nodes = {0}".format(G.number_of_nodes()))
print("Number of edges = {0}".format(G.number_of_edges()))
# Out:
# Number of nodes = 568
# Number of edges = 245

# %%
len(dictOfNodeSizes)
# Out:
# 568

# %% [markdown]
# ## Remove any nodes that have no edges.
# This happens because some of the linking nodes have few supporting observations and so have been weeded out

# %%
#for n in G.nodes:
#    if G.degree(n) == 0:
#        G.remove_node(n)
        
G.remove_nodes_from(list(nx.isolates(G)))

# %%
len(G.nodes)
# Out:
# 227

# %% [markdown]
# ## Remove any selfloop edges

# %%
for e in G.selfloop_edges(data=False):
    G.remove_edge(e[0],e[1])

# %% [markdown]
# ## Run through the list of nodes again and construct a list of the node sizes in the correct order

# %%
listOfNodeSizes = []

for node in G.nodes:
    listOfNodeSizes.append(dictOfNodeSizes[node])

# %% [markdown]
# ## A network of all the interacting taxa

# %%
plt.figure(figsize=(15,15))
edge_labels = nx.get_edge_attributes(G,'label')

pos = nx.spring_layout(G, iterations=50, k=50) 
#pos = nx.spring_layout(G)
#pos = nx.random_layout(G)
#pos = nx.circular_layout(G)
#pos = nx.spectral_layout(G)
#pos = nx.shell_layout(G, scale=1)

nodeColors = nx.get_node_attributes(G,'color')

nx.draw_networkx_edge_labels(G,pos, edge_labels = edge_labels, font_size=10, font_color='blue')

#nx.draw_networkx_nodes(G, pos, node_color=nodeColors.values())

nx.draw_networkx(G, pos, with_labels=True, node_size = listOfNodeSizes, node_color='c', alpha= 1, arrows=True, 
                    linewidths=1, font_color="black", font_size=10, style = 'dashed')

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
with open(taxon+country+".html", "w") as file:
    file.write(" \
<!DOCTYPE html> \
<html> \
<head> \
<script src='../../../GitHub\cytoscape.js\dist\cytoscape.min.js'></script> \
<script src='https://unpkg.com/layout-base/layout-base.js'></script> \
<script src='https://unpkg.com/cose-base/cose-base.js'></script> \
<script src='../../../GitHub\cytoscape.js-cose-bilkent\cytoscape-cose-bilkent.js'></script> \
</head> \
<style>#cy {width: 90%; height: 90%; position: absolute; top: 50px; left: 150px;}\
body {font-family: 'times; font-size: 6px;}\
</style> \
<body> \
<h1><em font-style: italic;>"+taxon+"</em> in "+country+"</h1>")

# %% [markdown]
# ### Write out the details of the species

# %%
with open(taxon+country+".html", "a") as file:
    file.write("<table><th>Species</th><th>Occupancy</th>")

# %%
species = G.nodes
with open(taxon+country+".html", "a") as file:
    for n in species:
        file.write("<tr><td><a target='_blank' href=https://www.gbif.org/species/"+str(nx.get_node_attributes(G, 'gbifkey')[n])+">"+n+"</a></td><td>"+str(dictOfNodeSizes[n])+"</td>\n")
        #file.write("<a href=https://www.gbif.org/species/"+str(nx.get_node_attributes(G, 'gbifkey')[n])+">"+n+"</a>, "+str(dictOfNodeSizes[n])+"\n")

# %%
with open(taxon+country+".html", "a") as file:
    file.write("</table>")    
file.close()

# %%
with open(taxon+country+".html", "a") as file:
    file.write(" \
<div id='cy'></div> \
<script> \
var cy = cytoscape({ \
  container: document.getElementById('cy'), \n \
  elements: [ \
")

# %% [markdown]
# ### Write nodes to file

# %%
file = open(taxon+country+".html", "a")
for n in species:
    file.write("{ data: { id: '"+n+"', href: 'https://www.gbif.org/species/"+str(nx.get_node_attributes(G, 'gbifkey')[n])+"', occnum: "+str(dictOfNodeSizes[n])+" }, },\n")
file.close()

# %% [markdown]
# ### Write edges to file

# %%
file = open(taxon+country+".html", "a")
for edge in G.edges:
    file.write("{data: {id: '"+edge[0]+edge[1]+"', source: '"+edge[0]+"', target: '"+edge[1]+"', label: '"+nx.get_edge_attributes(G, 'label')[edge]+"'}},\n")
file.close()

# %%
with open(taxon+country+".html", "a") as file:
    file.write("], \
style: [ \n\
        { \n\
            selector: 'node', \n\
            style: { \n\
                shape: 'circle', \n\
                'background-color': 'darkgreen', \n\
                label: 'data(id)', \n\
                'font-family': 'helvetica', \n\
                'font-style': 'italic', \n\
                'font-size': '12px', \n\
                'width': 'mapData(occnum, 0, 400, 3, 150)', \n\
                'height': 'mapData(occnum, 0, 400, 3, 150)' \n\
            } \n\
        },  \n\
        {  \n\
            selector: 'edge',  \n\
            style: {  \n\
                label: 'data(label)', \n\
                'font-family': 'helvetica', \n\
                'font-size': '12px', \n\
                'color': 'blue', \n\
                'curve-style': 'bezier', \n\
                'target-arrow-shape': 'triangle',  \n\
                'width': '1' \n\
                } \n\
            },  \n\
            {  \n\
              selector: ':selected',   \n\
              css: {  \n\
                'line-color': 'red',  \n\
                'background-color': 'red'  \n\
            }  \n\
        }], \n\
layout:  { \n\
            name: 'circle', padding: 10, animate: true, gravity: 30, animationDuration: 1000 \n\
     } \n\
} \n\
); \n\
cy.userZoomingEnabled( true ); \n\
</script> \n\
")

# %%
with open(taxon+country+".html", "a") as file:
    file.write("<h2>References</h2><ul>\n")

# %%
citations = cleanInteractDataTaxon['sourceCitation'].unique()
file = open(taxon+country+".html", "a")
for ref in citations:
    file.write("<li>"+str(ref)+"</li>\n")
file.close()

# %%
with open(taxon+country+".html", "a") as file:
    file.write("</ul> \
        </body> \
        </html>")
