# %% [markdown]
# # Interactias
#
# The impact that invasive species have on other biodiversity is largely to do with the interactions the invasive species has on the local species. Invasive species can predate or parasitize, they can disrupte pollination networks, they can compete with local species for different resources and many other types of interaction.
#
# Nevertheless, while much of the research on IAS is related to modelling spread and distribution, interactions are not as easy to study. Species interactions can happen very quickly, but have large consequences for the actors e.g. predation. They can happen only rarely, or a certain times of the day or season. Interactions are also difficult to quantify with relation to the impact on the interacting organisms.
#
# The aim of this notebook is to try to quantify the actual or potential impact of an invasive species through our knowledge of its interactions and the abundance of its actors.
#
# I will harvest species interactions data from GLOBI (https://www.globalbioticinteractions.org/) to discover the species that interact with an invasive species. I will then compare these interactions with the occupancy of the interacting species in a particular area.
#
# This notebook takes considerable insperation and code from Yikang Li's project on GLoBI (https://curiositydata.org/part1_globi_access/).

# %%
import pandas as pd
#import pytaxize
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the GLoBI data
#
# The current snapshot of GLoBI was taken on 2019-11-05 from https://depot.globalbioticinteractions.org/snapshot/target/data/tsv/interactions.tsv.gz

# %%
# This takes a few minutes to load in.
# the low_memory=False property will get rid of a warning, but will not help if there is really no memory left
data = pd.read_csv('../data/interactions.tsv', delimiter='\t', encoding='utf-8', low_memory=False)
len(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b9022b7da374> in <module>
#       1 # This takes a few minutes to load in.
#       2 # the low_memory=False property will get rid of a warning, but will not help if there is really no memory left
# ----> 3 data = pd.read_csv('../data/interactions.tsv', delimiter='\t', encoding='utf-8', low_memory=False)
#       4 len(data)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../data/interactions.tsv' does not exist: b'../data/interactions.tsv'

# %%
# Take a little look at the data to make sure it makes sense
data.head()
# Out:
#   sourceTaxonId                                     sourceTaxonIds  \
# 0  EOL:12001247  EOL:12001247 | OTT:133330 | IRMNG:11733708 | N...
# 1  EOL:12001247  EOL:12001247 | OTT:133330 | IRMNG:11733708 | N...
# 2  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
# 3  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
# 4  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
#
#              sourceTaxonName sourceTaxonRank  \
# 0       Leptoconchus massini         species
# 1       Leptoconchus massini         species
# 2  Leptoconchus inpleuractis         species
# 3  Leptoconchus inpleuractis         species
# 4  Leptoconchus inpleuractis         species
#
#                                 sourceTaxonPathNames  \
# 0  Animalia | Mollusca | Gastropoda | Neogastropo...
# 1  Animalia | Mollusca | Gastropoda | Neogastropo...
# 2  Animalia | Mollusca | Gastropoda | Neogastropo...
# 3  Animalia | Mollusca | Gastropoda | Neogastropo...
# 4  Animalia | Mollusca | Gastropoda | Neogastropo...
#
#                                   sourceTaxonPathIds  \
# 0  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 1  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 2  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 3  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 4  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
#
#                             sourceTaxonPathRankNames  \
# 0  kingdom | phylum | class | order | superfamily...
# 1  kingdom | phylum | class | order | superfamily...
# 2  kingdom | phylum | class | order | superfamily...
# 3  kingdom | phylum | class | order | superfamily...
# 4  kingdom | phylum | class | order | superfamily...
#
#       sourceTaxonSpeciesName sourceTaxonSpeciesId sourceTaxonGenusName  ...  \
# 0       Leptoconchus massini         EOL:12001247         Leptoconchus  ...
# 1       Leptoconchus massini         EOL:12001247         Leptoconchus  ...
# 2  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
# 3  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
# 4  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
#
#   eventDateUnixEpoch                          argumentTypeId  \
# 0                NaN  https://en.wiktionary.org/wiki/support
# 1                NaN  https://en.wiktionary.org/wiki/support
# 2                NaN  https://en.wiktionary.org/wiki/support
# 3                NaN  https://en.wiktionary.org/wiki/support
# 4                NaN  https://en.wiktionary.org/wiki/support
#
#                                    referenceCitation  \
# 0  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 1  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 2  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 3  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 4  Gittenberger, A., Gittenberger, E. (2011). Cry...
#
#                 referenceDoi referenceUrl  \
# 0  10.1007/s13127-011-0039-1          NaN
# 1  10.1007/s13127-011-0039-1          NaN
# 2  10.1007/s13127-011-0039-1          NaN
# 3  10.1007/s13127-011-0039-1          NaN
# 4  10.1007/s13127-011-0039-1          NaN
#
#                                       sourceCitation  \
# 0  Jorrit H. Poelen. 2014. Species associations m...
# 1  Jorrit H. Poelen. 2014. Species associations m...
# 2  Jorrit H. Poelen. 2014. Species associations m...
# 3  Jorrit H. Poelen. 2014. Species associations m...
# 4  Jorrit H. Poelen. 2014. Species associations m...
#
#                  sourceNamespace  \
# 0  FloraVincent/template-dataset
# 1  FloraVincent/template-dataset
# 2  FloraVincent/template-dataset
# 3  FloraVincent/template-dataset
# 4  FloraVincent/template-dataset
#
#                                     sourceArchiveURI sourceDOI  \
# 0  https://github.com/FloraVincent/template-datas...       NaN
# 1  https://github.com/FloraVincent/template-datas...       NaN
# 2  https://github.com/FloraVincent/template-datas...       NaN
# 3  https://github.com/FloraVincent/template-datas...       NaN
# 4  https://github.com/FloraVincent/template-datas...       NaN
#
#   sourceLastSeenAtUnixEpoch
# 0  2019-03-30T23:08:44.205Z
# 1  2019-03-30T23:08:44.205Z
# 2  2019-03-30T23:08:44.205Z
# 3  2019-03-30T23:08:44.205Z
# 4  2019-03-30T23:08:44.205Z
#
# [5 rows x 80 columns]

# %%
# List all the interaction types
data['interactionTypeName'].unique()
# Out:
# array(['parasiteOf', 'symbiontOf', 'commensalistOf', 'mutualistOf',
#        'eats', 'interactsWith', 'hasHost', 'pathogenOf', 'preysOn',
#        'pollinates', 'coOccursWith', 'visitsFlowersOf', 'adjacentTo',
#        'dispersalVectorOf', 'endoparasitoidOf', 'endoparasiteOf',
#        'hasVector', 'ectoParasiteOf', 'livesOn', 'livesNear',
#        'parasitoidOf', 'guestOf', 'livesInsideOf', 'farms',
#        'ectoParasitoid', 'inhabits', 'kills', 'hasDispersalVector',
#        'livesUnder', 'kleptoparasiteOf', 'laysEggsOn', 'visits',
#        'ecologicallyRelatedTo'], dtype=object)

# %% [markdown]
# ## Drop duplicates
#
# This line gets rid of duplicate interations. I currently can't see a reason to keep them, but this perhaps should be checked.
# Some more common interactions might have more support in the literature and therefore more records. Deduplicating them tends to equal out rare interactions with common ones.

# %%
data.drop_duplicates(['sourceTaxonId', 'interactionTypeName', 'targetTaxonId'], inplace = True)

# %%
## Chech how mant rows are left
len(data)
# Out:
# 1101736

# %% [markdown]
# Define the key taxon for the notebook for which to find all interactions

# %%
#taxon = "Oxalis pes-caprae"
#taxon = "Lantana camara"
taxon = "Cirsium vulgare"

# %%
# What are all the types of interactions involving Oxalis pes-caprae as source taxon?
data[data['sourceTaxonName'] == taxon]['interactionTypeName'].unique()
# Out:
# array(['interactsWith', 'visitsFlowersOf'], dtype=object)

# %%
# What are all the types of interactions involving Oxalis pes-caprae as target taxon?
data[data['targetTaxonName'] == taxon]['interactionTypeName'].unique()
# Out:
# array(['interactsWith', 'eats', 'visitsFlowersOf', 'hasHost',
#        'parasiteOf', 'livesInsideOf', 'preysOn', 'pollinates'],
#       dtype=object)

# %% [markdown]
# How many taxon sources do I have?

# %%
len(data[data['sourceTaxonName'] == taxon])
# Out:
# 130

# %% [markdown]
# How many taxon targets do I have?

# %%
len(data[data['targetTaxonName'] == taxon])
# Out:
# 338

# %% [markdown]
# Gather together all the data where the target is the taxon in question.

# %%
interacts_data = data[(data['targetTaxonName'] == taxon)]

# %%
interacts_data.head()
# Out:
#          sourceTaxonId                                     sourceTaxonIds  \
# 117947     EOL:6447088  EOL:6447088 | OTT:138038 | GBIF:3483411 | GBIF...
# 117948     EOL:4095553  EOL:4095553 | OTT:144679 | GBIF:5137800 | EOL:...
# 117949  EOL_V2:3639930  EOL_V2:3639930 | NBN:NBNSYS0000006982 | WD:Q27...
# 117950     EOL:2742935  EOL:2742935 | OTT:487756 | ITIS:757769 | NCBI:...
# 117951  EOL_V2:2668031  EOL_V2:2668031 | EOL_V2:2668031 | IRMNG:110385...
#
#                     sourceTaxonName sourceTaxonRank  \
# 117947  Golovinomyces cichoracearum         species
# 117948             Pontia protodice         species
# 117949             Cheilosia grossa         species
# 117950             Halictus ligatus         species
# 117951          Rhinocyllus conicus         species
#
#                                      sourceTaxonPathNames  \
# 117947  Fungi | Ascomycota | Leotiomycetes | Erysiphal...
# 117948  Animalia | Arthropoda | Insecta | Lepidoptera ...
# 117949  Cellular organisms | Eukaryota | Opisthokonta ...
# 117950  Animalia | Arthropoda | Insecta | Hymenoptera ...
# 117951  Animalia | Bilateria | Protostomia | Ecdysozoa...
#
#                                        sourceTaxonPathIds  \
# 117947  EOL_V2:5559 | EOL:5577 | EOL:2861056 | EOL:562...
# 117948  EOL:1 | EOL:164 | EOL:344 | EOL:747 | EOL:854 ...
# 117949  EOL:6061725 | EOL:2908256 | EOL:2910700 | EOL:...
# 117950  EOL:1 | EOL:164 | EOL:344 | EOL:648 | EOL:676 ...
# 117951  EOL:1 | EOL:3014411 | EOL:10459935 | EOL:88807...
#
#                                  sourceTaxonPathRankNames  \
# 117947  kingdom | phylum | class | order | family | ge...
# 117948  kingdom | phylum | class | order | superfamily...
# 117949  |  |  | kingdom |  |  |  |  |  | phylum |  |  ...
# 117950  kingdom | phylum | class | order | superfamily...
# 117951  kingdom | subkingdom | infrakingdom | superphy...
#
#              sourceTaxonSpeciesName sourceTaxonSpeciesId sourceTaxonGenusName  \
# 117947  Golovinomyces cichoracearum          EOL:6447088        Golovinomyces
# 117948             Pontia protodice          EOL:4095553               Pontia
# 117949             Cheilosia grossa       EOL_V2:3639930            Cheilosia
# 117950             Halictus ligatus          EOL:2742935             Halictus
# 117951          Rhinocyllus conicus       EOL_V2:2668031          Rhinocyllus
#
#         ... eventDateUnixEpoch                          argumentTypeId  \
# 117947  ...                NaN  https://en.wiktionary.org/wiki/support
# 117948  ...                NaN  https://en.wiktionary.org/wiki/support
# 117949  ...                NaN  https://en.wiktionary.org/wiki/support
# 117950  ...                NaN  https://en.wiktionary.org/wiki/support
# 117951  ...                NaN  https://en.wiktionary.org/wiki/support
#
#                                         referenceCitation referenceDoi  \
# 117947  A. Thessen. 2014. Species associations extract...          NaN
# 117948  A. Thessen. 2014. Species associations extract...          NaN
# 117949  A. Thessen. 2014. Species associations extract...          NaN
# 117950  A. Thessen. 2014. Species associations extract...          NaN
# 117951  A. Thessen. 2014. Species associations extract...          NaN
#
#        referenceUrl                                     sourceCitation  \
# 117947          NaN  A. Thessen. 2014. Species associations extract...
# 117948          NaN  A. Thessen. 2014. Species associations extract...
# 117949          NaN  A. Thessen. 2014. Species associations extract...
# 117950          NaN  A. Thessen. 2014. Species associations extract...
# 117951          NaN  A. Thessen. 2014. Species associations extract...
#
#                 sourceNamespace  \
# 117947  Bhanditz/pseudonitzchia
# 117948  Bhanditz/pseudonitzchia
# 117949  Bhanditz/pseudonitzchia
# 117950  Bhanditz/pseudonitzchia
# 117951  Bhanditz/pseudonitzchia
#
#                                          sourceArchiveURI sourceDOI  \
# 117947  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
# 117948  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
# 117949  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
# 117950  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
# 117951  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
#
#        sourceLastSeenAtUnixEpoch
# 117947  2019-11-02T23:25:50.260Z
# 117948  2019-11-02T23:25:50.260Z
# 117949  2019-11-02T23:25:50.260Z
# 117950  2019-11-02T23:25:50.260Z
# 117951  2019-11-02T23:25:50.260Z
#
# [5 rows x 80 columns]

# %%
# What are the columns of this dataset?
data.columns
# Out:
# Index(['sourceTaxonId', 'sourceTaxonIds', 'sourceTaxonName', 'sourceTaxonRank',
#        'sourceTaxonPathNames', 'sourceTaxonPathIds',
#        'sourceTaxonPathRankNames', 'sourceTaxonSpeciesName',
#        'sourceTaxonSpeciesId', 'sourceTaxonGenusName', 'sourceTaxonGenusId',
#        'sourceTaxonFamilyName', 'sourceTaxonFamilyId', 'sourceTaxonOrderName',
#        'sourceTaxonOrderId', 'sourceTaxonClassName', 'sourceTaxonClassId',
#        'sourceTaxonPhylumName', 'sourceTaxonPhylumId',
#        'sourceTaxonKingdomName', 'sourceTaxonKingdomId', 'sourceId',
#        'sourceOccurrenceId', 'sourceCatalogNumber', 'sourceBasisOfRecordId',
#        'sourceBasisOfRecordName', 'sourceLifeStageId', 'sourceLifeStageName',
#        'sourceBodyPartId', 'sourceBodyPartName', 'sourcePhysiologicalStateId',
#        'sourcePhysiologicalStateName', 'interactionTypeName',
#        'interactionTypeId', 'targetTaxonId', 'targetTaxonIds',
#        'targetTaxonName', 'targetTaxonRank', 'targetTaxonPathNames',
#        'targetTaxonPathIds', 'targetTaxonPathRankNames',
#        'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
#        'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
#        'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
#        'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
#        'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId',
#        'targetId', 'targetOccurrenceId', 'targetCatalogNumber',
#        'targetBasisOfRecordId', 'targetBasisOfRecordName', 'targetLifeStageId',
#        'targetLifeStageName', 'targetBodyPartId', 'targetBodyPartName',
#        'targetPhysiologicalStateId', 'targetPhysiologicalStateName',
#        'decimalLatitude', 'decimalLongitude', 'localityId', 'localityName',
#        'eventDateUnixEpoch', 'argumentTypeId', 'referenceCitation',
#        'referenceDoi', 'referenceUrl', 'sourceCitation', 'sourceNamespace',
#        'sourceArchiveURI', 'sourceDOI', 'sourceLastSeenAtUnixEpoch'],
#       dtype='object')

# %% [markdown]
# Simplify the table to make it readable

# %%
interacts_data = interacts_data[['sourceTaxonId', 'sourceTaxonName', 'sourceTaxonRank',
       'sourceTaxonPathNames', 'sourceTaxonFamilyName', 'interactionTypeName',
       'interactionTypeId', 'targetTaxonId',
       'targetTaxonName','targetTaxonPathNames',
       'targetTaxonPathIds', 'targetTaxonPathRankNames',
       'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
       'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
       'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
       'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
       'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId', 'referenceDoi', 'decimalLatitude', 'decimalLongitude'
        ]].dropna(subset=['targetTaxonId', 'targetTaxonName','targetTaxonPathNames','targetTaxonPathIds'])
interacts_data.head()
# Out:
#          sourceTaxonId              sourceTaxonName sourceTaxonRank  \
# 117947     EOL:6447088  Golovinomyces cichoracearum         species
# 117948     EOL:4095553             Pontia protodice         species
# 117949  EOL_V2:3639930             Cheilosia grossa         species
# 117950     EOL:2742935             Halictus ligatus         species
# 117951  EOL_V2:2668031          Rhinocyllus conicus         species
#
#                                      sourceTaxonPathNames  \
# 117947  Fungi | Ascomycota | Leotiomycetes | Erysiphal...
# 117948  Animalia | Arthropoda | Insecta | Lepidoptera ...
# 117949  Cellular organisms | Eukaryota | Opisthokonta ...
# 117950  Animalia | Arthropoda | Insecta | Hymenoptera ...
# 117951  Animalia | Bilateria | Protostomia | Ecdysozoa...
#
#        sourceTaxonFamilyName interactionTypeName  \
# 117947          Erysiphaceae       interactsWith
# 117948              Pieridae       interactsWith
# 117949             Syrphidae       interactsWith
# 117950            Halictidae       interactsWith
# 117951         Curculionidae       interactsWith
#
#                                 interactionTypeId targetTaxonId  \
# 117947  http://purl.obolibrary.org/obo/RO_0002437    EOL:468830
# 117948  http://purl.obolibrary.org/obo/RO_0002437    EOL:468830
# 117949  http://purl.obolibrary.org/obo/RO_0002437    EOL:468830
# 117950  http://purl.obolibrary.org/obo/RO_0002437    EOL:468830
# 117951  http://purl.obolibrary.org/obo/RO_0002437    EOL:468830
#
#         targetTaxonName                               targetTaxonPathNames  \
# 117947  Cirsium vulgare  Plantae | Tracheophyta | Magnoliopsida | Aster...
# 117948  Cirsium vulgare  Plantae | Tracheophyta | Magnoliopsida | Aster...
# 117949  Cirsium vulgare  Plantae | Tracheophyta | Magnoliopsida | Aster...
# 117950  Cirsium vulgare  Plantae | Tracheophyta | Magnoliopsida | Aster...
# 117951  Cirsium vulgare  Plantae | Tracheophyta | Magnoliopsida | Aster...
#
#         ... targetTaxonOrderId targetTaxonClassName targetTaxonClassId  \
# 117947  ...           EOL:4205        Magnoliopsida            EOL:283
# 117948  ...           EOL:4205        Magnoliopsida            EOL:283
# 117949  ...           EOL:4205        Magnoliopsida            EOL:283
# 117950  ...           EOL:4205        Magnoliopsida            EOL:283
# 117951  ...           EOL:4205        Magnoliopsida            EOL:283
#
#        targetTaxonPhylumName targetTaxonPhylumId targetTaxonKingdomName  \
# 117947          Tracheophyta            EOL:4077                Plantae
# 117948          Tracheophyta            EOL:4077                Plantae
# 117949          Tracheophyta            EOL:4077                Plantae
# 117950          Tracheophyta            EOL:4077                Plantae
# 117951          Tracheophyta            EOL:4077                Plantae
#
#        targetTaxonKingdomId referenceDoi decimalLatitude decimalLongitude
# 117947           EOL_V2:281          NaN             NaN              NaN
# 117948           EOL_V2:281          NaN             NaN              NaN
# 117949           EOL_V2:281          NaN             NaN              NaN
# 117950           EOL_V2:281          NaN             NaN              NaN
# 117951           EOL_V2:281          NaN             NaN              NaN
#
# [5 rows x 29 columns]

# %%
interacts_data.groupby(interacts_data['sourceTaxonFamilyName']).size().sort_values(ascending = False)
# Out:
# sourceTaxonFamilyName
# Apidae                43
# Megachilidae          23
# Tephritidae           18
# Halictidae            14
# Nymphalidae           10
# Syrphidae             10
# Eulophidae             7
# Curculionidae          5
# Pucciniaceae           5
# Aphididae              5
# Pieridae               4
# Erysiphaceae           4
# Eurytomidae            4
# Hesperiidae            4
# Leptosphaeriaceae      4
# Colletidae             3
# Cicadellidae           3
# Agromyzidae            3
# Papilionidae           3
# Pteromalidae           3
# Phaeosphaeriaceae      3
# Miridae                2
# Tingidae               2
# Apionidae              2
# Bombyliidae            2
# Calliphoridae          2
# Cerambycidae           2
# Chrysomelidae          2
# Peronosporaceae        2
# Trichogrammatidae      2
# Nitidulidae            2
# Torymidae              2
# Mycosphaerellaceae     2
# Lygaeidae              2
# Fagaceae               1
# Andrenidae             1
# Anthomyiidae           1
# Melittidae             1
# Aphrophoridae          1
# Tachinidae             1
# Arctiidae              1
# Asteraceae             1
# Braconidae             1
# Cantharidae            1
# Gelechiidae            1
# Kateretidae            1
# Hybotidae              1
# Sciuridae              1
# Pyralidae              1
# Columbidae             1
# Membracidae            1
# Cosmopterigidae        1
# Crambidae              1
# Noctuidae              1
# Conopidae              1
# dtype: int64

# %% [markdown]
# ## Linking to Wikipedia
# A nice trick by Yikang Li is to make the results clickable, so that you can figure out what sort of oraganisms are interacting

# %%
def make_clickable_both(val): 
    name, url = val.split('#')
    return f'<a href="{url}">{name}</a>'

# %%
def sourcesWithWiki(taxonIn):
    """ Function that takes taxon of interest and finds their interactions and linked to their Wikipedia pages.
    Args:
        taxonIn: the source taxon that we are interested in, can be in any level.

    Returns:
        The source taxa with clickable Wikipedia links for certain source taxon and certain interaction type, 
        in descending order of number of records.
    """
    
    d = data[data['targetTaxonName'] == taxonIn]
    d_cleaned = d[['sourceTaxonId', 'sourceTaxonName', 'sourceTaxonRank',
       'sourceTaxonPathNames', 'sourceTaxonFamilyName', 'interactionTypeName',
       'interactionTypeId', 'targetTaxonId',
       'targetTaxonName','targetTaxonPathNames',
       'targetTaxonPathIds', 'targetTaxonPathRankNames',
       'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
       'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
       'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
       'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
       'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId', 'referenceDoi', 'decimalLatitude', 'decimalLongitude'
        ]].dropna(subset=['targetTaxonId', 'targetTaxonName','targetTaxonPathNames','targetTaxonPathIds'])

    result = d_cleaned.groupby(d_cleaned['sourceTaxonFamilyName']).size().sort_values(ascending = False)
    target_df = pd.DataFrame(result)
    target_df.columns = ['count']

    urls = dict(name= list(target_df.index), 
    url= ['https://en.wikipedia.org/wiki/' + str(i) for i in list(target_df.index)])
    target_df.index = [i + '#' + j for i,j in zip(urls['name'], urls['url'])]
    index_list = list(target_df.index)
    target_df.index =[make_clickable_both(i) for i in index_list]
    df = target_df.style.format({'wiki': make_clickable_both})
    
    return df

# %%
sourcesWithWiki(taxon)
# Out:
# <style  type="text/css" >
# </style><table id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row0" class="row_heading level0 row0" ><a href="https://en.wikipedia.org/wiki/Apidae">Apidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row0_col0" class="data row0 col0" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row1" class="row_heading level0 row1" ><a href="https://en.wikipedia.org/wiki/Megachilidae">Megachilidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row1_col0" class="data row1 col0" >23</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row2" class="row_heading level0 row2" ><a href="https://en.wikipedia.org/wiki/Tephritidae">Tephritidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row2_col0" class="data row2 col0" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row3" class="row_heading level0 row3" ><a href="https://en.wikipedia.org/wiki/Halictidae">Halictidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row3_col0" class="data row3 col0" >14</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row4" class="row_heading level0 row4" ><a href="https://en.wikipedia.org/wiki/Nymphalidae">Nymphalidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row4_col0" class="data row4 col0" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row5" class="row_heading level0 row5" ><a href="https://en.wikipedia.org/wiki/Syrphidae">Syrphidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row5_col0" class="data row5 col0" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row6" class="row_heading level0 row6" ><a href="https://en.wikipedia.org/wiki/Eulophidae">Eulophidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row6_col0" class="data row6 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row7" class="row_heading level0 row7" ><a href="https://en.wikipedia.org/wiki/Curculionidae">Curculionidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row7_col0" class="data row7 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row8" class="row_heading level0 row8" ><a href="https://en.wikipedia.org/wiki/Pucciniaceae">Pucciniaceae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row8_col0" class="data row8 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row9" class="row_heading level0 row9" ><a href="https://en.wikipedia.org/wiki/Aphididae">Aphididae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row9_col0" class="data row9 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row10" class="row_heading level0 row10" ><a href="https://en.wikipedia.org/wiki/Pieridae">Pieridae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row10_col0" class="data row10 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row11" class="row_heading level0 row11" ><a href="https://en.wikipedia.org/wiki/Erysiphaceae">Erysiphaceae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row11_col0" class="data row11 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row12" class="row_heading level0 row12" ><a href="https://en.wikipedia.org/wiki/Eurytomidae">Eurytomidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row12_col0" class="data row12 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row13" class="row_heading level0 row13" ><a href="https://en.wikipedia.org/wiki/Hesperiidae">Hesperiidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row13_col0" class="data row13 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row14" class="row_heading level0 row14" ><a href="https://en.wikipedia.org/wiki/Leptosphaeriaceae">Leptosphaeriaceae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row14_col0" class="data row14 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row15" class="row_heading level0 row15" ><a href="https://en.wikipedia.org/wiki/Colletidae">Colletidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row15_col0" class="data row15 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row16" class="row_heading level0 row16" ><a href="https://en.wikipedia.org/wiki/Cicadellidae">Cicadellidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row16_col0" class="data row16 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row17" class="row_heading level0 row17" ><a href="https://en.wikipedia.org/wiki/Agromyzidae">Agromyzidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row17_col0" class="data row17 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row18" class="row_heading level0 row18" ><a href="https://en.wikipedia.org/wiki/Papilionidae">Papilionidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row18_col0" class="data row18 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row19" class="row_heading level0 row19" ><a href="https://en.wikipedia.org/wiki/Pteromalidae">Pteromalidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row19_col0" class="data row19 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row20" class="row_heading level0 row20" ><a href="https://en.wikipedia.org/wiki/Phaeosphaeriaceae">Phaeosphaeriaceae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row20_col0" class="data row20 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row21" class="row_heading level0 row21" ><a href="https://en.wikipedia.org/wiki/Miridae">Miridae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row21_col0" class="data row21 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11level0_row22" class="row_heading level0 row22" ><a href="https://en.wikipedia.org/wiki/Tingidae">Tingidae</a></th>
#                         <td id="T_50113bdc_0098_11ea_9c69_50eb71e8ed11row22_col0" class="data row22 col0" >2</td>
