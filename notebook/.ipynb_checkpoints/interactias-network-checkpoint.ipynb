# %% [markdown]
# # Interactias Network
#
# One way of examining the impact of invasive species is to look at all their interactions and the interations those organisms have with each other. This full interaction network gives you a good idea whether a species might be a "keystone" species
#
# *"The concept of the "keystone species" is redefined to allow for the a priori prediction of these species within ecosystems. A keystone species is held to be a **strongly interacting species** whose top-down effect on species diversity and competition is large relative to its biomass dominance within a functional group."*
#
# Davic, R. D. (2003). Linking keystone species and functional groups: a new operational definition of the keystone species concept. Conservation Ecology, 7(1).
#
# I will harvest species interactions data from GLOBI (https://www.globalbioticinteractions.org/) to discover the species that interact with an invasive species. I will then harvest all the interactions for those species to create two tiers of interactions. I will then create a network diagram to visualize this.
#
# This notebook takes considerable insperation and code from Yikang Li's project on GLoBI (https://curiositydata.org/part1_globi_access/).

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the GLoBI data
#
# The current snapshot of GLoBI was taken on 2019-11-05 from https://depot.globalbioticinteractions.org/snapshot/target/data/tsv/interactions.tsv.gz

# %%
# This takes a few minutes to load in.
# the low_memory=False property will get rid of a warning, but will not help if there is really no memory left
data = pd.read_csv('C://Users//quentin//Documents//interactias//interactias//data//interactions.tsv', delimiter='\t', encoding='utf-8', low_memory=False)
len(data)
# Out:
# 3878740

# %%
# Take a little look at the data to make sure it makes sense
data.head()
# Out:
#   sourceTaxonId                                     sourceTaxonIds  \
# 0  EOL:12001247  EOL:12001247 | OTT:133330 | IRMNG:11733708 | N...
# 1  EOL:12001247  EOL:12001247 | OTT:133330 | IRMNG:11733708 | N...
# 2  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
# 3  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
# 4  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
#
#              sourceTaxonName sourceTaxonRank  \
# 0       Leptoconchus massini         species
# 1       Leptoconchus massini         species
# 2  Leptoconchus inpleuractis         species
# 3  Leptoconchus inpleuractis         species
# 4  Leptoconchus inpleuractis         species
#
#                                 sourceTaxonPathNames  \
# 0  Animalia | Mollusca | Gastropoda | Neogastropo...
# 1  Animalia | Mollusca | Gastropoda | Neogastropo...
# 2  Animalia | Mollusca | Gastropoda | Neogastropo...
# 3  Animalia | Mollusca | Gastropoda | Neogastropo...
# 4  Animalia | Mollusca | Gastropoda | Neogastropo...
#
#                                   sourceTaxonPathIds  \
# 0  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 1  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 2  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 3  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 4  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
#
#                             sourceTaxonPathRankNames  \
# 0  kingdom | phylum | class | order | superfamily...
# 1  kingdom | phylum | class | order | superfamily...
# 2  kingdom | phylum | class | order | superfamily...
# 3  kingdom | phylum | class | order | superfamily...
# 4  kingdom | phylum | class | order | superfamily...
#
#       sourceTaxonSpeciesName sourceTaxonSpeciesId sourceTaxonGenusName  ...  \
# 0       Leptoconchus massini         EOL:12001247         Leptoconchus  ...
# 1       Leptoconchus massini         EOL:12001247         Leptoconchus  ...
# 2  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
# 3  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
# 4  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
#
#   eventDateUnixEpoch                          argumentTypeId  \
# 0                NaN  https://en.wiktionary.org/wiki/support
# 1                NaN  https://en.wiktionary.org/wiki/support
# 2                NaN  https://en.wiktionary.org/wiki/support
# 3                NaN  https://en.wiktionary.org/wiki/support
# 4                NaN  https://en.wiktionary.org/wiki/support
#
#                                    referenceCitation  \
# 0  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 1  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 2  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 3  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 4  Gittenberger, A., Gittenberger, E. (2011). Cry...
#
#                 referenceDoi referenceUrl  \
# 0  10.1007/s13127-011-0039-1          NaN
# 1  10.1007/s13127-011-0039-1          NaN
# 2  10.1007/s13127-011-0039-1          NaN
# 3  10.1007/s13127-011-0039-1          NaN
# 4  10.1007/s13127-011-0039-1          NaN
#
#                                       sourceCitation  \
# 0  Jorrit H. Poelen. 2014. Species associations m...
# 1  Jorrit H. Poelen. 2014. Species associations m...
# 2  Jorrit H. Poelen. 2014. Species associations m...
# 3  Jorrit H. Poelen. 2014. Species associations m...
# 4  Jorrit H. Poelen. 2014. Species associations m...
#
#                  sourceNamespace  \
# 0  FloraVincent/template-dataset
# 1  FloraVincent/template-dataset
# 2  FloraVincent/template-dataset
# 3  FloraVincent/template-dataset
# 4  FloraVincent/template-dataset
#
#                                     sourceArchiveURI sourceDOI  \
# 0  https://github.com/FloraVincent/template-datas...       NaN
# 1  https://github.com/FloraVincent/template-datas...       NaN
# 2  https://github.com/FloraVincent/template-datas...       NaN
# 3  https://github.com/FloraVincent/template-datas...       NaN
# 4  https://github.com/FloraVincent/template-datas...       NaN
#
#   sourceLastSeenAtUnixEpoch
# 0  2019-03-30T23:08:44.205Z
# 1  2019-03-30T23:08:44.205Z
# 2  2019-03-30T23:08:44.205Z
# 3  2019-03-30T23:08:44.205Z
# 4  2019-03-30T23:08:44.205Z
#
# [5 rows x 80 columns]

# %% [markdown]
# ## Drop duplicates
#
# This line gets rid of duplicate interations. I currently can't see a reason to keep them, but this perhaps should be checked.
# Some more common interactions might have more support in the literature and therefore more records. Deduplicating them tends to equal out rare interactions with common ones.

# %%
data.drop_duplicates(['sourceTaxonName', 'interactionTypeName', 'targetTaxonName'], inplace = True)

# %%
## Check how many rows are left
len(data)
# Out:
# 394688

# %% [markdown]
# ## Remove ranks that are not species
# Many entries in GLoBI are non-specific interations at a high taxonomic level. For example, roses are visited by bees.
# I have chossen to remove these interactions from the study, at least preliminarly

# %%
data.drop(data[data['sourceTaxonRank'] != 'species'].index, inplace = True)
data.drop(data[data['targetTaxonRank'] != 'species'].index, inplace = True)

# %%
## Check how many rows are left
len(data)
# Out:
# 394688

# %% [markdown]
# ## Remove "interactsWith"
# There are many vague interactions with the term interactsWith. These aren't really that useful, because it could be any kind of interaction, positive or negative, direct or indirect.

# %%
data = data[data.interactionTypeName != 'interactsWith']

len(data)
# Out:
# 394688

# %% [markdown]
# Define the key taxon for the notebook for which to find all interactions

# %%
taxon = "Oxalis corniculata"
#taxon = "Oxalis pes-caprae"
#taxon = "Lantana camara"
#taxon = "Cirsium vulgare"
#taxon = "Procyon lotor" # raccoon
#taxon = "Sciurus carolinensis" # Eastern grey squirrel

# %%
# What are all the types of interactions involving Oxalis pes-caprae as source taxon?
data[data['sourceTaxonName'] == taxon]['interactionTypeName'].unique()
# Out:
# array([], dtype=object)

# %%
# What are all the types of interactions involving Oxalis pes-caprae as target taxon?
data[data['targetTaxonName'] == taxon]['interactionTypeName'].unique()
# Out:
# array(['eats', 'parasiteOf', 'visitsFlowersOf', 'hasHost', 'mutualistOf',
#        'pathogenOf', 'pollinates'], dtype=object)

# %% [markdown]
# How many taxon sources do I have?

# %%
len(data[data['sourceTaxonName'] == taxon])
# Out:
# 0

# %% [markdown]
# How many taxon targets do I have?

# %%
len(data[data['targetTaxonName'] == taxon])
# Out:
# 48

# %% [markdown]
# Gather together all the data where the target is the taxon in question.

# %%
# What are the columns of this dataset?
data.columns
# Out:
# Index(['sourceTaxonId', 'sourceTaxonIds', 'sourceTaxonName', 'sourceTaxonRank',
#        'sourceTaxonPathNames', 'sourceTaxonPathIds',
#        'sourceTaxonPathRankNames', 'sourceTaxonSpeciesName',
#        'sourceTaxonSpeciesId', 'sourceTaxonGenusName', 'sourceTaxonGenusId',
#        'sourceTaxonFamilyName', 'sourceTaxonFamilyId', 'sourceTaxonOrderName',
#        'sourceTaxonOrderId', 'sourceTaxonClassName', 'sourceTaxonClassId',
#        'sourceTaxonPhylumName', 'sourceTaxonPhylumId',
#        'sourceTaxonKingdomName', 'sourceTaxonKingdomId', 'sourceId',
#        'sourceOccurrenceId', 'sourceCatalogNumber', 'sourceBasisOfRecordId',
#        'sourceBasisOfRecordName', 'sourceLifeStageId', 'sourceLifeStageName',
#        'sourceBodyPartId', 'sourceBodyPartName', 'sourcePhysiologicalStateId',
#        'sourcePhysiologicalStateName', 'interactionTypeName',
#        'interactionTypeId', 'targetTaxonId', 'targetTaxonIds',
#        'targetTaxonName', 'targetTaxonRank', 'targetTaxonPathNames',
#        'targetTaxonPathIds', 'targetTaxonPathRankNames',
#        'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
#        'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
#        'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
#        'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
#        'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId',
#        'targetId', 'targetOccurrenceId', 'targetCatalogNumber',
#        'targetBasisOfRecordId', 'targetBasisOfRecordName', 'targetLifeStageId',
#        'targetLifeStageName', 'targetBodyPartId', 'targetBodyPartName',
#        'targetPhysiologicalStateId', 'targetPhysiologicalStateName',
#        'decimalLatitude', 'decimalLongitude', 'localityId', 'localityName',
#        'eventDateUnixEpoch', 'argumentTypeId', 'referenceCitation',
#        'referenceDoi', 'referenceUrl', 'sourceCitation', 'sourceNamespace',
#        'sourceArchiveURI', 'sourceDOI', 'sourceLastSeenAtUnixEpoch'],
#       dtype='object')

# %% [markdown]
# ## Simplify the table to make it readable

# %% [markdown]
# ## Get the primary interation data for the species in question

# %%
    interactDataTaxon = data[data['targetTaxonName'] == taxon]
    interactDataTaxon = interactDataTaxon.append(data[data['sourceTaxonName'] == taxon])

# %% [markdown]
# ## Get a list of all the primary interacting species

# %%
interactingTaxa = interactDataTaxon['sourceTaxonName'].append(interactDataTaxon['targetTaxonName']).unique()

# %% [markdown]
# ## Get all the secondary interactions

# %%
for name in interactingTaxa:
    interactDataTaxon = interactDataTaxon.append(data[data['sourceTaxonName'] == name])

# %%
    cleanInteractDataTaxon = interactDataTaxon[['sourceTaxonId', 'sourceTaxonName', 'sourceTaxonRank',
       'sourceTaxonPathNames', 'sourceTaxonFamilyName', 'interactionTypeName',
       'interactionTypeId', 'targetTaxonId', 'targetTaxonRank',
       'targetTaxonName','targetTaxonPathNames',
       'targetTaxonPathIds', 'targetTaxonPathRankNames',
       'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
       'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
       'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
       'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
       'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId', 'referenceDoi', 'decimalLatitude', 'decimalLongitude'
        ]].dropna(subset=['targetTaxonId', 'targetTaxonName','targetTaxonPathNames','targetTaxonPathIds'])

# %%
cleanInteractDataTaxon.head()
# Out:
#           sourceTaxonId         sourceTaxonName sourceTaxonRank  \
# 193783      EOL:1048468        Anas aucklandica         species
# 212212   EOL_V2:1049189  Callipepla californica         species
# 212652     GBIF:7341600      Melozone crissalis         species
# 213107      ITIS:997805    Haemorhous mexicanus         species
# 1131090    GBIF:2514966         Puccinia sorghi         species
#
#                                       sourceTaxonPathNames  \
# 193783                                    Anas aucklandica
# 212212   Animalia | Chordata | Aves | Galliformes | Odo...
# 212652   Animalia | Chordata | Aves | Passeriformes | E...
# 213107   Animalia | Bilateria | Deuterostomia | Chordat...
# 1131090  Fungi | Basidiomycota | Pucciniomycetes | Pucc...
#
#         sourceTaxonFamilyName interactionTypeName  \
# 193783                    NaN                eats
# 212212         Odontophoridae                eats
# 212652            Emberizidae                eats
# 213107           Fringillidae                eats
# 1131090          Pucciniaceae          parasiteOf
#
#                                  interactionTypeId targetTaxonId  \
# 193783   http://purl.obolibrary.org/obo/RO_0002470    ITIS:29067
# 212212   http://purl.obolibrary.org/obo/RO_0002470    ITIS:29067
# 212652   http://purl.obolibrary.org/obo/RO_0002470    ITIS:29067
# 213107   http://purl.obolibrary.org/obo/RO_0002470    ITIS:29067
# 1131090  http://purl.obolibrary.org/obo/RO_0002444  GBIF:8427624
#
#         targetTaxonRank     targetTaxonName  ... targetTaxonOrderId  \
# 193783          species  Oxalis corniculata  ...        ITIS:846628
# 212212          species  Oxalis corniculata  ...        ITIS:846628
# 212652          species  Oxalis corniculata  ...        ITIS:846628
# 213107          species  Oxalis corniculata  ...        ITIS:846628
# 1131090         species  Oxalis corniculata  ...       GBIF:7224021
#
#         targetTaxonClassName targetTaxonClassId targetTaxonPhylumName  \
# 193783         Magnoliopsida         ITIS:18063          Tracheophyta
# 212212         Magnoliopsida         ITIS:18063          Tracheophyta
# 212652         Magnoliopsida         ITIS:18063          Tracheophyta
# 213107         Magnoliopsida         ITIS:18063          Tracheophyta
# 1131090        Magnoliopsida           GBIF:220          Tracheophyta
#
#         targetTaxonPhylumId targetTaxonKingdomName targetTaxonKingdomId  \
# 193783          ITIS:846496                Plantae          ITIS:202422
# 212212          ITIS:846496                Plantae          ITIS:202422
# 212652          ITIS:846496                Plantae          ITIS:202422
# 213107          ITIS:846496                Plantae          ITIS:202422
# 1131090        GBIF:7707728                Plantae               GBIF:6
#
#         referenceDoi decimalLatitude decimalLongitude
# 193783           NaN             NaN              NaN
# 212212           NaN             NaN              NaN
# 212652           NaN             NaN              NaN
# 213107           NaN             NaN              NaN
# 1131090          NaN             NaN              NaN
#
# [5 rows x 30 columns]

# %%
# How many different sort of interaction do I have left?
# Checking out all the interaction types
cleanInteractDataTaxon['interactionTypeName'].unique()
# Out:
# array(['eats', 'parasiteOf', 'mutualistOf', 'pathogenOf', 'pollinates',
#        'visitsFlowersOf', 'hasHost'], dtype=object)

# %%
cleanInteractDataTaxon.groupby(cleanInteractDataTaxon['interactionTypeName']).size().sort_values(ascending = False)
# Out:
# interactionTypeName
# pollinates         540
# mutualistOf        353
# eats               289
# visitsFlowersOf    149
# hasHost             17
# parasiteOf           8
# pathogenOf           6
# dtype: int64

# %%
len(cleanInteractDataTaxon)
# Out:
# 1362

# %%
cleanInteractDataTaxon.head()
# Out:
#           sourceTaxonId         sourceTaxonName sourceTaxonRank  \
# 193783      EOL:1048468        Anas aucklandica         species
# 212212   EOL_V2:1049189  Callipepla californica         species
# 212652     GBIF:7341600      Melozone crissalis         species
# 213107      ITIS:997805    Haemorhous mexicanus         species
# 1131090    GBIF:2514966         Puccinia sorghi         species
#
#                                       sourceTaxonPathNames  \
# 193783                                    Anas aucklandica
# 212212   Animalia | Chordata | Aves | Galliformes | Odo...
# 212652   Animalia | Chordata | Aves | Passeriformes | E...
# 213107   Animalia | Bilateria | Deuterostomia | Chordat...
# 1131090  Fungi | Basidiomycota | Pucciniomycetes | Pucc...
#
#         sourceTaxonFamilyName interactionTypeName  \
# 193783                    NaN                eats
# 212212         Odontophoridae                eats
# 212652            Emberizidae                eats
# 213107           Fringillidae                eats
# 1131090          Pucciniaceae          parasiteOf
#
#                                  interactionTypeId targetTaxonId  \
# 193783   http://purl.obolibrary.org/obo/RO_0002470    ITIS:29067
# 212212   http://purl.obolibrary.org/obo/RO_0002470    ITIS:29067
# 212652   http://purl.obolibrary.org/obo/RO_0002470    ITIS:29067
# 213107   http://purl.obolibrary.org/obo/RO_0002470    ITIS:29067
# 1131090  http://purl.obolibrary.org/obo/RO_0002444  GBIF:8427624
#
#         targetTaxonRank     targetTaxonName  ... targetTaxonOrderId  \
# 193783          species  Oxalis corniculata  ...        ITIS:846628
# 212212          species  Oxalis corniculata  ...        ITIS:846628
# 212652          species  Oxalis corniculata  ...        ITIS:846628
# 213107          species  Oxalis corniculata  ...        ITIS:846628
# 1131090         species  Oxalis corniculata  ...       GBIF:7224021
#
#         targetTaxonClassName targetTaxonClassId targetTaxonPhylumName  \
# 193783         Magnoliopsida         ITIS:18063          Tracheophyta
# 212212         Magnoliopsida         ITIS:18063          Tracheophyta
# 212652         Magnoliopsida         ITIS:18063          Tracheophyta
# 213107         Magnoliopsida         ITIS:18063          Tracheophyta
# 1131090        Magnoliopsida           GBIF:220          Tracheophyta
#
#         targetTaxonPhylumId targetTaxonKingdomName targetTaxonKingdomId  \
# 193783          ITIS:846496                Plantae          ITIS:202422
# 212212          ITIS:846496                Plantae          ITIS:202422
# 212652          ITIS:846496                Plantae          ITIS:202422
# 213107          ITIS:846496                Plantae          ITIS:202422
# 1131090        GBIF:7707728                Plantae               GBIF:6
#
#         referenceDoi decimalLatitude decimalLongitude
# 193783           NaN             NaN              NaN
# 212212           NaN             NaN              NaN
# 212652           NaN             NaN              NaN
# 213107           NaN             NaN              NaN
# 1131090          NaN             NaN              NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # Drawing a network of the interactions

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create graphic object
G = nx.DiGraph()

# Match colours to interactions to distinguish them on the graph
colorInteractions = {'interaction':['pollinates', 'mutualistOf', 'eats', 'visitsFlowersOf', 'hasHost', 'parasiteOf', 'pathogenOf'],
        'colour':['r', 'g', 'b', 'y', 'm', 'w', 'c']}  

colorInteractionsDf = pd.DataFrame(colorInteractions)

# %%
# iterate over rows with iterrows()
for index, row in cleanInteractDataTaxon.iterrows():
     # access data using column names
     #print(row['sourceTaxonName'], row['targetTaxonName'], row['interactionTypeName'])
    G.add_node(row['sourceTaxonName'])
    G.add_node(row['targetTaxonName'], color = colorInteractionsDf[colorInteractionsDf.interaction == row['interactionTypeName']].iloc[0]['colour'])
    #print(colorInteractionsDf[colorInteractionsDf.interaction == row['interactionTypeName']].iloc[:,1])
    G.add_edge(row['targetTaxonName'], row['sourceTaxonName'], label = row['interactionTypeName'])

# %% [markdown]
# ## A network of all the interacting taxa

# %%
plt.figure(figsize=(20,20))
edge_labels = nx.get_edge_attributes(G,'label')

pos = nx.spring_layout(G) 
#pos = nx.random_layout(G)
#pos = nx.circular_layout(G)
#pos = nx.spectral_layout(G)
#pos = nx.shell_layout(G, scale=2)

#nodeColors = nx.get_node_attributes(G,'color')

#nx.draw_networkx_edge_labels(G,pos, edge_labels = edge_labels, font_size=10, font_color='blue')

#nx.draw_networkx_nodes(G, pos, node_color=nodeColors.values())

nx.draw_networkx(G, pos, with_labels=True, node_size=1000, node_color='c', alpha= 1, arrows=True, 
                    linewidths=1, font_color="black", font_size=10, style = 'dashed')

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
edge_labels
# Out:
# {('Oxalis corniculata', 'Anas aucklandica'): 'eats',
#  ('Oxalis corniculata', 'Callipepla californica'): 'eats',
#  ('Oxalis corniculata', 'Melozone crissalis'): 'eats',
#  ('Oxalis corniculata', 'Haemorhous mexicanus'): 'eats',
#  ('Oxalis corniculata', 'Puccinia sorghi'): 'parasiteOf',
#  ('Oxalis corniculata', 'Erysiphe russellii'): 'parasiteOf',
#  ('Oxalis corniculata', 'Zizula hylax'): 'eats',
#  ('Oxalis corniculata', 'Pseudozizeeria maha'): 'eats',
#  ('Oxalis corniculata', 'Lucia limbaria'): 'eats',
#  ('Oxalis corniculata', 'Zizeeria knysna'): 'eats',
#  ('Oxalis corniculata', 'Actizera stellata'): 'eats',
#  ('Oxalis corniculata', 'Actizera lucida'): 'eats',
#  ('Oxalis corniculata', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Oxalis corniculata', 'Bibio albipennis'): 'pollinates',
#  ('Oxalis corniculata', 'Cylindromyia rufipes'): 'pollinates',
#  ('Oxalis corniculata', 'Leptometopa latipes'): 'pollinates',
#  ('Oxalis corniculata', 'Thorybes bathyllus'): 'pollinates',
#  ('Oxalis corniculata', 'Epeolus pusillus'): 'pollinates',
#  ('Oxalis corniculata', 'Photinus pyralis'): 'pollinates',
#  ('Oxalis corniculata', 'Trichiotinus affinis'): 'pollinates',
#  ('Oxalis corniculata', 'Mordellistena aspersa'): 'pollinates',
#  ('Oxalis corniculata', 'Asclera puncticollis'): 'pollinates',
#  ('Oxalis corniculata', 'Andrena pruni'): 'pollinates',
#  ('Oxalis corniculata', 'Sapyga centrata'): 'pollinates',
#  ('Oxalis corniculata', 'Ceratina dupla'): 'pollinates',
#  ('Oxalis corniculata', 'Tomato leaf curl China virus - OX2'): 'pathogenOf',
#  ('Oxalis corniculata',
#   'Ageratum Yellow vein China virus - OX1'): 'pathogenOf',
#  ('Oxalis corniculata', 'Bombus pensylvanicus'): 'pollinates',
#  ('Oxalis corniculata', 'Andrena carlini'): 'pollinates',
#  ('Oxalis corniculata', nan): 'pollinates',
#  ('Oxalis corniculata', 'Paragus haemorrhous'): 'visitsFlowersOf',
#  ('Oxalis corniculata', 'Petrobia harti'): 'hasHost',
#  ('Oxyethira albiceps', 'Anas aucklandica'): 'eats',
#  ('Halicarcinus varius', 'Anas aucklandica'): 'eats',
#  ('Austrovenus stutchburyi', 'Anas aucklandica'): 'eats',
#  ('Paphies australis', 'Anas aucklandica'): 'eats',
#  ('Milax gagates', 'Anas aucklandica'): 'eats',
#  ('Helix aspersa', 'Anas aucklandica'): 'eats',
#  ('Austrolittorina antipodum', 'Anas aucklandica'): 'eats',
#  ('Zeacumantus lutulentus', 'Anas aucklandica'): 'eats',
#  ('Persicaria decipiens', 'Anas aucklandica'): 'eats',
#  ('Leucopogon fasciculatus', 'Anas aucklandica'): 'eats',
#  ('Melicope simplex', 'Anas aucklandica'): 'eats',
#  ('Trifolium repens', 'Anas aucklandica'): 'eats',
#  ('Trifolium repens', 'Andrena carlini'): 'pollinates',
#  ('Solanum tuberosum', 'Anas aucklandica'): 'eats',
#  ('Apodasmia similis', 'Anas aucklandica'): 'eats',
#  ('Margyricarpus pinnatus', 'Callipepla californica'): 'eats',
#  ('Phaseolus vulgaris', 'Callipepla californica'): 'eats',
#  ('Lens culinaris', 'Callipepla californica'): 'eats',
#  ('Polygonum aviculare', 'Callipepla californica'): 'eats',
#  ('Polygonum aviculare', 'Haemorhous mexicanus'): 'eats',
#  ('Panicum capillare', 'Callipepla californica'): 'eats',
#  ('Convolvulus arvensis', 'Callipepla californica'): 'eats',
#  ('Chenopodium album', 'Callipepla californica'): 'eats',
#  ('Chenopodium album', 'Melozone crissalis'): 'eats',
#  ('Brassica rapa', 'Callipepla californica'): 'eats',
#  ('Brassica rapa', 'Haemorhous mexicanus'): 'eats',
#  ('Brassica rapa', 'Pieris rapae'): 'eats',
#  ('Echium vulgare', 'Callipepla californica'): 'eats',
#  ('Madia sativa', 'Callipepla californica'): 'eats',
#  ('Madia sativa', 'Melozone crissalis'): 'eats',
#  ('Madia sativa', 'Haemorhous mexicanus'): 'eats',
#  ('Centaurea melitensis', 'Callipepla californica'): 'eats',
#  ('Centaurea melitensis', 'Melozone crissalis'): 'eats',
#  ('Centaurea melitensis', 'Haemorhous mexicanus'): 'eats',
#  ('Gevuina avellana', 'Callipepla californica'): 'eats',
#  ('Zea mays', 'Callipepla californica'): 'eats',
#  ('Zea mays', 'Melozone crissalis'): 'eats',
#  ('Zea mays', 'Puccinia sorghi'): 'hasHost',
#  ('Zea mays', 'Andrena carlini'): 'pollinates',
#  ('Avena sativa', 'Callipepla californica'): 'eats',
#  ('Amaranthus retroflexus', 'Callipepla californica'): 'eats',
#  ('Amaranthus retroflexus', 'Melozone crissalis'): 'eats',
#  ('Raphanus sativus', 'Callipepla californica'): 'eats',
#  ('Raphanus sativus', 'Haemorhous mexicanus'): 'eats',
#  ('Raphanus sativus', 'Pieris rapae'): 'eats',
#  ('Medicago polymorpha', 'Callipepla californica'): 'eats',
#  ('Vicia sativa', 'Callipepla californica'): 'eats',
#  ('Bromus hordeaceus', 'Callipepla californica'): 'eats',
#  ('Sisymbrium altissimum', 'Callipepla californica'): 'eats',
#  ('Sisymbrium altissimum', 'Pieris rapae'): 'eats',
#  ('Erodium cicutarium', 'Callipepla californica'): 'eats',
#  ('Erodium cicutarium', 'Melozone crissalis'): 'eats',
#  ('Triticum aestivum', 'Callipepla californica'): 'eats',
#  ('Holosteum umbellatum', 'Callipepla californica'): 'eats',
#  ('Lactuca serriola', 'Callipepla californica'): 'eats',
#  ('Helianthus annuus', 'Callipepla californica'): 'eats',
#  ('Helianthus annuus', 'Bibio albipennis'): 'pollinates',
#  ('Helianthus annuus', 'Sapyga centrata'): 'pollinates',
#  ('Pisum sativum', 'Callipepla californica'): 'eats',
#  ('Pisum sativum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Echinochloa crus-galli', 'Callipepla californica'): 'eats',
#  ('Lupinus bicolor', 'Callipepla californica'): 'eats',
#  ('Croton setiger', 'Callipepla californica'): 'eats',
#  ('Croton setiger', 'Melozone crissalis'): 'eats',
#  ('Croton setiger', 'Haemorhous mexicanus'): 'eats',
#  ('Acmispon americanus', 'Callipepla californica'): 'eats',
#  ('Phalaris caroliniana', 'Callipepla californica'): 'eats',
#  ('Stipa mucronata', 'Callipepla californica'): 'eats',
#  ('Phleum pratense', 'Callipepla californica'): 'eats',
#  ('Poa annua', 'Callipepla californica'): 'eats',
#  ('Bromus secalinus', 'Callipepla californica'): 'eats',
#  ('Lolium perenne', 'Callipepla californica'): 'eats',
#  ('Rumex acetosella', 'Callipepla californica'): 'eats',
#  ('Rumex acetosella', 'Melozone crissalis'): 'eats',
#  ('Rumex acetosella', 'Haemorhous mexicanus'): 'eats',
#  ('Rumex crispus', 'Callipepla californica'): 'eats',
#  ('Persicaria lapathifolia', 'Callipepla californica'): 'eats',
#  ('Persicaria punctata', 'Callipepla californica'): 'eats',
#  ('Persicaria punctata', 'Andrena pruni'): 'pollinates',
#  ('Fallopia convolvulus', 'Callipepla californica'): 'eats',
#  ('Silene antirrhina', 'Callipepla californica'): 'eats',
#  ('Cerastium arvense', 'Callipepla californica'): 'eats',
#  ('Stellaria media', 'Callipepla californica'): 'eats',
#  ('Stellaria media', 'Melozone crissalis'): 'eats',
#  ('Stellaria media', 'Haemorhous mexicanus'): 'eats',
#  ('Stellaria media', 'Andrena pruni'): 'pollinates',
#  ('Stellaria media', 'Sapyga centrata'): 'visitsFlowersOf',
#  ('Stellaria media', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Spergula arvensis', 'Callipepla californica'): 'eats',
#  ('Spergula arvensis', 'Melozone crissalis'): 'eats',
#  ('Spergula arvensis', 'Haemorhous mexicanus'): 'eats',
#  ('Calandrinia ciliata', 'Callipepla californica'): 'eats',
#  ('Calandrinia ciliata', 'Melozone crissalis'): 'eats',
#  ('Claytonia perfoliata', 'Callipepla californica'): 'eats',
#  ('Claytonia perfoliata', 'Melozone crissalis'): 'eats',
#  ('Claytonia perfoliata', 'Haemorhous mexicanus'): 'eats',
#  ('Eschscholzia californica', 'Callipepla californica'): 'eats',
#  ('Brassica nigra', 'Callipepla californica'): 'eats',
#  ('Brassica nigra', 'Haemorhous mexicanus'): 'eats',
#  ('Brassica nigra', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Malva pusilla', 'Callipepla californica'): 'eats',
#  ('Malva pusilla', 'Bibio albipennis'): 'pollinates',
#  ('Malva pusilla', 'Epeolus pusillus'): 'pollinates',
#  ('Malva pusilla', 'Mordellistena aspersa'): 'pollinates',
#  ('Malva pusilla', 'Andrena pruni'): 'pollinates',
#  ('Malva pusilla', 'Ceratina dupla'): 'pollinates',
#  ('Malva pusilla', 'Andrena carlini'): 'pollinates',
#  ('Toxicodendron diversilobum', 'Callipepla californica'): 'eats',
#  ('Toxicodendron diversilobum', 'Melozone crissalis'): 'eats',
#  ('Toxicodendron diversilobum', 'Haemorhous mexicanus'): 'eats',
#  ('Malosma laurina', 'Callipepla californica'): 'eats',
#  ('Lotus tenuis', 'Callipepla californica'): 'eats',
#  ('Melilotus albus', 'Callipepla californica'): 'eats',
#  ('Melilotus albus', 'Ceratina dupla'): 'pollinates',
#  ('Daucus carota', 'Callipepla californica'): 'eats',
#  ('Solanum ptychanthum', 'Callipepla californica'): 'eats',
#  ('Solanum ptychanthum', 'Melozone crissalis'): 'eats',
#  ('Solanum ptychanthum', 'Haemorhous mexicanus'): 'eats',
#  ('Plantago major', 'Callipepla californica'): 'eats',
#  ('Plantago patagonica', 'Callipepla californica'): 'eats',
#  ('Plantago lanceolata', 'Callipepla californica'): 'eats',
#  ('Plantago lanceolata', 'Melozone crissalis'): 'eats',
#  ('Triumfetta semitriloba', 'Callipepla californica'): 'eats',
#  ('Verbena hastata', 'Callipepla californica'): 'eats',
#  ('Verbena hastata', 'Bibio albipennis'): 'pollinates',
#  ('Verbena hastata', 'Andrena pruni'): 'pollinates',
#  ('Verbena hastata', 'Andrena carlini'): 'pollinates',
#  ('Sonchus oleraceus', 'Callipepla californica'): 'eats',
#  ('Sonchus asper', 'Callipepla californica'): 'eats',
#  ('Centaurea benedicta', 'Callipepla californica'): 'eats',
#  ('Silybum marianum', 'Callipepla californica'): 'eats',
#  ('Silybum marianum', 'Melozone crissalis'): 'eats',
#  ('Silybum marianum', 'Haemorhous mexicanus'): 'eats',
#  ('Anthemis cotula', 'Callipepla californica'): 'eats',
#  ('Anthemis cotula', 'Melozone crissalis'): 'eats',
#  ('Anthemis cotula', 'Haemorhous mexicanus'): 'eats',
#  ('Grindelia squarrosa', 'Callipepla californica'): 'eats',
#  ('Grindelia squarrosa', 'Epeolus pusillus'): 'hasHost',
#  ('Olea europaea', 'Callipepla californica'): 'eats',
#  ('Malus pumila', 'Callipepla californica'): 'eats',
#  ('Amsinckia intermedia', 'Callipepla californica'): 'eats',
#  ('Dysphania botrys', 'Callipepla californica'): 'eats',
#  ('Vicia villosa', 'Callipepla californica'): 'eats',
#  ('Cirsium arvense', 'Callipepla californica'): 'eats',
#  ('Cirsium arvense', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Claytonia parviflora', 'Callipepla californica'): 'eats',
#  ('Capsella bursa-pastoris', 'Callipepla californica'): 'eats',
#  ('Capsella bursa-pastoris', 'Pieris rapae'): 'eats',
#  ('Solanum nigrum', 'Callipepla californica'): 'eats',
#  ('Crataegus douglasii', 'Callipepla californica'): 'eats',
#  ('Rhus glabra', 'Callipepla californica'): 'eats',
#  ('Rhus glabra', 'Bibio albipennis'): 'pollinates',
#  ('Rhus glabra', 'Sapyga centrata'): 'pollinates',
#  ('Avena fatua', 'Callipepla californica'): 'eats',
#  ('Avena fatua', 'Melozone crissalis'): 'eats',
#  ('Bromus tectorum', 'Callipepla californica'): 'eats',
#  ('Verbena bracteata', 'Callipepla californica'): 'eats',
#  ('Verbena bracteata', 'Andrena carlini'): 'pollinates',
#  ('Calamovilfa longifolia', 'Callipepla californica'): 'eats',
#  ('Cytisus scoparius', 'Callipepla californica'): 'eats',
#  ('Brahea armata', 'Callipepla californica'): 'eats',
#  ('Zonotrichia leucophrys', 'Callipepla californica'): 'parasiteOf',
#  ('Sturnella neglecta', 'Callipepla californica'): 'parasiteOf',
#  ('Digitaria sanguinalis', 'Melozone crissalis'): 'eats',
#  ('Papaver macounii', 'Melozone crissalis'): 'eats',
#  ('Geranium dissectum', 'Melozone crissalis'): 'eats',
#  ('Geranium dissectum', 'Haemorhous mexicanus'): 'eats',
#  ('Amsinckia tessellata', 'Melozone crissalis'): 'eats',
#  ('Amsinckia tessellata', 'Haemorhous mexicanus'): 'eats',
#  ('Saissetia oleae', 'Melozone crissalis'): 'eats',
#  ('Gammarotettix genitalis', 'Melozone crissalis'): 'eats',
#  ('Senecio vulgaris', 'Haemorhous mexicanus'): 'eats',
#  ('Ambrosia psilostachya', 'Haemorhous mexicanus'): 'eats',
#  ('Pinus canariensis', 'Haemorhous mexicanus'): 'eats',
#  ('Opuntia engelmannii', 'Haemorhous mexicanus'): 'eats',
#  ('Ficus carica', 'Haemorhous mexicanus'): 'eats',
#  ('Ligustrum lucidum', 'Haemorhous mexicanus'): 'eats',
#  ('Oxalis rosea', 'Erysiphe russellii'): 'parasiteOf',
#  ('Phaulopsis dorsiflora', 'Zizula hylax'): 'eats',
#  ('Dyschoriste setigera', 'Zizula hylax'): 'eats',
#  ('Lantana camara', 'Zizula hylax'): 'eats',
#  ('Lantana camara', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Lantana camara', 'Bibio albipennis'): 'pollinates',
#  ('Lantana camara', 'Ceratina dupla'): 'pollinates',
#  ('Mimosa pudica', 'Zizula hylax'): 'eats',
#  ('Lantana hybrida', 'Zizula hylax'): 'eats',
#  ('Lantana montevidensis', 'Zizula hylax'): 'eats',
#  ('Ruellia longepetiolata', 'Zizula hylax'): 'eats',
#  ('Ruellia simplex', 'Zizula hylax'): 'eats',
#  ('Dicliptera chinensis', 'Zizula hylax'): 'eats',
#  ('Tribulus terrestris', 'Pseudozizeeria maha'): 'eats',
#  ('Tribulus terrestris', 'Zizeeria knysna'): 'eats',
#  ('Crepidiastrum lanceolatum', 'Pseudozizeeria maha'): 'visitsFlowersOf',
#  ('Serissa japonica', 'Pseudozizeeria maha'): 'eats',
#  ('Cuphea hyssopifolia', 'Pseudozizeeria maha'): 'eats',
#  ('Oxalis dillenii', 'Pseudozizeeria maha'): 'eats',
#  ('Oxalis brasiliensis', 'Pseudozizeeria maha'): 'eats',
#  ('Oxalis exilis', 'Lucia limbaria'): 'eats',
#  ('Polygonum equisetiforme', 'Zizeeria knysna'): 'eats',
#  ('Medicago sativa', 'Zizeeria knysna'): 'eats',
#  ('Medicago sativa', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Medicago sativa', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Spinacia oleracea', 'Zizeeria knysna'): 'eats',
#  ('Glycine max', 'Zizeeria knysna'): 'eats',
#  ('Amaranthus viridis', 'Zizeeria knysna'): 'eats',
#  ('Badula insularis', 'Zizeeria knysna'): 'visitsFlowersOf',
#  ('Trifolium africanum', 'Actizera stellata'): 'eats',
#  ('Pieris rapae', 'Pieris rapae'): 'pathogenOf',
#  ('Brassica oleracea', 'Pieris rapae'): 'hasHost',
#  ('Armoracia rusticana', 'Pieris rapae'): 'eats',
#  ('Moricandia arvensis', 'Pieris rapae'): 'eats',
#  ('Tropaeolum majus', 'Pieris rapae'): 'eats',
#  ('Thlaspi arvense', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Streptanthus tortuosus', 'Pieris rapae'): 'eats',
#  ('Sisymbrium officinale', 'Pieris rapae'): 'eats',
#  ('Sisymbrium irio', 'Pieris rapae'): 'eats',
#  ('Sinapis arvensis', 'Pieris rapae'): 'eats',
#  ('Rorippa islandica', 'Pieris rapae'): 'eats',
#  ('Rorippa islandica', 'Bibio albipennis'): 'pollinates',
#  ('Rorippa islandica', 'Photinus pyralis'): 'pollinates',
#  ('Rorippa curvisiliqua', 'Pieris rapae'): 'eats',
#  ('Reseda odorata', 'Pieris rapae'): 'eats',
#  ('Raphanus raphanistrum', 'Pieris rapae'): 'eats',
#  ('Matthiola incana', 'Pieris rapae'): 'eats',
#  ('Lunaria annua', 'Pieris rapae'): 'eats',
#  ('Hesperis matronalis', 'Pieris rapae'): 'eats',
#  ('Crateva adansonii', 'Pieris rapae'): 'eats',
#  ('Tarenaya spinosa', 'Pieris rapae'): 'eats',
#  ('Peritoma serrulata', 'Pieris rapae'): 'eats',
#  ('Capparis spinosa', 'Pieris rapae'): 'eats',
#  ('Brassica napus', 'Pieris rapae'): 'eats',
#  ('Brassica juncea', 'Pieris rapae'): 'eats',
#  ('Barbarea vulgaris', 'Pieris rapae'): 'eats',
#  ('Barbarea verna', 'Pieris rapae'): 'eats',
#  ('Barbarea orthoceras', 'Pieris rapae'): 'eats',
#  ('Rorippa indica', 'Pieris rapae'): 'eats',
#  ('Lepidium virginicum', 'Pieris rapae'): 'eats',
#  ('Lepidium virginicum', 'Sapyga centrata'): 'pollinates',
#  ('Lepidium virginicum', 'Ceratina dupla'): 'pollinates',
#  ('Cardamine pratensis', 'Pieris rapae'): 'eats',
#  ('Alliaria petiolata', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Sinapis alba', 'Pieris rapae'): 'eats',
#  ('Rorippa sylvestris', 'Pieris rapae'): 'eats',
#  ('Nicotiana tabacum', 'Pieris rapae'): 'eats',
#  ('Mesembryanthemum crystallinum', 'Pieris rapae'): 'eats',
#  ('Lobularia maritima', 'Pieris rapae'): 'eats',
#  ('Lepidium latifolium', 'Pieris rapae'): 'eats',
#  ('Lepidium draba', 'Pieris rapae'): 'eats',
#  ('Lepidium densiflorum', 'Pieris rapae'): 'eats',
#  ('Lepidium campestre', 'Pieris rapae'): 'eats',
#  ('Hirschfeldia incana', 'Pieris rapae'): 'eats',
#  ('Erysimum capitatum', 'Pieris rapae'): 'eats',
#  ('Eruca vesicaria', 'Pieris rapae'): 'eats',
#  ('Diplotaxis virgata', 'Pieris rapae'): 'eats',
#  ('Descurainia sophia', 'Pieris rapae'): 'eats',
#  ('Caulanthus cooperi', 'Pieris rapae'): 'eats',
#  ('Cardamine diphylla', 'Pieris rapae'): 'eats',
#  ('Capparis sandwichiana', 'Pieris rapae'): 'eats',
#  ('Biscutella auriculata', 'Pieris rapae'): 'eats',
#  ('Aurinia saxatilis', 'Pieris rapae'): 'eats',
#  ('Arabis alpina', 'Pieris rapae'): 'eats',
#  ('Rosmarinus officinalis', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Salvia yangii', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Prunella vulgaris', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Lotus corniculatus', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Pontederia cordata', 'Pieris rapae'): 'eats',
#  ('Pontederia cordata', 'Andrena pruni'): 'pollinates',
#  ('Pontederia cordata', 'Bombus pensylvanicus'): 'eats',
#  ('Malacothrix saxatilis', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Salsola kali', 'Pieris rapae'): 'eats',
#  ('Jasminum polyanthum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Oxalis stricta', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Oxalis stricta', 'Bibio albipennis'): 'pollinates',
#  ('Oxalis stricta', 'Thorybes bathyllus'): 'pollinates',
#  ('Oxalis stricta', 'Mordellistena aspersa'): 'pollinates',
#  ('Oxalis stricta', 'Andrena pruni'): 'pollinates',
#  ('Oxalis stricta', 'Ceratina dupla'): 'pollinates',
#  ('Coreopsis rosea', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Coreopsis verticillata', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Dimorphotheca fruticosa', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Origanum vulgare', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Isocoma menziesii', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Salvia greggii', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Salvia greggii', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Lobelia erinus', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Salvia brandegeei', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Asclepias syriaca', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Asclepias syriaca', 'Cylindromyia rufipes'): 'pollinates',
#  ('Asclepias syriaca', 'Thorybes bathyllus'): 'visitsFlowersOf',
#  ('Cistanthe grandiflora', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Glebionis coronaria', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Salvia mellifera', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Lavandula angustifolia', 'Pieris rapae'): 'hasHost',
#  ('Cucumis sativus', 'Pieris rapae'): 'eats',
#  ('Linnaea grandiflora', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Lepidium didymum', 'Pieris rapae'): 'eats',
#  ('Veronica speciosa', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Podranea ricasoliana', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Ceratostigma plumbaginoides', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Persicaria hydropiperoides', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Pycnanthemum muticum', 'Pieris rapae'): 'eats',
#  ('Lobelia fenestralis', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Symphyotrichum oblongifolium', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Mentha pulegium', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Sambucus nigra', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Carduus acanthoides', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Carduus acanthoides', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Verbena stricta', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Verbena stricta', 'Bibio albipennis'): 'pollinates',
#  ('Verbena stricta', 'Andrena pruni'): 'pollinates',
#  ('Verbena stricta', 'Andrena carlini'): 'pollinates',
#  ('Stachys chamissonis', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Veronica stricta', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Dimorphotheca jucunda', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Apocynum cannabinum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Apocynum cannabinum', 'Cylindromyia rufipes'): 'pollinates',
#  ('Malva nicaeensis', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Conoclinium dissectum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Conoclinium dissectum', 'Thorybes bathyllus'): 'visitsFlowersOf',
#  ('Rheum palmatum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Taraxacum platycarpum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Mentha longifolia', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Arctium lappa', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Conoclinium coelestinum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Baccharis salicifolia', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Aesculus californica', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Ficaria verna', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Bidens laevis', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Bidens laevis', 'Trichiotinus affinis'): 'pollinates',
#  ('Asclepias fascicularis', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Rumex obtusifolius', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Nepeta cataria', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Nepeta cataria', 'Photinus pyralis'): 'pollinates',
#  ('Nepeta cataria', 'Ceratina dupla'): 'pollinates',
#  ('Olearia paniculata', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Solanum chenopodioides', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Thyridia repens', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Echium candicans', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Convolvulus cneorum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Nepeta racemosa', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Euphorbia stictospora', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Monardella villosa', 'Pieris rapae'): 'eats',
#  ('Ballota acetabulosa', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Nepeta faassenii', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Arctium minus', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Arctium minus', 'Trichiotinus affinis'): 'pollinates',
#  ('Dimorphocarpa wislizenii', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Sonchus tenerrimus', 'Pieris rapae'): 'mutualistOf',
#  ('Andryala pinnatifida', 'Pieris rapae'): 'mutualistOf',
#  ('Anacyclus radiatus', 'Pieris rapae'): 'mutualistOf',
#  ('Cedronella canariensis', 'Pieris rapae'): 'mutualistOf',
#  ('Galactites tomentosa', 'Pieris rapae'): 'mutualistOf',
#  ('Tarenaya hassleriana', 'Pieris rapae'): 'eats',
#  ('Gynandropsis gynandra', 'Pieris rapae'): 'eats',
#  ('Crateva formosensis', 'Pieris rapae'): 'eats',
#  ('Turritis glabra', 'Pieris rapae'): 'eats',
#  ('Sisymbrium luteum', 'Pieris rapae'): 'eats',
#  ('Rorippa palustris', 'Pieris rapae'): 'eats',
#  ('Rorippa dubia', 'Pieris rapae'): 'eats',
#  ('Rorippa austriaca', 'Pieris rapae'): 'eats',
#  ('Orychophragmus violaceus', 'Pieris rapae'): 'eats',
#  ('Nasturtium officinale', 'Pieris rapae'): 'eats',
#  ('Eutrema japonicum', 'Pieris rapae'): 'eats',
#  ('Draba nemorosa', 'Pieris rapae'): 'eats',
#  ('Cardamine regeliana', 'Pieris rapae'): 'eats',
#  ('Cardamine nipponica', 'Pieris rapae'): 'eats',
#  ('Cardamine leucantha', 'Pieris rapae'): 'eats',
#  ('Cardamine impatiens', 'Pieris rapae'): 'eats',
#  ('Cardamine debilis', 'Pieris rapae'): 'eats',
#  ('Cardamine appendiculata', 'Pieris rapae'): 'eats',
#  ('Cakile edentula', 'Pieris rapae'): 'eats',
#  ('Arabis stelleri', 'Pieris rapae'): 'eats',
#  ('Arabis serrata', 'Pieris rapae'): 'eats',
#  ('Arabis hirsuta', 'Pieris rapae'): 'eats',
#  ('Arabis flagellosa', 'Pieris rapae'): 'eats',
#  ('Lepidium africanum', 'Pieris rapae'): 'eats',
#  ('Lactuca sativa', 'Pieris rapae'): 'eats',
#  ('Sidalcea pedata', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Ixeridium dentatum', 'Pieris rapae'): 'visitsFlowersOf',
#  ('Podophyllum peltatum', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Podophyllum peltatum', 'Bibio albipennis'): 'pollinates',
#  ('Podophyllum peltatum', 'Cylindromyia rufipes'): 'pollinates',
#  ('Podophyllum peltatum', 'Photinus pyralis'): 'pollinates',
#  ('Podophyllum peltatum', 'Mordellistena aspersa'): 'pollinates',
#  ('Podophyllum peltatum', 'Andrena pruni'): 'pollinates',
#  ('Podophyllum peltatum', 'Sapyga centrata'): 'pollinates',
#  ('Hydrophyllum appendiculatum', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Hydrophyllum appendiculatum', 'Bibio albipennis'): 'pollinates',
#  ('Hydrophyllum appendiculatum', 'Trichiotinus affinis'): 'pollinates',
#  ('Hydrophyllum appendiculatum', 'Sapyga centrata'): 'pollinates',
#  ('Hydrangea arborescens', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Hydrangea arborescens', 'Ceratina dupla'): 'pollinates',
#  ('Sassafras albidum', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Sassafras albidum', 'Leptometopa latipes'): 'visitsFlowersOf',
#  ('Erigenia bulbosa', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Helenium autumnale', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Helenium autumnale', 'Bibio albipennis'): 'pollinates',
#  ('Ipomoea hederacea', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Ipomoea hederacea', 'Bibio albipennis'): 'pollinates',
#  ('Ipomoea hederacea', 'Andrena pruni'): 'pollinates',
#  ('Ipomoea hederacea', 'Ceratina dupla'): 'pollinates',
#  ('Pycnanthemum flexuosum', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Pycnanthemum flexuosum', 'Bibio albipennis'): 'pollinates',
#  ('Rubus canadensis', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Rubus canadensis', 'Sapyga centrata'): 'pollinates',
#  ('Circaea lutetiana', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Sida spinosa', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Sida spinosa', 'Bibio albipennis'): 'pollinates',
#  ('Sida spinosa', 'Andrena pruni'): 'pollinates',
#  ('Maianthemum racemosum', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Maianthemum racemosum', 'Andrena carlini'): 'pollinates',
#  ('Sium suave', 'Ichneumon ambulatorius'): 'visitsFlowersOf',
#  ('Sium suave', 'Leptometopa latipes'): 'visitsFlowersOf',
#  ('Sium suave', 'Andrena pruni'): 'pollinates',
#  ('Sium suave', 'Sapyga centrata'): 'pollinates',
#  ('Pyrus coronaria', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Pyrus coronaria', 'Mordellistena aspersa'): 'pollinates',
#  ('Oxalis violacea', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Oxalis violacea', 'Andrena pruni'): 'pollinates',
#  ('Oxalis violacea', 'Sapyga centrata'): 'pollinates',
#  ('Oxalis violacea', 'Ceratina dupla'): 'pollinates',
#  ('Helianthus laetiflorus', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Helianthus laetiflorus', 'Bibio albipennis'): 'pollinates',
#  ('Helianthus laetiflorus', 'Sapyga centrata'): 'pollinates',
#  ('Mimulus alatus', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Mimulus alatus', 'Bibio albipennis'): 'pollinates',
#  ('Mimulus alatus', 'Andrena pruni'): 'pollinates',
#  ('Mimulus alatus', 'Sapyga centrata'): 'pollinates',
#  ('Mimulus alatus', 'Ceratina dupla'): 'pollinates',
#  ('Symphyotrichum turbinellum', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Symphyotrichum turbinellum', 'Ceratina dupla'): 'pollinates',
#  ('Phlox pilosa', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Phlox pilosa', 'Cylindromyia rufipes'): 'pollinates',
#  ('Phlox pilosa', 'Photinus pyralis'): 'pollinates',
#  ('Erigeron divergens', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Erigeron divergens', 'Cylindromyia rufipes'): 'visitsFlowersOf',
#  ('Erigeron divergens', 'Epeolus pusillus'): 'hasHost',
#  ('Hybanthus concolor', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Crataegus crus-galli', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Liparis liliifolia', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Liparis liliifolia', 'Bibio albipennis'): 'pollinates',
#  ('Liparis liliifolia', 'Leptometopa latipes'): 'pollinates',
#  ('Liparis liliifolia', 'Andrena pruni'): 'pollinates',
#  ('Liparis liliifolia', 'Ceratina dupla'): 'pollinates',
#  ('Asparagus officinalis', 'Ichneumon ambulatorius'): 'pollinates',
#  ('Asparagus officinalis', 'Bibio albipennis'): 'pollinates',
#  ('Asparagus officinalis', 'Thorybes bathyllus'): 'pollinates',
#  ('Asparagus officinalis', 'Ceratina dupla'): 'pollinates',
#  ('Salix humilis', 'Ichneumon ambulatorius'): 'visitsFlowersOf',
#  ('Pastinaca sativa', 'Ichneumon ambulatorius'): 'visitsFlowersOf',
#  ('Pastinaca sativa', 'Photinus pyralis'): 'pollinates',
#  ('Pastinaca sativa', 'Andrena carlini'): 'pollinates',
#  ('Heracleum lanatum', 'Ichneumon ambulatorius'): 'visitsFlowersOf',
#  ('Heracleum lanatum', 'Bibio albipennis'): 'visitsFlowersOf',
#  ('Heracleum lanatum', 'Leptometopa latipes'): 'visitsFlowersOf',
#  ('Heracleum lanatum', 'Thorybes bathyllus'): 'pollinates',
#  ('Heracleum lanatum', 'Trichiotinus affinis'): 'pollinates',
#  ('Cicuta maculata', 'Ichneumon ambulatorius'): 'visitsFlowersOf',
#  ('Cicuta maculata', 'Leptometopa latipes'): 'visitsFlowersOf',
#  ('Oxypolis rigidior', 'Ichneumon ambulatorius'): 'visitsFlowersOf',
#  ('Oxypolis rigidior', 'Bibio albipennis'): 'pollinates',
#  ('Oxypolis rigidior', 'Leptometopa latipes'): 'visitsFlowersOf',
#  ('Oxypolis rigidior', 'Photinus pyralis'): 'pollinates',
#  ('Oxypolis rigidior', 'Ceratina dupla'): 'pollinates',
#  ('Asclepias sullivantii', 'Ichneumon ambulatorius'): 'visitsFlowersOf',
#  ('Heliopsis helianthoides', 'Bibio albipennis'): 'pollinates',
#  ('Heliopsis helianthoides', 'Trichiotinus affinis'): 'pollinates',
#  ('Helianthus tuberosus', 'Bibio albipennis'): 'pollinates',
#  ('Helianthus strumosus', 'Bibio albipennis'): 'pollinates',
#  ('Helianthus strumosus', 'Sapyga centrata'): 'pollinates',
#  ('Persicaria bicornis', 'Bibio albipennis'): 'pollinates',
#  ('Persicaria bicornis', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Persicaria bicornis', 'Photinus pyralis'): 'pollinates',
#  ('Lonicera reticulata', 'Bibio albipennis'): 'pollinates',
#  ('Lonicera reticulata', 'Sapyga centrata'): 'pollinates',
#  ('Lonicera reticulata', 'Ceratina dupla'): 'pollinates',
#  ('Lithospermum canescens', 'Bibio albipennis'): 'pollinates',
#  ('Lithospermum canescens', 'Sapyga centrata'): 'pollinates',
#  ('Lithospermum canescens', 'Ceratina dupla'): 'pollinates',
#  ('Passiflora lutea', 'Bibio albipennis'): 'pollinates',
#  ('Passiflora lutea', 'Andrena carlini'): 'pollinates',
#  ('Panicum virgatum', 'Bibio albipennis'): 'pollinates',
#  ('Panicum virgatum', 'Sapyga centrata'): 'pollinates',
#  ('Panicum virgatum', 'Ceratina dupla'): 'pollinates',
#  ('Mentha arvensis', 'Bibio albipennis'): 'pollinates',
#  ('Mentha arvensis', 'Andrena pruni'): 'pollinates',
#  ('Mentha arvensis', 'Ceratina dupla'): 'pollinates',
#  ('Rubus villosus', 'Bibio albipennis'): 'pollinates',
#  ('Rubus villosus', 'Photinus pyralis'): 'pollinates',
#  ('Rubus villosus', 'Sapyga centrata'): 'pollinates',
#  ('Lindernia dubia', 'Bibio albipennis'): 'pollinates',
#  ('Lindernia dubia', 'Sapyga centrata'): 'pollinates',
#  ('Lindernia dubia', 'Ceratina dupla'): 'pollinates',
#  ('Hypoxis hirsuta', 'Bibio albipennis'): 'pollinates',
#  ('Hypoxis hirsuta', 'Andrena pruni'): 'pollinates',
#  ('Hypoxis hirsuta', 'Sapyga centrata'): 'pollinates',
#  ('Hypoxis hirsuta', 'Ceratina dupla'): 'pollinates',
#  ('Hypoxis hirsuta', 'Andrena carlini'): 'pollinates',
#  ('Hypericum punctatum', 'Bibio albipennis'): 'pollinates',
#  ('Pycnanthemum pilosum', 'Bibio albipennis'): 'pollinates',
#  ('Pycnanthemum pilosum', 'Sapyga centrata'): 'pollinates',
#  ('Pycnanthemum pilosum', 'Andrena carlini'): 'pollinates',
#  ('Ptelea trifoliata', 'Bibio albipennis'): 'pollinates',
#  ('Orobanche uniflora', 'Bibio albipennis'): 'pollinates',
#  ('Orobanche uniflora', 'Asclera puncticollis'): 'pollinates',
#  ('Orobanche uniflora', 'Andrena pruni'): 'pollinates',
#  ('Orobanche uniflora', 'Ceratina dupla'): 'pollinates',
#  ('Parthenocissus quinquefolia', 'Bibio albipennis'): 'pollinates',
#  ('Parthenocissus quinquefolia', 'Epeolus pusillus'): 'pollinates',
#  ('Parthenocissus quinquefolia', 'Mordellistena aspersa'): 'pollinates',
#  ('Parthenocissus quinquefolia', 'Sapyga centrata'): 'pollinates',
#  ('Parthenocissus quinquefolia', 'Andrena carlini'): 'pollinates',
#  ('Myosurus minimus', 'Bibio albipennis'): 'pollinates',
#  ('Myosurus minimus', 'Photinus pyralis'): 'pollinates',
#  ('Myosurus minimus', 'Andrena pruni'): 'pollinates',
#  ('Myosurus minimus', 'Ceratina dupla'): 'pollinates',
#  ('Symphyotrichum lateriflorum', 'Bibio albipennis'): 'pollinates',
#  ('Symphyotrichum pilosum', 'Bibio albipennis'): 'pollinates',
#  ('Symphyotrichum pilosum', 'Thorybes bathyllus'): 'pollinates',
#  ('Symphyotrichum pilosum', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Nelumbo lutea', 'Bibio albipennis'): 'pollinates',
#  ('Nelumbo lutea', 'Andrena pruni'): 'pollinates',
#  ('Nelumbo lutea', 'Ceratina dupla'): 'pollinates',
#  ('Helianthus mollis', 'Bibio albipennis'): 'pollinates',
#  ('Mimulus ringens', 'Bibio albipennis'): 'pollinates',
#  ('Mimulus ringens', 'Photinus pyralis'): 'pollinates',
#  ('Mimulus ringens', 'Mordellistena aspersa'): 'pollinates',
#  ('Mimulus ringens', 'Andrena pruni'): 'pollinates',
#  ('Mimulus ringens', 'Sapyga centrata'): 'pollinates',
#  ('Mimulus ringens', 'Ceratina dupla'): 'pollinates',
#  ('Mimulus ringens', 'Bombus pensylvanicus'): 'pollinates',
#  ('Solidago nemoralis', 'Bibio albipennis'): 'pollinates',
#  ('Solidago nemoralis', 'Sapyga centrata'): 'pollinates',
#  ('Lilium superbum', 'Bibio albipennis'): 'pollinates',
#  ('Lilium superbum', 'Sapyga centrata'): 'pollinates',
#  ('Lilium superbum', 'Ceratina dupla'): 'pollinates',
#  ('Lilium superbum', 'Andrena carlini'): 'pollinates',
#  ('Hibiscus laevis', 'Bibio albipennis'): 'pollinates',
#  ('Hibiscus laevis', 'Andrena carlini'): 'pollinates',
#  ('Mertensia virginica', 'Bibio albipennis'): 'pollinates',
#  ('Mertensia virginica', 'Mordellistena aspersa'): 'pollinates',
#  ('Mertensia virginica', 'Andrena pruni'): 'pollinates',
#  ('Mertensia virginica', 'Ceratina dupla'): 'pollinates',
#  ('Mertensia virginica', 'Andrena carlini'): 'pollinates',
#  ('Ranunculus recurvatus', 'Bibio albipennis'): 'pollinates',
#  ('Ranunculus recurvatus', 'Cylindromyia rufipes'): 'pollinates',
#  ('Ranunculus recurvatus', 'Epeolus pusillus'): 'pollinates',
#  ('Solidago speciosa', 'Bibio albipennis'): 'pollinates',
#  ('Solidago speciosa', 'Mordellistena aspersa'): 'pollinates',
#  ('Solidago speciosa', 'Andrena pruni'): 'pollinates',
#  ('Solidago speciosa', 'Sapyga centrata'): 'pollinates',
#  ('Lespedeza virginica', 'Bibio albipennis'): 'pollinates',
#  ('Lespedeza virginica', 'Thorybes bathyllus'): 'eats',
#  ('Lespedeza virginica', 'Ceratina dupla'): 'pollinates',
#  ('Lespedeza virginica', 'Andrena carlini'): 'pollinates',
#  ('Ranunculus fascicularis', 'Bibio albipennis'): 'pollinates',
#  ('Ranunculus fascicularis', 'Bombus pensylvanicus'): 'pollinates',
#  ('Monarda fistulosa', 'Bibio albipennis'): 'pollinates',
#  ('Monarda fistulosa', 'Andrena pruni'): 'pollinates',
#  ('Monarda fistulosa', 'Ceratina dupla'): 'pollinates',
#  ('Monarda fistulosa', 'Bombus pensylvanicus'): 'pollinates',
#  ('Liatris pycnostachya', 'Bibio albipennis'): 'pollinates',
#  ('Liatris pycnostachya', 'Ceratina dupla'): 'pollinates',
#  ('Iris versicolor', 'Bibio albipennis'): 'pollinates',
#  ('Iris versicolor', 'Sapyga centrata'): 'pollinates',
#  ('Iris versicolor', 'Ceratina dupla'): 'pollinates',
#  ('Ipomoea purpurea', 'Bibio albipennis'): 'pollinates',
#  ('Ipomoea purpurea', 'Cylindromyia rufipes'): 'pollinates',
#  ('Ipomoea purpurea', 'Sapyga centrata'): 'pollinates',
#  ('Ipomoea purpurea', 'Ceratina dupla'): 'pollinates',
#  ('Taenidia integerrima', 'Bibio albipennis'): 'pollinates',
#  ('Taenidia integerrima', 'Photinus pyralis'): 'pollinates',
#  ('Taenidia integerrima', 'Sapyga centrata'): 'pollinates',
#  ('Zizia aurea', 'Bibio albipennis'): 'visitsFlowersOf',
#  ('Zizia aurea', 'Andrena carlini'): 'pollinates',
#  ('Salix ambigua', 'Bibio albipennis'): 'visitsFlowersOf',
#  ('Apocynum androsaemifolium', 'Cylindromyia rufipes'): 'pollinates',
#  ('Apocynum androsaemifolium', 'Trichiotinus affinis'): 'pollinates',
#  ('Castilleja coccinea', 'Cylindromyia rufipes'): 'pollinates',
#  ('Desmodium canescens', 'Cylindromyia rufipes'): 'pollinates',
#  ('Nabalus crepidineus', 'Cylindromyia rufipes'): 'pollinates',
#  ('Ipomoea pandurata', 'Cylindromyia rufipes'): 'pollinates',
#  ('Ipomoea pandurata', 'Ceratina dupla'): 'pollinates',
#  ('Arnoglossum plantagineum', 'Cylindromyia rufipes'): 'pollinates',
#  ('Comandra umbellata', 'Cylindromyia rufipes'): 'pollinates',
#  ('Phyla lanceolata', 'Cylindromyia rufipes'): 'pollinates',
#  ('Phyla lanceolata', 'Andrena pruni'): 'pollinates',
#  ('Phyla lanceolata', 'Ceratina dupla'): 'pollinates',
#  ('Dicentra cucullaria', 'Cylindromyia rufipes'): 'pollinates',
#  ('Chamaecrista fasciculata', 'Cylindromyia rufipes'): 'pollinates',
#  ('Marrubium vulgare', 'Cylindromyia rufipes'): 'pollinates',
#  ('Marrubium vulgare', 'Andrena pruni'): 'pollinates',
#  ('Marrubium vulgare', 'Sapyga centrata'): 'pollinates',
#  ('Marrubium vulgare', 'Ceratina dupla'): 'pollinates',
#  ('Asclepias purpurascens', 'Cylindromyia rufipes'): 'pollinates',
#  ('Asclepias purpurascens', 'Thorybes bathyllus'): 'pollinates',
#  ('Asclepias purpurascens', 'Ceratina dupla'): 'pollinates',
#  ('Desmodium illinoense', 'Cylindromyia rufipes'): 'pollinates',
#  ('Planodes virginicum', 'Cylindromyia rufipes'): 'pollinates',
#  ('Oenothera biennis', 'Cylindromyia rufipes'): 'pollinates',
#  ('Oenothera biennis', 'Andrena pruni'): 'pollinates',
#  ('Oenothera biennis', 'Ceratina dupla'): 'pollinates',
#  ('Dipsacus sylvestris', 'Cylindromyia rufipes'): 'pollinates',
#  ('Diospyros virginiana', 'Cylindromyia rufipes'): 'pollinates',
#  ('Erigeron pulchellus', 'Cylindromyia rufipes'): 'pollinates',
#  ('Asclepias incarnata', 'Cylindromyia rufipes'): 'pollinates',
#  ('Asclepias incarnata', 'Trichiotinus affinis'): 'pollinates',
#  ('Oenothera fruticosa', 'Cylindromyia rufipes'): 'pollinates',
#  ('Oenothera fruticosa', 'Ceratina dupla'): 'pollinates',
#  ('Bidens frondosa', 'Cylindromyia rufipes'): 'pollinates',
#  ('Coreopsis tripteris', 'Cylindromyia rufipes'): 'pollinates',
#  ('Coreopsis tripteris', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Abutilon theophrasti', 'Cylindromyia rufipes'): 'pollinates',
#  ('Philadelphus inodorus', 'Cylindromyia rufipes'): 'pollinates',
#  ('Philadelphus inodorus', 'Photinus pyralis'): 'pollinates',
#  ('Philadelphus inodorus', 'Trichiotinus affinis'): 'pollinates',
#  ('Philadelphus inodorus', 'Asclera puncticollis'): 'pollinates',
#  ('Philadelphus inodorus', 'Sapyga centrata'): 'pollinates',
#  ('Persicaria hydropiper', 'Leptometopa latipes'): 'pollinates',
#  ('Persicaria hydropiper', 'Mordellistena aspersa'): 'pollinates',
#  ('Persicaria hydropiper', 'Andrena pruni'): 'pollinates',
#  ('Persicaria hydropiper', 'Sapyga centrata'): 'pollinates',
#  ('Gnaphalium polycephalum', 'Leptometopa latipes'): 'pollinates',
#  ('Gnaphalium polycephalum', 'Trichiotinus affinis'): 'pollinates',
#  ('Ludwigia polycarpa', 'Leptometopa latipes'): 'pollinates',
#  ('Ludwigia polycarpa', 'Ceratina dupla'): 'pollinates',
#  ('Robinia pseudoacacia', 'Leptometopa latipes'): 'pollinates',
#  ('Robinia pseudoacacia', 'Asclera puncticollis'): 'pollinates',
#  ('Silphium laciniatum', 'Leptometopa latipes'): 'pollinates',
#  ('Silphium laciniatum', 'Andrena pruni'): 'pollinates',
#  ('Silphium laciniatum', 'Sapyga centrata'): 'pollinates',
#  ('Ruellia ciliosa', 'Leptometopa latipes'): 'pollinates',
#  ('Ruellia ciliosa', 'Sapyga centrata'): 'pollinates',
#  ('Silphium perfoliatum', 'Leptometopa latipes'): 'pollinates',
#  ('Silphium perfoliatum', 'Andrena pruni'): 'pollinates',
#  ('Linaria vulgaris', 'Leptometopa latipes'): 'pollinates',
#  ('Linaria vulgaris', 'Trichiotinus affinis'): 'pollinates',
#  ('Linaria vulgaris', 'Mordellistena aspersa'): 'pollinates',
#  ('Linaria vulgaris', 'Andrena pruni'): 'pollinates',
#  ('Linaria vulgaris', 'Sapyga centrata'): 'pollinates',
#  ('Linaria vulgaris', 'Ceratina dupla'): 'pollinates',
#  ('Linaria vulgaris', 'Andrena carlini'): 'pollinates',
#  ('Fragaria virginiana', 'Leptometopa latipes'): 'pollinates',
#  ('Fragaria virginiana', 'Trichiotinus affinis'): 'pollinates',
#  ('Strophostyles leiosperma', 'Thorybes bathyllus'): 'eats',
#  ('Strophostyles leiosperma', 'Sapyga centrata'): 'pollinates',
#  ('Lespedeza capitata', 'Thorybes bathyllus'): 'eats',
#  ('Lespedeza capitata', 'Sapyga centrata'): 'pollinates',
#  ('Lespedeza capitata', 'Ceratina dupla'): 'pollinates',
#  ('Desmodium paniculatum', 'Thorybes bathyllus'): 'eats',
#  ('Apios americana', 'Thorybes bathyllus'): 'eats',
#  ('Trifolium pratense', 'Thorybes bathyllus'): 'eats',
#  ('Strophostyles helvula', 'Thorybes bathyllus'): 'eats',
#  ('Strophostyles helvula', 'Sapyga centrata'): 'pollinates',
#  ('Lespedeza hirta', 'Thorybes bathyllus'): 'eats',
#  ('Osmorhiza longistylis', 'Thorybes bathyllus'): 'pollinates',
#  ('Osmorhiza longistylis', 'Andrena pruni'): 'pollinates',
#  ('Osmorhiza longistylis', 'Ceratina dupla'): 'pollinates',
#  ('Johanneshowellia puberula', 'Epeolus pusillus'): 'hasHost',
#  ('Ericameria nauseosa', 'Epeolus pusillus'): 'hasHost',
#  ('Chrysothamnus depressus', 'Epeolus pusillus'): 'hasHost',
#  ('Gutierrezia sarothrae', 'Epeolus pusillus'): 'hasHost',
#  ('Symphyotrichum chilense', 'Epeolus pusillus'): 'hasHost',
#  ('Symphyotrichum chilense', 'Paragus haemorrhous'): 'eats',
#  ('Senecio spartioides', 'Epeolus pusillus'): 'hasHost',
#  ('Lorandersonia linifolia', 'Epeolus pusillus'): 'hasHost',
#  ('Heterotheca villosa', 'Epeolus pusillus'): 'hasHost',
#  ('Symphyotrichum eatonii', 'Epeolus pusillus'): 'hasHost',
#  ('Lobelia cardinalis', 'Epeolus pusillus'): 'pollinates',
#  ('Lobelia cardinalis', 'Mordellistena aspersa'): 'pollinates',
#  ('Lobelia cardinalis', 'Andrena pruni'): 'pollinates',
#  ('Lobelia cardinalis', 'Sapyga centrata'): 'pollinates',
#  ('Lobelia cardinalis', 'Ceratina dupla'): 'pollinates',
#  ('Melanthium virginicum', 'Epeolus pusillus'): 'pollinates',
#  ('Melanthium virginicum', 'Sapyga centrata'): 'pollinates',
#  ('Melanthium virginicum', 'Ceratina dupla'): 'pollinates',
#  ('Melanthium virginicum', 'Andrena carlini'): 'pollinates',
#  ('Tephrosia virginiana', 'Epeolus pusillus'): 'pollinates',
#  ('Tephrosia virginiana', 'Photinus pyralis'): 'pollinates',
#  ('Tephrosia virginiana', 'Sapyga centrata'): 'pollinates',
#  ('Maianthemum stellatum', 'Epeolus pusillus'): 'pollinates',
#  ('Solidago serotina', 'Epeolus pusillus'): 'pollinates',
#  ('Solidago serotina', 'Sapyga centrata'): 'pollinates',
#  ('Monarda bradburiana', 'Epeolus pusillus'): 'pollinates',
#  ('Monarda bradburiana', 'Ceratina dupla'): 'pollinates',
#  ('Ranunculus abortivus', 'Epeolus pusillus'): 'pollinates',
#  ('Ranunculus abortivus', 'Andrena pruni'): 'pollinates',
#  ('Solidago canadensis', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Helianthus divaricatus', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Erigeron canadensis', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Boltonia asteroides', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Bidens aristosa', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Symphyotrichum cordifolium', 'Epeolus pusillus'): 'visitsFlowersOf',
#  ('Fallopia scandens', 'Photinus pyralis'): 'pollinates',
#  ('Trifolium hybridum', 'Photinus pyralis'): 'pollinates',
#  ('Trifolium hybridum', 'Mordellistena aspersa'): 'pollinates',
#  ('Salix longifolia', 'Photinus pyralis'): 'pollinates',
#  ('Solanum rostratum', 'Photinus pyralis'): 'pollinates',
#  ('Polemonium reptans', 'Photinus pyralis'): 'pollinates',
#  ('Polemonium reptans', 'Mordellistena aspersa'): 'pollinates',
#  ('Prunus americana', 'Photinus pyralis'): 'pollinates',
#  ('Salix nigra', 'Photinus pyralis'): 'pollinates',
#  ('Salix nigra', 'Asclera puncticollis'): 'pollinates',
#  ('Salix nigra', 'Andrena pruni'): 'pollinates',
#  ('Salix nigra', 'Sapyga centrata'): 'pollinates',
#  ('Viola striata', 'Photinus pyralis'): 'pollinates',
#  ('Viola striata', 'Andrena carlini'): 'pollinates',
#  ('Potentilla canadensis', 'Photinus pyralis'): 'pollinates',
#  ('Potentilla canadensis', 'Andrena carlini'): 'pollinates',
#  ('Psoralea onobrychis', 'Photinus pyralis'): 'pollinates',
#  ('Trillium sessile', 'Photinus pyralis'): 'pollinates',
#  ('Trillium sessile', 'Andrena carlini'): 'pollinates',
#  ('Rorippa teres', 'Photinus pyralis'): 'pollinates',
#  ('Rorippa teres', 'Sapyga centrata'): 'pollinates',
#  ('Mollugo verticillata', 'Photinus pyralis'): 'pollinates',
#  ('Mollugo verticillata', 'Andrena pruni'): 'pollinates',
#  ('Mollugo verticillata', 'Ceratina dupla'): 'pollinates',
#  ('Mollugo verticillata', 'Andrena carlini'): 'pollinates',
#  ('Solidago ulmifolia', 'Photinus pyralis'): 'pollinates',
#  ('Populus deltoides', 'Photinus pyralis'): 'pollinates',
#  ('Populus deltoides', 'Mordellistena aspersa'): 'pollinates',
#  ('Phlox glaberrima', 'Photinus pyralis'): 'pollinates',
#  ('Phlox glaberrima', 'Andrena pruni'): 'pollinates',
#  ('Phlox glaberrima', 'Andrena carlini'): 'pollinates',
#  ('Stellaria longifolia', 'Photinus pyralis'): 'pollinates',
#  ('Senna marilandica', 'Trichiotinus affinis'): 'pollinates',
#  ('Lythrum alatum', 'Trichiotinus affinis'): 'pollinates',
#  ('Lythrum alatum', 'Andrena pruni'): 'pollinates',
#  ('Lythrum alatum', 'Ceratina dupla'): 'pollinates',
#  ('Clematis virginiana', 'Trichiotinus affinis'): 'pollinates',
#  ('Hypericum ascyron', 'Trichiotinus affinis'): 'pollinates',
#  ('Hypericum ascyron', 'Ceratina dupla'): 'pollinates',
#  ('Echinacea pallida', 'Trichiotinus affinis'): 'pollinates',
#  ('Asclepias tuberosa', 'Trichiotinus affinis'): 'pollinates',
#  ('Asclepias tuberosa', 'Ceratina dupla'): 'pollinates',
#  ('Echinacea purpurea', 'Trichiotinus affinis'): 'pollinates',
#  ('Persicaria amphibia', 'Trichiotinus affinis'): 'pollinates',
#  ('Nothoscordum bivalve', 'Trichiotinus affinis'): 'pollinates',
#  ('Nothoscordum bivalve', 'Ceratina dupla'): 'pollinates',
#  ('Nothoscordum bivalve', 'Bombus pensylvanicus'): 'pollinates',
#  ('Polytaenia nuttallii', 'Trichiotinus affinis'): 'pollinates',
#  ('Polytaenia nuttallii', 'Mordellistena aspersa'): 'pollinates',
#  ('Polytaenia nuttallii', 'Andrena pruni'): 'pollinates',
#  ('Rhamnus lanceolata', 'Trichiotinus affinis'): 'pollinates',
#  ('Rhamnus lanceolata', 'Sapyga centrata'): 'pollinates',
#  ('Rhamnus lanceolata', 'Andrena carlini'): 'pollinates',
#  ('Crataegus mollis', 'Trichiotinus affinis'): 'pollinates',
#  ('Crataegus mollis', 'Ceratina dupla'): 'pollinates',
#  ('Cynoglossum officinale', 'Trichiotinus affinis'): 'pollinates',
#  ('Cynoglossum officinale', 'Ceratina dupla'): 'pollinates',
#  ('Populus tremuloides', 'Trichiotinus affinis'): 'pollinates',
#  ('Symphoricarpos orbiculatus', 'Trichiotinus affinis'): 'pollinates',
#  ('Ambrosia trifida', 'Trichiotinus affinis'): 'pollinates',
#  ('Calochortus gunnisonii', 'Trichiotinus affinis'): 'visitsFlowersOf',
#  ('Salix cordata', 'Mordellistena aspersa'): 'pollinates',
#  ('Salix cordata', 'Andrena pruni'): 'pollinates',
#  ('Physalis virginiana', 'Mordellistena aspersa'): 'pollinates',
#  ('Physalis hispida', 'Mordellistena aspersa'): 'pollinates',
#  ('Sanicula marilandica', 'Mordellistena aspersa'): 'pollinates',
#  ('Sanicula marilandica', 'Andrena pruni'): 'pollinates',
#  ('Polygala sanguinea', 'Mordellistena aspersa'): 'pollinates',
#  ('Polygala sanguinea', 'Andrena pruni'): 'pollinates',
#  ('Veronica peregrina', 'Mordellistena aspersa'): 'pollinates',
#  ('Veronica peregrina', 'Andrena carlini'): 'pollinates',
#  ('Veronica arvensis', 'Mordellistena aspersa'): 'pollinates',
#  ('Veronica arvensis', 'Andrena carlini'): 'pollinates',
#  ('Ulmus americana', 'Mordellistena aspersa'): 'pollinates',
#  ('Ulmus americana', 'Sapyga centrata'): 'pollinates',
#  ('Ulmus americana', 'Andrena carlini'): 'pollinates',
#  ('Phryma leptostachya', 'Mordellistena aspersa'): 'pollinates',
#  ('Phryma leptostachya', 'Ceratina dupla'): 'visitsFlowersOf',
#  ('Vitis cordifolia', 'Mordellistena aspersa'): 'pollinates',
#  ('Vitis cordifolia', 'Sapyga centrata'): 'pollinates',
#  ('Vitis cordifolia', 'Andrena carlini'): 'pollinates',
#  ('Solanum carolinense', 'Mordellistena aspersa'): 'pollinates',
#  ('Solanum carolinense', 'Sapyga centrata'): 'pollinates',
#  ('Samolus valerandi', 'Asclera puncticollis'): 'pollinates',
#  ('Samolus valerandi', 'Andrena pruni'): 'pollinates',
#  ('Stylosanthes biflora', 'Asclera puncticollis'): 'pollinates',
#  ('Stylosanthes biflora', 'Sapyga centrata'): 'pollinates',
#  ('Tradescantia virginiana', 'Andrena pruni'): 'pollinates',
#  ('Saponaria officinalis', 'Andrena pruni'): 'pollinates',
#  ('Toxicodendron pubescens', 'Andrena pruni'): 'pollinates',
#  ('Toxicodendron pubescens', 'Sapyga centrata'): 'pollinates',
#  ('Lobelia siphilitica', 'Andrena pruni'): 'pollinates',
#  ('Lobelia siphilitica', 'Sapyga centrata'): 'pollinates',
#  ('Lobelia siphilitica', 'Ceratina dupla'): 'pollinates',
#  ('Lobelia siphilitica', 'Bombus pensylvanicus'): 'hasHost',
#  ('Lobelia spicata', 'Andrena pruni'): 'pollinates',
#  ('Lobelia spicata', 'Ceratina dupla'): 'pollinates',
#  ('Lobelia inflata', 'Andrena pruni'): 'pollinates',
#  ('Lobelia inflata', 'Ceratina dupla'): 'pollinates',
#  ('Penstemon hirsutus', 'Andrena pruni'): 'pollinates',
#  ('Scutellaria lateriflora', 'Andrena pruni'): 'pollinates',
#  ('Vernonia fasciculata', 'Andrena pruni'): 'pollinates',
#  ('Vernonia fasciculata', 'Andrena carlini'): 'pollinates',
#  ('Ratibida pinnata', 'Andrena pruni'): 'pollinates',
#  ('Ratibida pinnata', 'Sapyga centrata'): 'pollinates',
#  ('Ratibida pinnata', 'Ceratina dupla'): 'pollinates',
#  ('Lysimachia lanceolata', 'Andrena pruni'): 'pollinates',
#  ('Rudbeckia laciniata', 'Andrena pruni'): 'pollinates',
#  ('Pycnanthemum virginianum', 'Andrena pruni'): 'pollinates',
#  ('Pycnanthemum virginianum', 'Andrena carlini'): 'pollinates',
#  ('Sicyos angulatus', 'Andrena pruni'): 'pollinates',
#  ('Triosteum perfoliatum', 'Andrena pruni'): 'pollinates',
#  ('Triosteum perfoliatum', 'Andrena carlini'): 'pollinates',
#  ('Nuphar advena', 'Andrena pruni'): 'pollinates',
#  ('Nuphar advena', 'Ceratina dupla'): 'pollinates',
#  ('Glechoma hederacea', 'Andrena pruni'): 'pollinates',
#  ('Glechoma hederacea', 'Ceratina dupla'): 'pollinates',
#  ('Glechoma hederacea', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Sanguinaria canadensis', 'Andrena pruni'): 'pollinates',
#  ('Sanguinaria canadensis', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Rudbeckia triloba', 'Andrena pruni'): 'pollinates',
#  ('Rudbeckia triloba', 'Sapyga centrata'): 'pollinates',
#  ('Liatris scariosa', 'Andrena pruni'): 'pollinates',
#  ('Liatris scariosa', 'Ceratina dupla'): 'pollinates',
#  ('Lonicera sempervirens', 'Andrena pruni'): 'pollinates',
#  ('Lonicera sempervirens', 'Ceratina dupla'): 'pollinates',
#  ('Silphium terebinthinaceum', 'Andrena pruni'): 'pollinates',
#  ('Silphium terebinthinaceum', 'Sapyga centrata'): 'pollinates',
#  ('Sanicula canadensis', 'Andrena pruni'): 'pollinates',
#  ('Sisyrinchium angustifolium', 'Andrena pruni'): 'pollinates',
#  ('Enemion biternatum', 'Andrena pruni'): 'pollinates',
#  ('Enemion biternatum', 'Sapyga centrata'): 'visitsFlowersOf',
#  ('Enemion biternatum', 'Ceratina dupla'): 'pollinates',
#  ('Enemion biternatum', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Tilia americana', 'Andrena pruni'): 'pollinates',
#  ('Lespedeza procumbens', 'Andrena pruni'): 'pollinates',
#  ('Lespedeza procumbens', 'Ceratina dupla'): 'pollinates',
#  ('Stachys palustris', 'Andrena pruni'): 'pollinates',
#  ('Scrophularia marilandica', 'Andrena pruni'): 'pollinates',
#  ('Sambucus canadensis', 'Sapyga centrata'): 'pollinates',
#  ('Sambucus canadensis', 'Bombus pensylvanicus'): 'pollinates',
#  ('Thalictrum dasycarpum', 'Sapyga centrata'): 'pollinates',
#  ('Teucrium canadense', 'Sapyga centrata'): 'pollinates',
#  ('Hypericum cistifolium', 'Sapyga centrata'): 'pollinates',
#  ('Impatiens pallida', 'Sapyga centrata'): 'pollinates',
#  ('Proboscidea louisianica', 'Sapyga centrata'): 'pollinates',
#  ('Proboscidea louisianica', 'Ceratina dupla'): 'pollinates',
#  ('Smilax hispida', 'Sapyga centrata'): 'pollinates',
#  ('Campsis radicans', 'Sapyga centrata'): 'pollinates',
#  ('Taraxacum officinale', 'Sapyga centrata'): 'pollinates',
#  ('Rhus canadensis', 'Sapyga centrata'): 'pollinates',
#  ('Rhus canadensis', 'Andrena carlini'): 'pollinates',
#  ('Boechera dentata', 'Sapyga centrata'): 'visitsFlowersOf',
#  ('Lycopus americanus', 'Ceratina dupla'): 'pollinates',
#  ('Collinsia verna', 'Ceratina dupla'): 'pollinates',
#  ('Lactuca floridana', 'Ceratina dupla'): 'pollinates',
#  ('Lactuca canadensis', 'Ceratina dupla'): 'pollinates',
#  ('Krigia biflora', 'Ceratina dupla'): 'pollinates',
#  ('Parthenium integrifolium', 'Ceratina dupla'): 'pollinates',
#  ('Leonurus cardiaca', 'Ceratina dupla'): 'pollinates',
#  ('Aquilegia canadensis', 'Ceratina dupla'): 'pollinates',
#  ('Acer saccharinum', 'Ceratina dupla'): 'pollinates',
#  ('Antennaria plantaginifolia', 'Ceratina dupla'): 'pollinates',
#  ('Symphyotrichum anomalum', 'Ceratina dupla'): 'pollinates',
#  ('Baptisia alba', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Monarda citriodora', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Plectocephalus americanus', 'Bombus pensylvanicus'): 'eats',
#  ('Penstemon laxiflorus', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Sarracenia alata', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Zinnia elegans', 'Bombus pensylvanicus'): 'eats',
#  ('Eryngium leavenworthii', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Sophora secundiflora', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Callirhoe bushii', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Salvia farinacea', 'Bombus pensylvanicus'): 'eats',
#  ('Havardia pallens', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Tradescantia sillamontana', 'Bombus pensylvanicus'): 'eats',
#  ('Verbesina virginica', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Delphinium exaltatum', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Oenothera speciosa', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Asclepias viridis', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Wisteria frutescens', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Centratherum punctatum', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Pavonia lasiopetala', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Cardamine angustata', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Cardamine angustata', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Aesculus sylvatica', 'Bombus pensylvanicus'): 'visitsFlowersOf',
#  ('Viola pubescens', 'Bombus pensylvanicus'): 'pollinates',
#  ('Viola pubescens', 'Andrena carlini'): 'pollinates',
#  ('Trillium catesbaei', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Stellaria pubera', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Claytonia virginica', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Valerianella radiata', 'Andrena carlini'): 'pollinates',
#  ('Uvularia grandiflora', 'Andrena carlini'): 'pollinates',
#  ('Galium trifidum', 'Andrena carlini'): 'pollinates',
#  ('Viburnum prunifolium', 'Andrena carlini'): 'pollinates',
#  ('Veronicastrum virginicum', 'Andrena carlini'): 'pollinates',
#  ('Viola sagittata', 'Andrena carlini'): 'pollinates',
#  ('Verbascum thapsus', 'Andrena carlini'): 'pollinates',
#  ('Viola pedatifida', 'Andrena carlini'): 'pollinates',
#  ('Verbesina helianthoides', 'Andrena carlini'): 'pollinates',
#  ('Zanthoxylum americanum', 'Andrena carlini'): 'pollinates',
#  ('Solidago missouriensis', 'Andrena carlini'): 'pollinates',
#  ('Viola cucullata', 'Andrena carlini'): 'pollinates',
#  ('Viola pedata', 'Andrena carlini'): 'pollinates',
#  ('Verbena simplex', 'Andrena carlini'): 'pollinates',
#  ('Vitis vulpina', 'Andrena carlini'): 'pollinates',
#  ('Verbena urticifolia', 'Andrena carlini'): 'pollinates',
#  ('Staphylea trifolia', 'Andrena carlini'): 'pollinates',
#  ('Anemone americana', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Erythronium umbilicatum', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Erythronium albidum', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Cardamine concatenata', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Chamaedaphne calyculata', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Ilex mucronata', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Ledum groenlandicum', 'Andrena carlini'): 'pollinates',
#  ('Vaccinium myrtilloides', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Salix fragilis', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Rhododendron groenlandicum', 'Andrena carlini'): 'visitsFlowersOf',
#  ('Murdannia keisak', 'Paragus haemorrhous'): 'visitsFlowersOf',
#  ('Aster hispidus', 'Paragus haemorrhous'): 'pollinates',
#  ('Solidago virgaurea', 'Paragus haemorrhous'): 'pollinates',
#  ('Helichrysum stoechas', 'Paragus haemorrhous'): 'pollinates',
#  ('Mosla dianthera', 'Paragus haemorrhous'): 'visitsFlowersOf'}
