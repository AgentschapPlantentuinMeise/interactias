# %% [markdown]
# # Interactias Network
#
# One way of examining the impact of invasive species is to look at all their interactions and the interations those organisms have with each other. This full interaction network gives you a good idea whether a species might be a "keystone" species
#
# *"The concept of the "keystone species" is redefined to allow for the a priori prediction of these species within ecosystems. A keystone species is held to be a **strongly interacting species** whose top-down effect on species diversity and competition is large relative to its biomass dominance within a functional group."*
#
# Davic, R. D. (2003). Linking keystone species and functional groups: a new operational definition of the keystone species concept. Conservation Ecology, 7(1).
#
# I will harvest species interactions data from GLOBI (https://www.globalbioticinteractions.org/) to discover the species that interact with an invasive species. I will then harvest all the interactions for those species to create two tiers of interactions. I will then create a network diagram to visualize this.
#
# This notebook takes considerable insperation and code from Yikang Li's project on GLoBI (https://curiositydata.org/part1_globi_access/).

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the GLoBI data
#
# The current snapshot of GLoBI was taken on 2019-11-05 from https://depot.globalbioticinteractions.org/snapshot/target/data/tsv/interactions.tsv.gz

# %%
# This takes a few minutes to load in.
# the low_memory=False property will get rid of a warning, but will not help if there is really no memory left
data = pd.read_csv('C://Users//quentin//Documents//interactias//interactias//data//interactions.tsv', delimiter='\t', encoding='utf-8', low_memory=False)
len(data)
# Out:
# 3878740

# %%
# Take a little look at the data to make sure it makes sense
data.head()
# Out:
#   sourceTaxonId                                     sourceTaxonIds  \
# 0  EOL:12001247  EOL:12001247 | OTT:133330 | IRMNG:11733708 | N...
# 1  EOL:12001247  EOL:12001247 | OTT:133330 | IRMNG:11733708 | N...
# 2  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
# 3  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
# 4  EOL:12001243  EOL:12001243 | WD:Q13393577 | OTT:550603 | WOR...
#
#              sourceTaxonName sourceTaxonRank  \
# 0       Leptoconchus massini         species
# 1       Leptoconchus massini         species
# 2  Leptoconchus inpleuractis         species
# 3  Leptoconchus inpleuractis         species
# 4  Leptoconchus inpleuractis         species
#
#                                 sourceTaxonPathNames  \
# 0  Animalia | Mollusca | Gastropoda | Neogastropo...
# 1  Animalia | Mollusca | Gastropoda | Neogastropo...
# 2  Animalia | Mollusca | Gastropoda | Neogastropo...
# 3  Animalia | Mollusca | Gastropoda | Neogastropo...
# 4  Animalia | Mollusca | Gastropoda | Neogastropo...
#
#                                   sourceTaxonPathIds  \
# 0  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 1  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 2  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 3  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
# 4  EOL:1 | EOL:2195 | EOL:2366 | EOL:2447 | EOL:4...
#
#                             sourceTaxonPathRankNames  \
# 0  kingdom | phylum | class | order | superfamily...
# 1  kingdom | phylum | class | order | superfamily...
# 2  kingdom | phylum | class | order | superfamily...
# 3  kingdom | phylum | class | order | superfamily...
# 4  kingdom | phylum | class | order | superfamily...
#
#       sourceTaxonSpeciesName sourceTaxonSpeciesId sourceTaxonGenusName  ...  \
# 0       Leptoconchus massini         EOL:12001247         Leptoconchus  ...
# 1       Leptoconchus massini         EOL:12001247         Leptoconchus  ...
# 2  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
# 3  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
# 4  Leptoconchus inpleuractis         EOL:12001243         Leptoconchus  ...
#
#   eventDateUnixEpoch                          argumentTypeId  \
# 0                NaN  https://en.wiktionary.org/wiki/support
# 1                NaN  https://en.wiktionary.org/wiki/support
# 2                NaN  https://en.wiktionary.org/wiki/support
# 3                NaN  https://en.wiktionary.org/wiki/support
# 4                NaN  https://en.wiktionary.org/wiki/support
#
#                                    referenceCitation  \
# 0  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 1  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 2  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 3  Gittenberger, A., Gittenberger, E. (2011). Cry...
# 4  Gittenberger, A., Gittenberger, E. (2011). Cry...
#
#                 referenceDoi referenceUrl  \
# 0  10.1007/s13127-011-0039-1          NaN
# 1  10.1007/s13127-011-0039-1          NaN
# 2  10.1007/s13127-011-0039-1          NaN
# 3  10.1007/s13127-011-0039-1          NaN
# 4  10.1007/s13127-011-0039-1          NaN
#
#                                       sourceCitation  \
# 0  Jorrit H. Poelen. 2014. Species associations m...
# 1  Jorrit H. Poelen. 2014. Species associations m...
# 2  Jorrit H. Poelen. 2014. Species associations m...
# 3  Jorrit H. Poelen. 2014. Species associations m...
# 4  Jorrit H. Poelen. 2014. Species associations m...
#
#                  sourceNamespace  \
# 0  FloraVincent/template-dataset
# 1  FloraVincent/template-dataset
# 2  FloraVincent/template-dataset
# 3  FloraVincent/template-dataset
# 4  FloraVincent/template-dataset
#
#                                     sourceArchiveURI sourceDOI  \
# 0  https://github.com/FloraVincent/template-datas...       NaN
# 1  https://github.com/FloraVincent/template-datas...       NaN
# 2  https://github.com/FloraVincent/template-datas...       NaN
# 3  https://github.com/FloraVincent/template-datas...       NaN
# 4  https://github.com/FloraVincent/template-datas...       NaN
#
#   sourceLastSeenAtUnixEpoch
# 0  2019-03-30T23:08:44.205Z
# 1  2019-03-30T23:08:44.205Z
# 2  2019-03-30T23:08:44.205Z
# 3  2019-03-30T23:08:44.205Z
# 4  2019-03-30T23:08:44.205Z
#
# [5 rows x 80 columns]

# %% [markdown]
# ## Drop duplicates
#
# This line gets rid of duplicate interations. I currently can't see a reason to keep them, but this perhaps should be checked.
# Some more common interactions might have more support in the literature and therefore more records. Deduplicating them tends to equal out rare interactions with common ones.

# %%
data.drop_duplicates(['sourceTaxonId', 'interactionTypeName', 'targetTaxonId'], inplace = True)

# %%
## Check how many rows are left
len(data)
# Out:
# 1101736

# %% [markdown]
# Define the key taxon for the notebook for which to find all interactions

# %%
#taxon = "Oxalis pes-caprae"
#taxon = "Lantana camara"
#taxon = "Cirsium vulgare"
#taxon = "Procyon lotor" # raccoon
taxon = "Sciurus carolinensis" # Eastern grey squirrel

# %%
# What are all the types of interactions involving Oxalis pes-caprae as source taxon?
data[data['sourceTaxonName'] == taxon]['interactionTypeName'].unique()
# Out:
# array(['interactsWith', 'eats', 'preysOn'], dtype=object)

# %%
# What are all the types of interactions involving Oxalis pes-caprae as target taxon?
data[data['targetTaxonName'] == taxon]['interactionTypeName'].unique()
# Out:
# array(['interactsWith', 'eats', 'parasiteOf', 'preysOn', 'ectoParasiteOf',
#        'pathogenOf', 'hasHost', 'endoparasiteOf'], dtype=object)

# %% [markdown]
# How many taxon sources do I have?

# %%
len(data[data['sourceTaxonName'] == taxon])
# Out:
# 68

# %% [markdown]
# How many taxon targets do I have?

# %%
len(data[data['targetTaxonName'] == taxon])
# Out:
# 146

# %% [markdown]
# Gather together all the data where the target is the taxon in question.

# %%
interacts_data = data[(data['targetTaxonName'] == taxon)]

# %%
interacts_data.head()
# Out:
#          sourceTaxonId                                     sourceTaxonIds  \
# 123784     EOL:1030508  EOL:1030508 | OTT:615465 | WD:Q3837939 | WORMS...
# 123785      EOL:187856  EOL:187856 | EOL:187856 | IF:213648 | GBIF:259...
# 123786  EOL_V2:1178552  EOL_V2:1178552 | OTT:738512 | GBIF:2481209 | F...
# 123787  EOL_V2:1177531  EOL_V2:1177531 | OTT:712913 | EOL_V2:1177531 |...
# 123788  EOL_V2:1177473  EOL_V2:1177473 | OTT:183621 | ITIS:179736 | IR...
#
#                sourceTaxonName sourceTaxonRank  \
# 123784       Sordaria fimicola         species
# 123785  Elaphomyces granulatus         species
# 123786          Rynchops niger         species
# 123787    Hylocichla mustelina         species
# 123788         Corvus caurinus         species
#
#                                      sourceTaxonPathNames  \
# 123784  Fungi | Ascomycota | Sordariomycetes | Sordari...
# 123785  Fungi | Ascomycota | Eurotiomycetes | Eurotial...
# 123786  Animalia | Chordata | Aves | Charadriiformes |...
# 123787  Animalia | Chordata | Aves | Passeriformes | T...
# 123788  Animalia | Chordata | Aves | Passeriformes | C...
#
#                                        sourceTaxonPathIds  \
# 123784  EOL_V2:5559 | EOL:5577 | EOL:2858320 | EOL:569...
# 123785  EOL_V2:5559 | EOL:5577 | EOL:2860997 | EOL:562...
# 123786  EOL:1 | EOL:694 | EOL:695 | EOL:2917972 | EOL:...
# 123787  EOL:1 | EOL:694 | EOL:695 | EOL:1596 | EOL:160...
# 123788  EOL:1 | EOL:694 | EOL:695 | EOL:1596 | EOL:755...
#
#                                  sourceTaxonPathRankNames  \
# 123784  kingdom | phylum | class | order | family | ge...
# 123785  kingdom | phylum | class | order | family | ge...
# 123786  kingdom | phylum | class | order | family | ge...
# 123787  kingdom | phylum | class | order | family | ge...
# 123788  kingdom | phylum | class | order | family | ge...
#
#         sourceTaxonSpeciesName sourceTaxonSpeciesId sourceTaxonGenusName  ...  \
# 123784       Sordaria fimicola          EOL:1030508             Sordaria  ...
# 123785  Elaphomyces granulatus           EOL:187856          Elaphomyces  ...
# 123786          Rynchops niger       EOL_V2:1178552             Rynchops  ...
# 123787    Hylocichla mustelina       EOL_V2:1177531           Hylocichla  ...
# 123788         Corvus caurinus       EOL_V2:1177473               Corvus  ...
#
#        eventDateUnixEpoch                          argumentTypeId  \
# 123784                NaN  https://en.wiktionary.org/wiki/support
# 123785                NaN  https://en.wiktionary.org/wiki/support
# 123786                NaN  https://en.wiktionary.org/wiki/support
# 123787                NaN  https://en.wiktionary.org/wiki/support
# 123788                NaN  https://en.wiktionary.org/wiki/support
#
#                                         referenceCitation referenceDoi  \
# 123784  A. Thessen. 2014. Species associations extract...          NaN
# 123785  A. Thessen. 2014. Species associations extract...          NaN
# 123786  A. Thessen. 2014. Species associations extract...          NaN
# 123787  A. Thessen. 2014. Species associations extract...          NaN
# 123788  A. Thessen. 2014. Species associations extract...          NaN
#
#        referenceUrl                                     sourceCitation  \
# 123784          NaN  A. Thessen. 2014. Species associations extract...
# 123785          NaN  A. Thessen. 2014. Species associations extract...
# 123786          NaN  A. Thessen. 2014. Species associations extract...
# 123787          NaN  A. Thessen. 2014. Species associations extract...
# 123788          NaN  A. Thessen. 2014. Species associations extract...
#
#                 sourceNamespace  \
# 123784  Bhanditz/pseudonitzchia
# 123785  Bhanditz/pseudonitzchia
# 123786  Bhanditz/pseudonitzchia
# 123787  Bhanditz/pseudonitzchia
# 123788  Bhanditz/pseudonitzchia
#
#                                          sourceArchiveURI sourceDOI  \
# 123784  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
# 123785  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
# 123786  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
# 123787  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
# 123788  https://github.com/Bhanditz/pseudonitzchia/arc...       NaN
#
#        sourceLastSeenAtUnixEpoch
# 123784  2019-11-02T23:25:50.260Z
# 123785  2019-11-02T23:25:50.260Z
# 123786  2019-11-02T23:25:50.260Z
# 123787  2019-11-02T23:25:50.260Z
# 123788  2019-11-02T23:25:50.260Z
#
# [5 rows x 80 columns]

# %%
# What are the columns of this dataset?
data.columns
# Out:
# Index(['sourceTaxonId', 'sourceTaxonIds', 'sourceTaxonName', 'sourceTaxonRank',
#        'sourceTaxonPathNames', 'sourceTaxonPathIds',
#        'sourceTaxonPathRankNames', 'sourceTaxonSpeciesName',
#        'sourceTaxonSpeciesId', 'sourceTaxonGenusName', 'sourceTaxonGenusId',
#        'sourceTaxonFamilyName', 'sourceTaxonFamilyId', 'sourceTaxonOrderName',
#        'sourceTaxonOrderId', 'sourceTaxonClassName', 'sourceTaxonClassId',
#        'sourceTaxonPhylumName', 'sourceTaxonPhylumId',
#        'sourceTaxonKingdomName', 'sourceTaxonKingdomId', 'sourceId',
#        'sourceOccurrenceId', 'sourceCatalogNumber', 'sourceBasisOfRecordId',
#        'sourceBasisOfRecordName', 'sourceLifeStageId', 'sourceLifeStageName',
#        'sourceBodyPartId', 'sourceBodyPartName', 'sourcePhysiologicalStateId',
#        'sourcePhysiologicalStateName', 'interactionTypeName',
#        'interactionTypeId', 'targetTaxonId', 'targetTaxonIds',
#        'targetTaxonName', 'targetTaxonRank', 'targetTaxonPathNames',
#        'targetTaxonPathIds', 'targetTaxonPathRankNames',
#        'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
#        'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
#        'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
#        'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
#        'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId',
#        'targetId', 'targetOccurrenceId', 'targetCatalogNumber',
#        'targetBasisOfRecordId', 'targetBasisOfRecordName', 'targetLifeStageId',
#        'targetLifeStageName', 'targetBodyPartId', 'targetBodyPartName',
#        'targetPhysiologicalStateId', 'targetPhysiologicalStateName',
#        'decimalLatitude', 'decimalLongitude', 'localityId', 'localityName',
#        'eventDateUnixEpoch', 'argumentTypeId', 'referenceCitation',
#        'referenceDoi', 'referenceUrl', 'sourceCitation', 'sourceNamespace',
#        'sourceArchiveURI', 'sourceDOI', 'sourceLastSeenAtUnixEpoch'],
#       dtype='object')

# %% [markdown]
# ## Simplify the table to make it readable

# %%
interacts_data = interacts_data[['sourceTaxonId', 'sourceTaxonName', 'sourceTaxonRank',
       'sourceTaxonPathNames', 'sourceTaxonFamilyName', 'interactionTypeName',
       'interactionTypeId', 'targetTaxonId',
       'targetTaxonName','targetTaxonPathNames',
       'targetTaxonPathIds', 'targetTaxonPathRankNames',
       'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
       'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
       'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
       'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
       'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId', 'referenceDoi', 'decimalLatitude', 'decimalLongitude'
        ]].dropna(subset=['targetTaxonId', 'targetTaxonName','targetTaxonPathNames','targetTaxonPathIds'])
interacts_data.head()
# Out:
#          sourceTaxonId         sourceTaxonName sourceTaxonRank  \
# 123784     EOL:1030508       Sordaria fimicola         species
# 123785      EOL:187856  Elaphomyces granulatus         species
# 123786  EOL_V2:1178552          Rynchops niger         species
# 123787  EOL_V2:1177531    Hylocichla mustelina         species
# 123788  EOL_V2:1177473         Corvus caurinus         species
#
#                                      sourceTaxonPathNames  \
# 123784  Fungi | Ascomycota | Sordariomycetes | Sordari...
# 123785  Fungi | Ascomycota | Eurotiomycetes | Eurotial...
# 123786  Animalia | Chordata | Aves | Charadriiformes |...
# 123787  Animalia | Chordata | Aves | Passeriformes | T...
# 123788  Animalia | Chordata | Aves | Passeriformes | C...
#
#        sourceTaxonFamilyName interactionTypeName  \
# 123784          Sordariaceae       interactsWith
# 123785      Elaphomycetaceae       interactsWith
# 123786               Laridae       interactsWith
# 123787              Turdidae       interactsWith
# 123788              Corvidae       interactsWith
#
#                                 interactionTypeId targetTaxonId  \
# 123784  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
# 123785  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
# 123786  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
# 123787  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
# 123788  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
#
#              targetTaxonName  \
# 123784  Sciurus carolinensis
# 123785  Sciurus carolinensis
# 123786  Sciurus carolinensis
# 123787  Sciurus carolinensis
# 123788  Sciurus carolinensis
#
#                                      targetTaxonPathNames  ...  \
# 123784  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
# 123785  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
# 123786  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
# 123787  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
# 123788  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
#
#        targetTaxonOrderId targetTaxonClassName targetTaxonClassId  \
# 123784           EOL:8677             Mammalia           EOL:1642
# 123785           EOL:8677             Mammalia           EOL:1642
# 123786           EOL:8677             Mammalia           EOL:1642
# 123787           EOL:8677             Mammalia           EOL:1642
# 123788           EOL:8677             Mammalia           EOL:1642
#
#        targetTaxonPhylumName targetTaxonPhylumId targetTaxonKingdomName  \
# 123784              Chordata             EOL:694               Animalia
# 123785              Chordata             EOL:694               Animalia
# 123786              Chordata             EOL:694               Animalia
# 123787              Chordata             EOL:694               Animalia
# 123788              Chordata             EOL:694               Animalia
#
#        targetTaxonKingdomId referenceDoi decimalLatitude decimalLongitude
# 123784                EOL:1          NaN             NaN              NaN
# 123785                EOL:1          NaN             NaN              NaN
# 123786                EOL:1          NaN             NaN              NaN
# 123787                EOL:1          NaN             NaN              NaN
# 123788                EOL:1          NaN             NaN              NaN
#
# [5 rows x 29 columns]

# %%
interacts_data.groupby(interacts_data['sourceTaxonFamilyName']).size().sort_values(ascending = False)
# Out:
# sourceTaxonFamilyName
# Ceratophyllidae       7
# Heligmosomidae        7
# Accipitridae          6
# Rictulariidae         5
# Taeniidae             5
# Polyplacidae          5
# Canidae               4
# Felidae               4
# Heligmonellidae       4
# Moniliformidae        4
# Hymenolepididae       4
# Haemonchidae          3
# Strongyloididae       3
# Strigidae             3
# Hoplopleuridae        3
# Ixodidae              3
# Mustelidae            3
# Cardinalidae          2
# Enderleinellidae      2
# Icteridae             2
# Thelebolaceae         2
# Asteraceae            2
# Oxyuridae             2
# Ascarididae           2
# Setariidae            2
# Curculionidae         1
# Eurytomidae           1
# Anaplasmataceae       1
# Elaphomycetaceae      1
# Davaineidae           1
# Trichuridae           1
# Betulaceae            1
# Corvidae              1
# Trichostrongylidae    1
# Bartonellaceae        1
# Fagaceae              1
# Catenotaeniidae       1
# Cathartidae           1
# Sarcoptidae           1
# Flaviviridae          1
# Linguatulidae         1
# Pulicidae             1
# Pteromalidae          1
# Physalopteridae       1
# Onchocercidae         1
# Sordariaceae          1
# Miliolidae            1
# Leptopsyllidae        1
# Gongylonematidae      1
# Laridae               1
# Hystrichopsyllidae    1
# Troglodytidae         1
# Hepadnaviridae        1
# Sciuridae             1
# Haemogregarinidae     1
# Turdidae              1
# dtype: int64

# %% [markdown]
# ## Linking to Wikipedia
# A nice trick by Yikang Li is to make the results clickable, so that you can figure out what sort of organisms are interacting

# %%
def make_clickable_both(val): 
    name, url = val.split('#')
    return f'<a href="{url}">{name}</a>'

# %% [markdown]
# ## Gather all the interactions together

# %%
def sourcesWithWiki(taxonIn):
    """ Function that takes taxon of interest and finds their interactions and linked to their Wikipedia pages.
    Args:
        taxonIn: the source taxon that we are interested in, can be in any level.

    Returns:
        The source taxa with clickable Wikipedia links for certain source taxon and certain interaction type, 
       

 in descending order of number of records.
    """
    
    d = data[data['targetTaxonName'] == taxonIn]
    d = d.append(data[data['sourceTaxonName'] == taxonIn])
    d_cleaned = d[['sourceTaxonId', 'sourceTaxonName', 'sourceTaxonRank',
       'sourceTaxonPathNames', 'sourceTaxonFamilyName', 'interactionTypeName',
       'interactionTypeId', 'targetTaxonId',
       'targetTaxonName','targetTaxonPathNames',
       'targetTaxonPathIds', 'targetTaxonPathRankNames',
       'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
       'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
       'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
       'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
       'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId', 'referenceDoi', 'decimalLatitude', 'decimalLongitude'
        ]].dropna(subset=['targetTaxonId', 'targetTaxonName','targetTaxonPathNames','targetTaxonPathIds'])

    result = d_cleaned.groupby(d_cleaned['sourceTaxonFamilyName']).size().sort_values(ascending = False)
    target_df = pd.DataFrame(result)
    target_df.columns = ['count']

    urls = dict(name= list(target_df.index), 
    url= ['https://en.wikipedia.org/wiki/' + str(i) for i in list(target_df.index)])
    target_df.index = [i + '#' + j for i,j in zip(urls['name'], urls['url'])]
    index_list = list(target_df.index)
    target_df.index =[make_clickable_both(i) for i in index_list]
    df = target_df.style.format({'wiki': make_clickable_both})
    
    return df

# %%
sourcesWithWiki(taxon)
# Out:
# <style  type="text/css" >
# </style><table id="T_45de7634_0148_11ea_bb50_50eb71e8ed14" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row0" class="row_heading level0 row0" ><a href="https://en.wikipedia.org/wiki/Sciuridae">Sciuridae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row0_col0" class="data row0 col0" >45</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row1" class="row_heading level0 row1" ><a href="https://en.wikipedia.org/wiki/Ceratophyllidae">Ceratophyllidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row1_col0" class="data row1 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row2" class="row_heading level0 row2" ><a href="https://en.wikipedia.org/wiki/Heligmosomidae">Heligmosomidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row2_col0" class="data row2 col0" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row3" class="row_heading level0 row3" ><a href="https://en.wikipedia.org/wiki/Accipitridae">Accipitridae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row3_col0" class="data row3 col0" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row4" class="row_heading level0 row4" ><a href="https://en.wikipedia.org/wiki/Rictulariidae">Rictulariidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row4_col0" class="data row4 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row5" class="row_heading level0 row5" ><a href="https://en.wikipedia.org/wiki/Taeniidae">Taeniidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row5_col0" class="data row5 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row6" class="row_heading level0 row6" ><a href="https://en.wikipedia.org/wiki/Polyplacidae">Polyplacidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row6_col0" class="data row6 col0" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row7" class="row_heading level0 row7" ><a href="https://en.wikipedia.org/wiki/Canidae">Canidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row7_col0" class="data row7 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row8" class="row_heading level0 row8" ><a href="https://en.wikipedia.org/wiki/Felidae">Felidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row8_col0" class="data row8 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row9" class="row_heading level0 row9" ><a href="https://en.wikipedia.org/wiki/Heligmonellidae">Heligmonellidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row9_col0" class="data row9 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row10" class="row_heading level0 row10" ><a href="https://en.wikipedia.org/wiki/Moniliformidae">Moniliformidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row10_col0" class="data row10 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row11" class="row_heading level0 row11" ><a href="https://en.wikipedia.org/wiki/Hymenolepididae">Hymenolepididae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row11_col0" class="data row11 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row12" class="row_heading level0 row12" ><a href="https://en.wikipedia.org/wiki/Ixodidae">Ixodidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row12_col0" class="data row12 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row13" class="row_heading level0 row13" ><a href="https://en.wikipedia.org/wiki/Haemonchidae">Haemonchidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row13_col0" class="data row13 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row14" class="row_heading level0 row14" ><a href="https://en.wikipedia.org/wiki/Strongyloididae">Strongyloididae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row14_col0" class="data row14 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row15" class="row_heading level0 row15" ><a href="https://en.wikipedia.org/wiki/Strigidae">Strigidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row15_col0" class="data row15 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row16" class="row_heading level0 row16" ><a href="https://en.wikipedia.org/wiki/Hoplopleuridae">Hoplopleuridae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row16_col0" class="data row16 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row17" class="row_heading level0 row17" ><a href="https://en.wikipedia.org/wiki/Mustelidae">Mustelidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row17_col0" class="data row17 col0" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row18" class="row_heading level0 row18" ><a href="https://en.wikipedia.org/wiki/Cardinalidae">Cardinalidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row18_col0" class="data row18 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row19" class="row_heading level0 row19" ><a href="https://en.wikipedia.org/wiki/Thelebolaceae">Thelebolaceae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row19_col0" class="data row19 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row20" class="row_heading level0 row20" ><a href="https://en.wikipedia.org/wiki/Icteridae">Icteridae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row20_col0" class="data row20 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row21" class="row_heading level0 row21" ><a href="https://en.wikipedia.org/wiki/Enderleinellidae">Enderleinellidae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row21_col0" class="data row21 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_45de7634_0148_11ea_bb50_50eb71e8ed14level0_row22" class="row_heading level0 row22" ><a href="https://en.wikipedia.org/wiki/Oxyuridae">Oxyuridae</a></th>
#                         <td id="T_45de7634_0148_11ea_bb50_50eb71e8ed14row22_col0" class="data r

# %%
    interactDataTaxon = data[data['targetTaxonName'] == taxon]
    #interactDataTaxon = interactDataTaxon.append(data[data['sourceTaxonName'] == taxon])
    cleanInteractDataTaxon = interactDataTaxon[['sourceTaxonId', 'sourceTaxonName', 'sourceTaxonRank',
       'sourceTaxonPathNames', 'sourceTaxonFamilyName', 'interactionTypeName',
       'interactionTypeId', 'targetTaxonId',
       'targetTaxonName','targetTaxonPathNames',
       'targetTaxonPathIds', 'targetTaxonPathRankNames',
       'targetTaxonSpeciesName', 'targetTaxonSpeciesId',
       'targetTaxonGenusName', 'targetTaxonGenusId', 'targetTaxonFamilyName',
       'targetTaxonFamilyId', 'targetTaxonOrderName', 'targetTaxonOrderId',
       'targetTaxonClassName', 'targetTaxonClassId', 'targetTaxonPhylumName',
       'targetTaxonPhylumId', 'targetTaxonKingdomName', 'targetTaxonKingdomId', 'referenceDoi', 'decimalLatitude', 'decimalLongitude'
        ]].dropna(subset=['targetTaxonId', 'targetTaxonName','targetTaxonPathNames','targetTaxonPathIds'])

# %%
cleanInteractDataTaxon.head()
# Out:
#          sourceTaxonId         sourceTaxonName sourceTaxonRank  \
# 123784     EOL:1030508       Sordaria fimicola         species
# 123785      EOL:187856  Elaphomyces granulatus         species
# 123786  EOL_V2:1178552          Rynchops niger         species
# 123787  EOL_V2:1177531    Hylocichla mustelina         species
# 123788  EOL_V2:1177473         Corvus caurinus         species
#
#                                      sourceTaxonPathNames  \
# 123784  Fungi | Ascomycota | Sordariomycetes | Sordari...
# 123785  Fungi | Ascomycota | Eurotiomycetes | Eurotial...
# 123786  Animalia | Chordata | Aves | Charadriiformes |...
# 123787  Animalia | Chordata | Aves | Passeriformes | T...
# 123788  Animalia | Chordata | Aves | Passeriformes | C...
#
#        sourceTaxonFamilyName interactionTypeName  \
# 123784          Sordariaceae       interactsWith
# 123785      Elaphomycetaceae       interactsWith
# 123786               Laridae       interactsWith
# 123787              Turdidae       interactsWith
# 123788              Corvidae       interactsWith
#
#                                 interactionTypeId targetTaxonId  \
# 123784  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
# 123785  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
# 123786  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
# 123787  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
# 123788  http://purl.obolibrary.org/obo/RO_0002437    EOL:347685
#
#              targetTaxonName  \
# 123784  Sciurus carolinensis
# 123785  Sciurus carolinensis
# 123786  Sciurus carolinensis
# 123787  Sciurus carolinensis
# 123788  Sciurus carolinensis
#
#                                      targetTaxonPathNames  ...  \
# 123784  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
# 123785  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
# 123786  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
# 123787  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
# 123788  Animalia | Chordata | Mammalia | Rodentia | Sc...  ...
#
#        targetTaxonOrderId targetTaxonClassName targetTaxonClassId  \
# 123784           EOL:8677             Mammalia           EOL:1642
# 123785           EOL:8677             Mammalia           EOL:1642
# 123786           EOL:8677             Mammalia           EOL:1642
# 123787           EOL:8677             Mammalia           EOL:1642
# 123788           EOL:8677             Mammalia           EOL:1642
#
#        targetTaxonPhylumName targetTaxonPhylumId targetTaxonKingdomName  \
# 123784              Chordata             EOL:694               Animalia
# 123785              Chordata             EOL:694               Animalia
# 123786              Chordata             EOL:694               Animalia
# 123787              Chordata             EOL:694               Animalia
# 123788              Chordata             EOL:694               Animalia
#
#        targetTaxonKingdomId referenceDoi decimalLatitude decimalLongitude
# 123784                EOL:1          NaN             NaN              NaN
# 123785                EOL:1          NaN             NaN              NaN
# 123786                EOL:1          NaN             NaN              NaN
# 123787                EOL:1          NaN             NaN              NaN
# 123788                EOL:1          NaN             NaN              NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # Drawing a network of the interactions

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# Create graphic object
G = nx.DiGraph()
#G = nx.star_graph(20)

# %%
# iterate over rows with iterrows()
for index, row in cleanInteractDataTaxon.iterrows():
     # access data using column names
     #print(row['sourceTaxonName'], row['targetTaxonName'], row['interactionTypeName'])
    G.add_node(row['sourceTaxonFamilyName'])
    G.add_node(row['targetTaxonFamilyName'])
    G.add_edge(row['targetTaxonFamilyName'], row['sourceTaxonFamilyName'], label = row['interactionTypeName'])

# %% [markdown]
# ## A network of all the interacting families

# %%
plt.figure(figsize=(12,12))
edge_labels = nx.get_edge_attributes(G,'label')

pos = nx.spring_layout(G) 
colors = range(50)
nx.draw_networkx_edge_labels(G,pos, edge_labels = edge_labels, font_size=10, font_color='blue')

nx.draw_networkx(G, pos, with_labels=True, node_size=1000, node_color="skyblue", alpha= 1, arrows=True, 
                    linewidths=1, font_color="black", font_size=10, style = 'dashed')

plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## A network of all the interacting species

# %%
# Create graphic object
Gs = nx.DiGraph()

# %%
# iterate over rows with iterrows()
for index, row in cleanInteractDataTaxon.iterrows():
     # access data using column names
     #print(row['sourceTaxonName'], row['targetTaxonName'], row['interactionTypeName'])
    Gs.add_node(row['sourceTaxonName'])
    Gs.add_node(row['targetTaxonName'])
    Gs.add_edge(row['sourceTaxonName'], row['targetTaxonName'], label = row['interactionTypeName'])

# %%
plt.figure(figsize=(18,18))
edge_labels = nx.get_edge_attributes(Gs,'label')

pos = nx.spring_layout(Gs) 
colors = range(50)
nx.draw_networkx_edge_labels(Gs,pos, edge_labels = edge_labels, font_size=10, font_color='blue')

nx.draw_networkx(Gs, pos, with_labels=True, node_size=1000, node_color="skyblue", alpha= 1, arrows=True, 
                    linewidths=1, font_color="black", font_size=10, style = 'dashed')

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
print(Gs.__len__())
# Out:
# 96
