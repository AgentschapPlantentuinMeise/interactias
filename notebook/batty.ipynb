# %% [markdown]
# # Interactias Geo Selected Network
#
# One way of examining the impact of invasive species is to look at all their interactions and the interations those organisms have with each other. This full interaction network gives you an idication of whether a species might be a "keystone" species and therefore have a disproportionatly large impact.
#
# In this step of the evolution of this script it will be adapted to quantify species by their occupancy.
#
# I will harvest species interactions data from GLOBI (https://www.globalbioticinteractions.org/) to discover the species that interact with an invasive species.
# I will then harvest all the interactions for those species to create two tiers of interactions.
# I will then count all the occurences of these in species in the Belgian datacube.
# I will then create a network diagram to visualize this.
#
# This notebook takes considerable insperation and code from Yikang Li's project on GLoBI (https://curiositydata.org/part1_globi_access/).

# %%
import sys
print(sys.version)

#Python 3.7.4 (default, Aug 9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
#pygbif 0.3.0
# Out:
# 3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from pygbif import species
from pygbif import occurrences as occ
import sqlite3
from sqlite3 import Error
import pydot

# %% [markdown]
# ### Setting up some parameters

# %%
# There is no point accepting all the species that have more than one record.
# There are too many casual records of plants and birds
thresholdForOccNum = 5
# If you want to exclude the interactions list them comma seperated here
interactionsToExclude = "interactsWith"
#interactionsToExclude = ""

#ranksToExclude = '"Kingdom","subclass","Phyllum","class","order","superclass,"infraclass,"infraorder","parvclass"'
ranksToExclude = "subclass,kingdom"

# %%
## Define the country of interest
country  = 'BE'

## Define the year from where to consider records for the occupancy
year = 2000

## Define the place to find the data cube for occupancy data
## Currently the cube contains only Belgian data so that is all that can be used
database = r"..\data\cube.db" 

## Define the place to find the interaction data
globiDB = r"..\data\globi.db"

# %% [markdown]
# ### Define the key taxon for the notebook for which to find all interactions

# %%
#taxon = "Pipistrellus pipistrellus" # Common Pipistrelle
#taxon = "Rhinolophus sinicus" # Chinese rufous horseshoe bat
#taxon = "Rousettus leschenaulti" #Leschenault's rousette (a fruit bat)
taxon = "Rousettus aegyptiacus" #Egyptian fruit bat

# %% [markdown]
# ## Check to see if the taxon exits in GBIF

# %%
try:
    #NOTE: The function method name_suggest has a different behavior with regards to the gender of Latin names to name_backbone
    # If name_backbone is given a name in one gender it can still return the best match from the GBIF backbone if that
    # name is spelled as if it was another gender.
    #key = species.name_suggest(q=taxon, limit = 1)
    match = species.name_backbone(name=taxon, limit = 1)
    #print(key)
    
    # if there is no match this is returned form .name_backbone {'confidence': 100, 'matchType': 'NONE', 'synonym': False}
    if match['matchType'] == 'NONE':
        raise ValueError("TAXON NOT FOUND ON GBIF!")
    else:
        key = match['usageKey']
except ValueError as ve:
    print(ve)
    exit(1)

# %%
print('The taxon to be studied is ' + match['scientificName'])
# Out:
# The taxon to be studied is Rousettus aegyptiacus (E.Geoffroy, 1810)

# %% [markdown]
# ### Take a look at the interactions that the taxon has

# %%
# What are all the types of interactions involving taxon as source taxon?
#data[data['sourceTaxonName'] == taxon]['interactionTypeName'].unique()
try:
    connGlobi = sqlite3.connect(globiDB)
except Error as e:
    print(e)

# %%
curGlobi = connGlobi.cursor()
curGlobi.execute("SELECT interactionTypeName from globi  WHERE sourceTaxonName = ? GROUP BY interactionTypeName;", (taxon,))
interactDataTaxon = curGlobi.fetchall()

# %%
interactDataTaxon
# Out:
# [('coOccursWith',), ('eats',), ('visitsFlowersOf',)]

# %%
curGlobi = connGlobi.cursor()
curGlobi.execute("SELECT interactionTypeName from globi  WHERE targetTaxonName = ? GROUP BY interactionTypeName;", (taxon,))
interactDataTaxon = curGlobi.fetchall()
interactDataTaxon
# Out:
# [('ectoparasiteOf',), ('hasHost',), ('kills',), ('pathogenOf',), ('preysOn',)]

# %% [markdown]
# ## Get the primary interation data for the species in question

# %%
curGlobi = connGlobi.cursor()
# curGlobi.execute("SELECT * from globi  WHERE targetTaxonName = ? and interactionTypeName NOT IN (?) and targetTaxonRank NOT IN('kingdom','phyllum','class','subclass','infraclass') and sourceTaxonRank NOT IN('kingdom','phyllum','class','subclass','infraclass');", \
#                 (taxon,interactionsToExclude,))
curGlobi.execute("SELECT * from globi  WHERE targetTaxonName = ? and interactionTypeName NOT IN (?) and targetTaxonRank ='species' and sourceTaxonRank = 'species';", \
                 (taxon,interactionsToExclude,))
interactDataTaxon = curGlobi.fetchall()

# %%
curGlobi = connGlobi.cursor()
#curGlobi.execute("SELECT * from globi  WHERE sourceTaxonName = ? and interactionTypeName NOT IN (?) and targetTaxonRank NOT IN('kingdom','phyllum','class','subclass','infraclass') and sourceTaxonRank NOT IN('kingdom','phyllum','class','subclass','infraclass');", \
#                 (taxon,interactionsToExclude,))
curGlobi.execute("SELECT * from globi  WHERE sourceTaxonName = ? and interactionTypeName NOT IN (?) and targetTaxonRank ='species' and sourceTaxonRank = 'species';", \
                 (taxon,interactionsToExclude,))
sources = curGlobi.fetchall()

# %%
interactDataTaxon.extend(sources)
len(interactDataTaxon)
# Out:
# 276

# %%
# Convert to a Pandas dataframe
interactDataTaxon = pd.DataFrame(interactDataTaxon)

# %%
# Add column names
interactDataTaxon
interactDataTaxon.columns = ['sourceTaxonId', \
                                'sourceTaxonIds','sourceTaxonName','sourceTaxonRank','sourceTaxonPathNames', \
                                'sourceTaxonPathIds','sourceTaxonPathRankNames','sourceTaxonSpeciesName','sourceTaxonSpeciesId',\
                                'sourceTaxonGenusName','sourceTaxonGenusId','sourceTaxonFamilyName','sourceTaxonFamilyId',\
                                'sourceTaxonOrderName','sourceTaxonOrderId','sourceTaxonClassName','sourceTaxonClassId',\
                                'sourceTaxonPhylumName','sourceTaxonPhylumId','sourceTaxonKingdomName','sourceTaxonKingdomId',\
                                'sourceId','sourceOccurrenceId','sourceCatalogNumber','sourceBasisOfRecordId',\
                                'sourceBasisOfRecordName','sourceLifeStageId','sourceLifeStageName','sourceBodyPartId',\
                                'sourceBodyPartName','sourcePhysiologicalStateId','sourcePhysiologicalStateName', \
                                'sourceSexId', 'sourceSexName','interactionTypeName',\
                                'interactionTypeId','targetTaxonId','targetTaxonIds','targetTaxonName',\
                                'targetTaxonRank','targetTaxonPathNames','targetTaxonPathIds','targetTaxonPathRankNames',\
                                'targetTaxonSpeciesName','targetTaxonSpeciesId','targetTaxonGenusName','targetTaxonGenusId',\
                                'targetTaxonFamilyName','targetTaxonFamilyId','targetTaxonOrderName','targetTaxonOrderId',\
                                'targetTaxonClassName','targetTaxonClassId','targetTaxonPhylumName','targetTaxonPhylumId',\
                                'targetTaxonKingdomName','targetTaxonKingdomId','targetId','targetOccurrenceId',\
                                'targetCatalogNumber','targetBasisOfRecordId','targetBasisOfRecordName','targetLifeStageId',\
                                'targetLifeStageName','targetBodyPartId','targetBodyPartName','targetPhysiologicalStateId',\
                                'targetPhysiologicalStateName', 'targetSexId', 'targetSexName',\
                                'decimalLatitude','decimalLongitude','localityId',\
                                'localityName','eventDateUnixEpoch','argumentTypeId','referenceCitation',\
                                'referenceDoi','referenceUrl','sourceCitation','sourceNamespace',\
                                'sourceArchiveURI','sourceDOI','sourceLastSeenAtUnixEpoch']

# %% [markdown]
# ## Get a list of all the primary interacting species

# %%
interactingTaxaData = interactDataTaxon.drop_duplicates()

# %%
interactingTaxaData
# Out:
#     sourceTaxonId                                     sourceTaxonIds  \
# 0      NCBI:28875                                         NCBI:28875
# 1    NCBI:1904411                                       NCBI:1904411
# 2    GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 5    GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 15   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 16   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 18   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 19   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 22   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 23   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 53   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 55   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 71   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 72   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 73   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 78   GBIF:8879703  GBIF:8879703 | NCBI:11269 | OTT:4888314 | WD:Q...
# 82     NCBI:38766                           NCBI:38766 | OTT:4888078
# 83     NCBI:38766                           NCBI:38766 | OTT:4888078
# 84     NCBI:38766                           NCBI:38766 | OTT:4888078
# 85   NCBI:1712572                                       NCBI:1712572
# 86     NCBI:38766                           NCBI:38766 | OTT:4888078
# 87   NCBI:1340801                                       NCBI:1340801
# 89   NCBI:1508220                                       NCBI:1508220
# 99    NCBI:694006                          NCBI:694006 | OTT:4890215
# 100   NCBI:694006                          NCBI:694006 | OTT:4890215
# 103  NCBI:1508220                                       NCBI:1508220
# 105  NCBI:1508220                                       NCBI:1508220
# 113  NCBI:1508220                                       NCBI:1508220
# 116  NCBI:1508220                                       NCBI:1508220
# 124  NCBI:1508220                                       NCBI:1508220
# ..            ...                                                ...
# 246   ITIS:632267                                        ITIS:632267
# 247   ITIS:632267                                        ITIS:632267
# 248   ITIS:632267                                        ITIS:632267
# 249   ITIS:632267                                        ITIS:632267
# 250   ITIS:632267                                        ITIS:632267
# 251   ITIS:632267                                        ITIS:632267
# 252   ITIS:632267                                        ITIS:632267
# 253   ITIS:632267                                        ITIS:632267
# 254   ITIS:632267                                        ITIS:632267
# 255   ITIS:632267                                        ITIS:632267
# 256   ITIS:632267                                        ITIS:632267
# 257   ITIS:632267                                        ITIS:632267
# 258   ITIS:632267                                        ITIS:632267
# 259   ITIS:632267                                        ITIS:632267
# 260   ITIS:632267                                        ITIS:632267
# 261   ITIS:632267                                        ITIS:632267
# 262   ITIS:632267                                        ITIS:632267
# 263   ITIS:632267                                        ITIS:632267
# 264   ITIS:632267                                        ITIS:632267
# 265   ITIS:632267                                        ITIS:632267
# 266   ITIS:632267                                        ITIS:632267
# 267   ITIS:632267                                        ITIS:632267
# 268   ITIS:632267                                        ITIS:632267
# 269   ITIS:632267                                        ITIS:632267
# 270   ITIS:632267                                        ITIS:632267
# 271   ITIS:632267                                        ITIS:632267
# 272   ITIS:632267                                        ITIS:632267
# 273   ITIS:632267                                        ITIS:632267
# 55   | Mononegavirales | Filoviridae | Marburgvirus...
# 71   | Mononegavirales | Filoviridae | Marburgvirus...
# 72   | Mononegavirales | Filoviridae | Marburgvirus...
# 73   | Mononegavirales | Filoviridae | Marburgvirus...
# 78   | Mononegavirales | Filoviridae | Marburgvirus...
# 82   Viruses | ssRNA viruses | ssRNA negative-stran...
# 83   Viruses | ssRNA viruses | ssRNA negative-stran...
# 84   Viruses | ssRNA viruses | ssRNA negative-stran...
# 85   Viruses | ssRNA viruses | ssRNA negative-stran...
# 86   Viruses | ssRNA viruses | ssRNA negative-stran...
# 87   Viruses | Riboviria | Reoviridae | Sedoreoviri...
# 89   Viruses | ssRNA viruses | ssRNA positive-stran...
# 99   Viruses | ssRNA viruses | ssRNA positive-stran...
# 100  Viruses | ssRNA viruses | ssRNA positive-stran...
# 103  Viruses | ssRNA viruses | ssRNA positive-stran...
# 105  Viruses | ssRNA viruses | ssRNA positive-stran...
# 113  Viruses | ssRNA viruses | ssRNA positive-stran...
# 116  Viruses | ssRNA viruses | ssRNA positive-stran...
# 124  Viruses | ssRNA viruses | ssRNA positive-stran...
# ..                                                 ...
# 246  Animalia | Bilateria | Deuterostomia | Chordat...
# 247  Animalia | Bilateria | Deuterostomia | Chordat...
# 248  Animalia | Bilateria | Deuterostomia | Chordat...
# 249  Animalia | Bilateria | Deuterostomia | Chordat...
# 250  Animalia | Bilateria | Deuterostomia | Chordat...
# 251  Animalia | Bilateria | Deuterostomia | Chordat...
# 252  Animalia | Bilateria | Deuterostomia | Chordat...
# 253  Animalia | Bilateria | Deuterostomia | Chordat...
# 254  Animalia | Bilateria | Deuterostomia | Chordat...
# 255  Animalia | Bilateria | Deuterostomia | Chordat...
# 256  Animalia | Bilateria | Deuterostomia | Chordat...
# 257  Animalia | Bilateria | Deuterostomia | Chordat...
# 258  Animalia | Bilateria | Deuterostomia | Chordat...
# 259  Animalia | Bilateria | Deuterostomia | Chordat...
# 260  Animalia | Bilateria | Deuterostomia | Chordat...
# 261  Animalia | Bilateria | Deuterostomia | Chordat...
# 262  Animalia | Bilateria | Deuterostomia | Chordat...
# 263  Animalia | Bilateria | Deuterostomia | Chordat...
# 264  Animalia | Bilateria | Deuterostomia | Chordat...
# 265  Animalia | Bilateria | Deuterostomia | Chordat...
# 266  Animalia | Bilateria | Deuterostomia | Chordat...
# 267  Animalia | Bilateria | Deuterostomia | Chordat...
# 268  Animalia | Bilateria | Deuterostomia | Chordat...
# 269  Animalia | Bilateria | Deuterostomia | Chordat...
# 270  Animalia | Bilateria | Deuterostomia | Chordat...
# 271  Animalia | Bilateria | Deuterostomia | Chordat...
# 272  Animalia | Bilateria | Deuterostomia | Chordat...
# 273  Animalia | Bilateria | Deuterostomia | Chordat...
# 274  Animalia | Bilateria | Deuterostomia | Chordat...
# 275  Animalia | Bilateria | Deuterostomia | Chordat...
#
#                                     sourceTaxonPathIds  \
# 0    NCBI:10239 | NCBI:35325 | NCBI:10880 | NCBI:68...
# 1    NCBI:10239 | NCBI:35237 | NCBI:151341 | NCBI:1...
# 2    GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 5    GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 15   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 16   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 18   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 19   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 22   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 23   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 53   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 55   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 71   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 72   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 73   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 78   GBIF:8 | GBIF:842 | GBIF:7759 | GBIF:9173584 |...
# 82   NCBI:10239 | NCBI:439488 | NCBI:35301 | NCBI:1...
# 83   NCBI:10239 | NCBI:439488 | NCBI:35301 | NCBI:1...
# 84   NCBI:10239 | NCBI:439488 | NCBI:35301 | NCBI:1...
# 85   NCBI:10239 | NCBI:439488 | NCBI:35301 | NCBI:1...
# 86   NCBI:10239 | NCBI:439488 | NCBI:35301 | NCBI:1...
# 87   NCBI:10239 | NCBI:2559587 | NCBI:10880 | NCBI:...
# 89   NCBI:10239 | NCBI:439488 | NCBI:35278 | NCBI:7...
# 99   NCBI:10239 | NCBI:439488 | NCBI:35278 | NCBI:7...
# 100  NCBI:10239 | NCBI:439488 | NCBI:35278 | NCBI:7...
# 103  NCBI:10239 | NCBI:439488 | NCBI:35278 | NCBI:7...
# 105  NCBI:10239 | NCBI:439488 | NCBI:35278 | NCBI:7...
# 113  NCBI:10239 | NCBI:439488 | NCBI:35278 | NCBI:7...
# 116  NCBI:10239 | NCBI:439488 | NCBI:35278 | NCBI:7...
# 124  NCBI:10239 | NCBI:439488 | NCBI:35278 | NCBI:7...
# ..                                                 ...
# 246  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 247  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 248  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 249  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 250  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 251  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 252  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 253  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 254  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 255  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 256  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 257  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 258  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 259  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 260  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 261  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 262  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 263  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 264  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 265  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 266  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 267  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 268  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 269  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 270  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 271  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 272  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 273  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 274  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
# 275  ITIS:202423 | ITIS:914154 | ITIS:914156 | ITIS...
#
#                               sourceTaxonPathRankNames  \
# 0            |  | family | subfamily | genus | species
# 1                             |  | family |  | species
# 2           kingdom | order | family | genus | species
# 5           kingdom | order | family | genus | species
# 15          kingdom | order | family | genus | species
# 16          kingdom | order | family | genus | species
# 18          kingdom | order | family | genus | species
# 19          kingdom | order | family | genus | species
# 22          kingdom | order | family | genus | species
# 23          kingdom | order | family | genus | species
# 53          kingdom | order | family | genus | species
# 55          kingdom | order | family | genus | species
# 71          kingdom | order | family | genus | species
# 72          kingdom | order | family | genus | species
# 73          kingdom | order | family | genus | species
# 78          kingdom | order | family | genus | species
# 82            |  |  | order | family | genus | species
# 83            |  |  | order | family | genus | species
# 84            |  |  | order | family | genus | species
# 85         |  |  | order | family | genus |  | species
# 86            |  |  | order | family | genus | species
# 87        |  | family | subfamily | genus |  | species
# 89     |  |  | order | family | subfamily |  | species
# 99   |  |  | order | family | subfamily | genus | s...
# 100  |  |  | order | family | subfamily | genus | s...
# 103    |  |  | order | family | subfamily |  | species
# 105    |  |  | order | family | subfamily |  | species
# 113    |  |  | order | family | subfamily |  | species
# 116    |  |  | order | family | subfamily |  | species
# 124    |  |  | order | family | subfamily |  | species
# ..                                                 ...
# 246  kingdom | subkingdom | infrakingdom | phylum |...
# 247  kingdom | subkingdom | infrakingdom | phylum |...
# 248  kingdom | subkingdom | infrakingdom | phylum |...
# 249  kingdom | subkingdom | infrakingdom | phylum |...
# 250  kingdom | subkingdom | infrakingdom | phylum |...
# 251  kingdom | subkingdom | infrakingdom | phylum |...
# 252  kingdom | subkingdom | infrakingdom | phylum |...
# 253  kingdom | subkingdom | infrakingdom | phylum |...
# 254  kingdom | subkingdom | infrakingdom | phylum |...
# 255  kingdom | subkingdom | infrakingdom | phylum |...
# 256  kingdom | subkingdom | infrakingdom | phylum |...
# 257  kingdom | subkingdom | infrakingdom | phylum |...
# 258  kingdom | subkingdom | infrakingdom | phylum |...
# 259  kingdom | subkingdom | infrakingdom | phylum |...
# 260  kingdom | subkingdom | infrakingdom | phylum |...
# 261  kingdom | subkingdom | infrakingdom | phylum |...
# 262  kingdom | subkingdom | infrakingdom | phylum |...
# 263  kingdom | subkingdom | infrakingdom | phylum |...
# 264  kingdom | subkingdom | infrakingdom | phylum |...
# 265  kingdom | subkingdom | infrakingdom | phylum |...
# 266  kingdom | subkingdom | infrakingdom | phylum |...
# 267  kingdom | subkingdom | infrakingdom | phylum |...
# 268  kingdom | subkingdom | infrakingdom | phylum |...
# 269  kingdom | subkingdom | infrakingdom | phylum |...
# 270  kingdom | subkingdom | infrakingdom | phylum |...
# 271  kingdom | subkingdom | infrakingdom | phylum |...
# 272  kingdom | subkingdom | infrakingdom | phylum |...
# 273  kingdom | subkingdom | infrakingdom | phylum |...
# 274  kingdom | subkingdom | infrakingdom | phylum |...
# 275  kingdom | subkingdom | infrakingdom | phylum |...
#
#                    sourceTaxonSpeciesName sourceTaxonSpeciesId  \
# 0                             Rotavirus A           NCBI:28875
# 1    Rousettus aegyptiacus polyomavirus 1         NCBI:1904411
# 2                    Marburg marburgvirus         GBIF:8879703
# 5                    Marburg marburgvirus         GBIF:8879703
# 15                   Marburg marburgvirus         GBIF:8879703
# 16                   Marburg marburgvirus         GBIF:8879703
# 18                   Marburg marburgvirus         GBIF:8879703
# 19                   Marburg marburgvirus         GBIF:8879703
# 22                   Marburg marburgvirus         GBIF:8879703
# 23                   Marburg marburgvirus         GBIF:8879703
# 53                   Marburg marburgvirus         GBIF:8879703
# 55                   Marburg marburgvirus         GBIF:8879703
# 71                   Marburg marburgvirus         GBIF:8879703
# 72                   Marburg marburgvirus         GBIF:8879703
# 73                   Marburg marburgvirus         GBIF:8879703
# 78                   Marburg marburgvirus         GBIF:8879703
# 82                   Lagos bat lyssavirus           NCBI:38766
# 83                   Lagos bat lyssavirus           NCBI:38766
# 84                   Lagos bat lyssavirus           NCBI:38766
# 85                            Yogue virus         NCBI:1712572
# 86                   Lagos bat lyssavirus           NCBI:38766
# 87                          Bat rotavirus         NCBI:1340801
# 89                        Bat coronavirus         NCBI:1508220
# 99         Rousettus bat coronavirus HKU9          NCBI:694006
# 100        Rousettus bat coronavirus HKU9          NCBI:694006
# 103                       Bat coronavirus         NCBI:1508220
# 105                       Bat coronavirus         NCBI:1508220
# 113                       Bat coronavirus         NCBI:1508220
# 116                       Bat coronavirus         NCBI:1508220
# 124                       Bat coronavirus         NCBI:1508220
# ..                                    ...                  ...
# 246                 Rousettus aegyptiacus          ITIS:632267
# 247                 Rousettus aegyptiacus          ITIS:632267
# 248                 Rousettus aegyptiacus          ITIS:632267
# 249                 Rousettus aegyptiacus          ITIS:632267
# 250                 Rousettus aegyptiacus          ITIS:632267
# 251                 Rousettus aegyptiacus          ITIS:632267
# 252                 Rousettus aegyptiacus          ITIS:632267
# 253                 Rousettus aegyptiacus          ITIS:632267
# 254                 Rousettus aegyptiacus          ITIS:632267
# 255                 Rousettus aegyptiacus          ITIS:632267
# 256                 Rousettus aegyptiacus          ITIS:632267
# 257                 Rousettus aegyptiacus          ITIS:632267
# 5    https://en.wiktionary.org/wiki/support
# 15   https://en.wiktionary.org/wiki/support
# 16   https://en.wiktionary.org/wiki/support
# 18   https://en.wiktionary.org/wiki/support
# 19   https://en.wiktionary.org/wiki/support
# 22   https://en.wiktionary.org/wiki/support
# 23   https://en.wiktionary.org/wiki/support
# 53   https://en.wiktionary.org/wiki/support
# 55   https://en.wiktionary.org/wiki/support
# 71   https://en.wiktionary.org/wiki/support
# 72   https://en.wiktionary.org/wiki/support
# 73   https://en.wiktionary.org/wiki/support
# 78   https://en.wiktionary.org/wiki/support
# 82   https://en.wiktionary.org/wiki/support
# 83   https://en.wiktionary.org/wiki/support
# 84   https://en.wiktionary.org/wiki/support
# 85   https://en.wiktionary.org/wiki/support
# 86   https://en.wiktionary.org/wiki/support
# 87   https://en.wiktionary.org/wiki/support
# 89   https://en.wiktionary.org/wiki/support
# 99   https://en.wiktionary.org/wiki/support
# 100  https://en.wiktionary.org/wiki/support
# 103  https://en.wiktionary.org/wiki/support
# 105  https://en.wiktionary.org/wiki/support
# 113  https://en.wiktionary.org/wiki/support
# 116  https://en.wiktionary.org/wiki/support
# 124  https://en.wiktionary.org/wiki/support
# ..                                      ...
# 246  https://en.wiktionary.org/wiki/support
# 247  https://en.wiktionary.org/wiki/support
# 248  https://en.wiktionary.org/wiki/support
# 249  https://en.wiktionary.org/wiki/support
# 250  https://en.wiktionary.org/wiki/support
# 251  https://en.wiktionary.org/wiki/support
# 252  https://en.wiktionary.org/wiki/support
# 253  https://en.wiktionary.org/wiki/support
# 254  https://en.wiktionary.org/wiki/support
# 255  https://en.wiktionary.org/wiki/support
# 256  https://en.wiktionary.org/wiki/support
# 257  https://en.wiktionary.org/wiki/support
# 258  https://en.wiktionary.org/wiki/support
# 259  https://en.wiktionary.org/wiki/support
# 260  https://en.wiktionary.org/wiki/support
# 261  https://en.wiktionary.org/wiki/support
# 262  https://en.wiktionary.org/wiki/support
# 263  https://en.wiktionary.org/wiki/support
# 264  https://en.wiktionary.org/wiki/support
# 265  https://en.wiktionary.org/wiki/support
# 266  https://en.wiktionary.org/wiki/support
# 267  https://en.wiktionary.org/wiki/support
# 268  https://en.wiktionary.org/wiki/support
# 269  https://en.wiktionary.org/wiki/support
# 270  https://en.wiktionary.org/wiki/support
# 271  https://en.wiktionary.org/wiki/support
# 272  https://en.wiktionary.org/wiki/support
# 273  https://en.wiktionary.org/wiki/support
# 274  https://en.wiktionary.org/wiki/support
# 275  https://en.wiktionary.org/wiki/support
#
#                                      referenceCitation  \
# 0    Sasaki M, Kajihara M, Changula K, Mori-Kajihar...
# 1    Carr M, Gonzalez G, Sasaki M, Ito K, Ishii A, ...
# 2    Towner JS, Amman BR, Sealy TK, Carroll SA, Com...
# 5    Towner JS, Amman BR, Sealy TK, Carroll SA, Com...
# 15   Kajihara M, Hang'ombe BM, Changula K, Harima H...
# 16   Kajihara M, Hang'ombe BM, Changula K, Harima H...
# 18   Kuzmin IV, Niezgoda M, Franka R, Agwanda B, Ma...
# 19   Towner JS, Pourrut X, Albariño CG, Nkogue CN, ...
# 22   Maganga GD, Bourgarel M, Ella GE, Drexler JF, ...
# 23   Amman BR, Nyakarahuka L, McElroy AK, Dodd KA, ...
# 53   Amman BR, Carroll SA, Reed ZD, Sealy TK, Balin...
# 55   Amman BR, Carroll SA, Reed ZD, Sealy TK, Balin...
# 71   Amman BR, Bird BH, Bakarr IA, Bangura J, Schuh...
# 72   Amman BR, Bird BH, Bakarr IA, Bangura J, Schuh...
# 73   Amman BR, Bird BH, Bakarr IA, Bangura J, Schuh...
# 78   Amman BR, Bird BH, Bakarr IA, Bangura J, Schuh...
# 82   Markotter W, Randles J, Rupprecht CE, Sabeta C...
# 83   Kuzmin IV, Mayer AE, Niezgoda M, Markotter W, ...
# 84   Kuzmin IV, Niezgoda M, Franka R, Agwanda B, Ma...
# 85   Walker PJ, Widen SG, Firth C, Blasdell KR, Woo...
# 86   Picard-Meyer E, Barrat J, Tissot E, Barrat MJ,...
# 87   Waruhiu C, Ommeh S, Obanda V, Agwanda B, Gakuy...
# 89   Waruhiu C, Ommeh S, Obanda V, Agwanda B, Gakuy...
# 99   Anthony SJ, Johnson CK, Greig DJ, Kramer S, Ch...
# 100  Anthony SJ, Johnson CK, Greig DJ, Kramer S, Ch...
# 103  Lacroix A, Duong V, Hul V, San S, Davun H, Oma...
# 105  Lacroix A, Duong V, Hul V, San S, Davun H, Oma...
# 113  Lacroix A, Duong V, Hul V, San S, Davun H, Oma...
# 116  Lacroix A, Duong V, Hul V, San S, Davun H, Oma...
# 124  Lacroix A, Duong V, Hul V, San S, Davun H, Oma...
# ..                                                 ...
# 246  Korine, C., Izhaki, I., & Arad, Z. (1999). Is ...
# 247  Korine, C., Izhaki, I., & Arad, Z. (1999). Is ...
# 248  Korine, C., Izhaki, I., & Arad, Z. (1999). Is ...
# 249  Korine, C., Izhaki, I., & Arad, Z. (1999). Is ...
# 250  Korine, C., Izhaki, I., & Arad, Z. (1999). Is ...
# 251  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 252  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 253  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 254  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 255  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 256  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 257  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 258  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 259  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 260  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 261  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 262  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 263  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 264  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 265  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 266  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 267  del Vaglio, M. A., Nicolau, H., Bosso, L., Rus...
# 268  Albayrak, I., Aşan, N., & Yorulmaz, T. (2008)....
# 269  Albayrak, I., Aşan, N., & Yorulmaz, T. (2008)....
# 270  Albayrak, I., Aşan, N., & Yorulmaz, T. (2008)....
# 271  Albayrak, I., Aşan, N., & Yorulmaz, T. (2008)....
# 272  Albayrak, I., Aşan, N., & Yorulmaz, T. (2008)....
# 273  Albayrak, I., Aşan, N., & Yorulmaz, T. (2008)....
# 274  Albayrak, I., Aşan, N., & Yorulmaz, T. (2008)....
# 275  Albayrak, I., Aşan, N., & Yorulmaz, T. (2008)....
#
#                       referenceDoi referenceUrl  \
# 0
# 1
# 2
# 5
# 15
# 16
# 18
# 19
# 22
# 23
# 53
# 55
# 71
# 72
# 73
# 78
# 82
# 83
# 84
# 85
# 86
# 87
# 89
# 99
# 100
# 103
# 105
# 113
# 116
# 124
# ..                             ...          ...
# 246  10.1016/S0006-3207(98)00126-8
# 247  10.1016/S0006-3207(98)00126-8
# 248  10.1016/S0006-3207(98)00126-8
# 249  10.1016/S0006-3207(98)00126-8
# 250  10.1016/S0006-3207(98)00126-8
# 251      10.4404/Hystrix-22.2-4587
# 252      10.4404/Hystrix-22.2-4587
# 253      10.4404/Hystrix-22.2-4587
# 254      10.4404/Hystrix-22.2-4587
# 255      10.4404/Hystrix-22.2-4587
# 256      10.4404/Hystrix-22.2-4587
# 257      10.4404/Hystrix-22.2-4587
# 258      10.4404/Hystrix-22.2-4587
# 259      10.4404/Hystrix-22.2-4587
# 260      10.4404/Hystrix-22.2-4587
# 261      10.4404/Hystrix-22.2-4587
# 262      10.4404/Hystrix-22.2-4587
# 263      10.4404/Hystrix-22.2-4587
# 264      10.4404/Hystrix-22.2-4587
# 265      10.4404/Hystrix-22.2-4587
# 266      10.4404/Hystrix-22.2-4587
# 267      10.4404/Hystrix-22.2-4587
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
#
#                                         sourceCitation  \
# 0    Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 1    Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 2    Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 5    Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 15   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 16   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 18   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 19   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 22   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 23   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 53   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 55   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 71   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 72   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 73   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 78   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 82   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 83   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 84   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 85   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 86   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 87   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 89   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 99   Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 100  Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 103  Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 105  Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 113  Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 116  Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# 124  Chen L, Liu B, Yang J, Jin Q, 2014. DBatVir: t...
# ..                                                 ...
# 246  Quentin J. Groom. 2020. Bat interation data ma...
# 247  Quentin J. Groom. 2020. Bat interation data ma...
# 248  Quentin J. Groom. 2020. Bat interation data ma...
# 249  Quentin J. Groom. 2020. Bat interation data ma...
# 250  Quentin J. Groom. 2020. Bat interation data ma...
# 251  Quentin J. Groom. 2020. Bat interation data ma...
# 252  Quentin J. Groom. 2020. Bat interation data ma...
# 253  Quentin J. Groom. 2020. Bat interation data ma...
# 254  Quentin J. Groom. 2020. Bat interation data ma...
# 255  Quentin J. Groom. 2020. Bat interation data ma...
# 256  Quentin J. Groom. 2020. Bat interation data ma...
# 257  Quentin J. Groom. 2020. Bat interation data ma...
# 258  Quentin J. Groom. 2020. Bat interation data ma...
# 259  Quentin J. Groom. 2020. Bat interation data ma...
# 260  Quentin J. Groom. 2020. Bat interation data ma...
# 261  Quentin J. Groom. 2020. Bat interation data ma...
# 262  Quentin J. Groom. 2020. Bat interation data ma...
# 263  Quentin J. Groom. 2020. Bat interation data ma...
# 264  Quentin J. Groom. 2020. Bat interation data ma...
# 265  Quentin J. Groom. 2020. Bat interation data ma...
# 266  Quentin J. Groom. 2020. Bat interation data ma...
# 267  Quentin J. Groom. 2020. Bat interation data ma...
# 268  Quentin J. Groom. 2020. Bat interation data ma...
# 269  Quentin J. Groom. 2020. Bat interation data ma...
# 270  Quentin J. Groom. 2020. Bat interation data ma...
# 271  Quentin J. Groom. 2020. Bat interation data ma...
# 272  Quentin J. Groom. 2020. Bat interation data ma...
# 273  Quentin J. Groom. 2020. Bat interation data ma...
# 274  Quentin J. Groom. 2020. Bat interation data ma...
# 275  Quentin J. Groom. 2020. Bat interation data ma...
#
#                       sourceNamespace  \
# 0    globalbioticinteractions/dbatvir
# 1    globalbioticinteractions/dbatvir
# 2    globalbioticinteractions/dbatvir
# 5    globalbioticinteractions/dbatvir
# 15   globalbioticinteractions/dbatvir
# 16   globalbioticinteractions/dbatvir
# 18   globalbioticinteractions/dbatvir
# 19   globalbioticinteractions/dbatvir
# 22   globalbioticinteractions/dbatvir
# 23   globalbioticinteractions/dbatvir
# 53   globalbioticinteractions/dbatvir
# 55   globalbioticinteractions/dbatvir
# 71   globalbioticinteractions/dbatvir
# 72   globalbioticinteractions/dbatvir
# 73   globalbioticinteractions/dbatvir
10.5281/zenodo.3816676  2020-05-08T22:13:44.214Z\n
# 273  10.5281/zenodo.3816676  2020-05-08T22:13:44.214Z\n
# 274  10.5281/zenodo.3816676  2020-05-08T22:13:44.214Z\n
# 275  10.5281/zenodo.3816676  2020-05-08T22:13:44.214Z\n
#
# [164 rows x 84 columns]

# %%
primaryInteractingTaxa = interactingTaxaData['sourceTaxonName'].drop_duplicates()
len(primaryInteractingTaxa)
# Out:
# 19

# %%
primaryInteractingTaxa = (primaryInteractingTaxa.append(interactingTaxaData['targetTaxonName']).drop_duplicates())
len(primaryInteractingTaxa)
# Out:
# 58

# %%
primaryInteractingTaxa
# Out:
# 0                               Rotavirus A
# 1      Rousettus aegyptiacus polyomavirus 1
# 2                      Marburg marburgvirus
# 82                     Lagos bat lyssavirus
# 85                              Yogue virus
# 87                            Bat rotavirus
# 89                          Bat coronavirus
# 99           Rousettus bat coronavirus HKU9
# 134                      Bat mastadenovirus
# 148                            Homo sapiens
# 198                              Flavivirus
# 199                         Lagos bat virus
# 201                          Shamonda virus
# 202                        Zaire ebolavirus
# 204                 European bat lyssavirus
# 205                       Chikungunya virus
# 212                             Felis catus
# 213                   Eucampsipoda africana
# 214                   Rousettus aegyptiacus
# 214                      Ekebergia capensis
# 215                    Elaeodendron croceum
# 216               Acokanthera oppositifolia
# 217                Miniopterus schreibersii
# 218                    Rhinolophus capensis
# 219                 Miniopterus fraterculus
# 220                    Rhinolophus clivosus
# 221                            Bombax ceiba
# 222                         Ziziphus jujuba
# 223                      Terminalia catappa
# 224                      Prosopis juliflora
# 225                     Phoenix dactylifera
# 226                         Melia azedarach
# 227                      Ficus benghalensis
# 228                        Pachnoda sinuata
# 229                               Ficus sur
# 232                         Myrtus communis
# 234                            Ficus carica
# 235                       Citrus reticulata
# 236                            Citrus limon
# 237                         Agave americana
# 239                             Morus nigra
# 240                       Arbutus andrachne
# 241                       Ceratonia siliqua
# 242                          Diospyros kaki
# 243                     Eriobotrya japonica
# 244                        Eugenia uniflora
# 246                        Ficus microcarpa
# 247                         Ficus religiosa
# 248                        Ficus rubiginosa
# 249                         Ficus sycomorus
# 251                   Washingtonia filifera
# 253                      Styrax officinalis
# 260                         Citrus sinensis
# 261                      Crataegus azarolus
# 268                          Vitis vinifera
# 269                         Punica granatum
# 273                          Ficus elastica
# 275                          Prunus persica
# dtype: object

# %% [markdown]
# ## A function to query the globi database

# %%
def secondaryDataInGlobi(conn, intaxon):
    cur = conn.cursor()
    cur.execute("SELECT * from globi where (targetTaxonName = ? OR sourceTaxonName = ?) and interactionTypeName NOT IN (?) and targetTaxonRank ='species' and sourceTaxonRank = 'species';", \
                (intaxon,intaxon,interactionsToExclude,))
    return(cur.fetchall())

# %% [markdown]
# ## Get all the secondary interactions

# %%
try:
    conn = sqlite3.connect(globiDB)
except Error as e:
    print(e)

# %%
secondarylist = []

for name in primaryInteractingTaxa:
    temp = secondaryDataInGlobi(conn, name)
    secondarylist.extend(temp)

# %%
# Convert to a Pandas dataframe
secondarylist = pd.DataFrame(secondarylist)

# %%
secondarylist.columns = ['sourceTaxonId', \
                                'sourceTaxonIds','sourceTaxonName','sourceTaxonRank','sourceTaxonPathNames', \
                                'sourceTaxonPathIds','sourceTaxonPathRankNames','sourceTaxonSpeciesName','sourceTaxonSpeciesId',\
                                'sourceTaxonGenusName','sourceTaxonGenusId','sourceTaxonFamilyName','sourceTaxonFamilyId',\
                                'sourceTaxonOrderName','sourceTaxonOrderId','sourceTaxonClassName','sourceTaxonClassId',\
                                'sourceTaxonPhylumName','sourceTaxonPhylumId','sourceTaxonKingdomName','sourceTaxonKingdomId',\
                                'sourceId','sourceOccurrenceId','sourceCatalogNumber','sourceBasisOfRecordId',\
                                'sourceBasisOfRecordName','sourceLifeStageId','sourceLifeStageName','sourceBodyPartId',\
                                'sourceBodyPartName','sourcePhysiologicalStateId','sourcePhysiologicalStateName',\
                                'sourceSexId', 'sourceSexName', 'interactionTypeName',\
                                'interactionTypeId','targetTaxonId','targetTaxonIds','targetTaxonName',\
                                'targetTaxonRank','targetTaxonPathNames','targetTaxonPathIds','targetTaxonPathRankNames',\
                                'targetTaxonSpeciesName','targetTaxonSpeciesId','targetTaxonGenusName','targetTaxonGenusId',\
                                'targetTaxonFamilyName','targetTaxonFamilyId','targetTaxonOrderName','targetTaxonOrderId',\
                                'targetTaxonClassName','targetTaxonClassId','targetTaxonPhylumName','targetTaxonPhylumId',\
                                'targetTaxonKingdomName','targetTaxonKingdomId','targetId','targetOccurrenceId',\
                                'targetCatalogNumber','targetBasisOfRecordId','targetBasisOfRecordName','targetLifeStageId',\
                                'targetLifeStageName','targetBodyPartId','targetBodyPartName','targetPhysiologicalStateId',\
                                'targetPhysiologicalStateName', 'targetSexId', 'targetSexName', \
                                'decimalLatitude','decimalLongitude','localityId',\
                                'localityName','eventDateUnixEpoch','argumentTypeId','referenceCitation',\
                                'referenceDoi','referenceUrl','sourceCitation','sourceNamespace',\
                                'sourceArchiveURI','sourceDOI','sourceLastSeenAtUnixEpoch']

# %%
allInteractionsData = interactingTaxaData.append(secondarylist)

# %%
allInteractionsData = allInteractionsData.drop_duplicates()

# %%
    cleanInteractDataTaxon = allInteractionsData[['sourceTaxonId', 'sourceTaxonName', 'sourceTaxonRank',
       'sourceTaxonFamilyName', 'interactionTypeName',
       'targetTaxonName','targetTaxonRank', 'sourceCitation', 'sourceDOI'
        ]].dropna(subset=['targetTaxonName','sourceTaxonName'])

# %%
allSourceInteractingTaxa = cleanInteractDataTaxon['sourceTaxonName'].drop_duplicates()
allTargetInteractingTaxa = cleanInteractDataTaxon['targetTaxonName'].drop_duplicates()

# %%
allInteractingTaxa = allSourceInteractingTaxa.append(allTargetInteractingTaxa).drop_duplicates()
allInteractingTaxa.count()

# %%
allInteractingTaxa.head()

# %%
# How many different sort of interaction do I have left?
# Checking out all the interaction types
cleanInteractDataTaxon.groupby(cleanInteractDataTaxon['interactionTypeName']).size().sort_values(ascending = False)

# %% [markdown]
# ### This function takes a name string and checks on GBIF to see if the name exists there.

# %%
def speciesExistsInGBIF(name, rank):
    try:
        match = species.name_backbone(name=name, rank=rank, limit = 1)

        # if there is no match this is returned from .name_backbone {'confidence': 100, 'matchType': 'NONE', 'synonym': False}
        if match['matchType'] == 'NONE':
            return False
        else:
            return match
    except ValueError as ve:
        print(ve)
        exit(1)

# %% [markdown]
# ### Check that the species in question is actually found on GBIF

# %%
if(speciesExistsInGBIF(taxon, "species") == False):
    print("##### {0} has not been found on GBIF #####".format(taxon))

# %% [markdown]
# ### Check to see which taxa in the interaction network are found in GBIF and list those ones that are not

# %%
taxaFound = {}

print('Taxa from GLoBI, but not found in GBIF')
for name in allInteractingTaxa.items():
    GBIFName = speciesExistsInGBIF(name[1], "species")
    if GBIFName == False:
        taxaFound[name[1]] = False
        print(name[1])
    else:
        taxaFound[name[1]] = GBIFName['usageKey']

# %%
# Convert to a Pandas dataframe
taxaFound = pd.DataFrame.from_dict(taxaFound, orient='index')

# %%
len(taxaFound)

# %%
taxaFound

# %% [markdown]
# ## Drawing a network of the interactions
#
# Now that I have a list of all the species in the country I can use this as my nodes list for the network diagram.

# %%
#networkx seems to be a leading network tool in Python
import networkx as nx
import matplotlib.pyplot as plt

try:
    import pygraphviz
    from networkx.drawing.nx_agraph import write_dot
    print("using package pygraphviz")
except ImportError:
    try:
        import pydot
        from networkx.drawing.nx_pydot import write_dot
        print("using package pydot")
    except ImportError:
        print()
        print("Both pygraphviz and pydot were not found ")
        print("see  https://networkx.github.io/documentation/latest/reference/drawing.html")
        print()

# %%
# Create graphic object
G = nx.DiGraph()

# %%
# Match colours to interactions to distinguish them on the graph
colorInteractions = {'interaction':['pollinates', 'mutualistOf', 'eats', 'visitsFlowersOf', 'hasHost', 'parasiteOf', 'pathogenOf'],
        'colour':['r', 'g', 'b', 'y', 'm', 'w', 'c']}  

colorInteractionsDf = pd.DataFrame(colorInteractions)

#len(list(G.nodes))

# %% [markdown]
# ## A quick look at the interaction data to see if it is what is expected

# %%
#cleanInteractDataTaxon.loc[(cleanInteractDataTaxon["sourceTaxonName"] == 'Apis mellifera') & (cleanInteractDataTaxon["targetTaxonName"] == 'Procyon lotor')]
cleanInteractDataTaxon.loc[(cleanInteractDataTaxon["targetTaxonName"] == 'Pipistrellus pipistrellus')]

# %% [markdown]
# ### Add the nodes to the graph

# %%
for index, row in taxaFound.iterrows():
    # access data using column names
    #print('A: ', row.name, row[0])
    G.add_node(row.name, gbifkey=row[0])
    #create a list of node sizes scaled for the network visulization

# %% [markdown]
# ### Add edges to the graph

# %%
# iterate over the interacting species that are in GBIF and in the country with iterrows()
# Find the taxa found in the country that are in the source taxon name of the interation data,
# then add the edge if the target species is in the country too.

taxaFound_copy = taxaFound.copy()

for index, row in taxaFound.iterrows():
    # loop over all the taxa finding if any of them are mentioned in the sourceTaxonName field
    for edge in cleanInteractDataTaxon.iterrows():
        if row.name == edge[1]['sourceTaxonName']:
            #print('B: ', edge[1]['sourceTaxonName'], edge[1]['targetTaxonName'])
            # Some of the target species will not be in GBIF of in the country, so only add an edge where they are.
            for index2, row2 in taxaFound_copy.iterrows():
                #print('E: ', row2.name, edge[1]['targetTaxonName'])
                if row2.name == edge[1]['targetTaxonName']:
                    print('C: ', edge[1]['targetTaxonName'], row.name, edge[1]['interactionTypeName'])
                    G.add_edge(edge[1]['targetTaxonName'], row.name, label = edge[1]['interactionTypeName'])
                    
#len(list(G.nodes))

# %%
# iterate over rows with iterrows()

# Find the taxa found in the country that are in the target taxon name of the interation data,
# then add the edge if the source species is in the country too.

for index, row in taxaFound.iterrows():
    for edge in cleanInteractDataTaxon.iterrows():
        if row.name == edge[1]['targetTaxonName']:
            #print('D: ', edge[1]['sourceTaxonName'], edge[1]['targetTaxonName'])
            #G.add_node(edge[1]['sourceTaxonName'], gbifkey=row['key'])
            #dictOfNodeSizes[edge[1]['sourceTaxonName']] = int(row['count']/maxRecords*100)
            for index2, row2 in taxaFound.iterrows():
                #print('E: ', row2['species'])
                if row2.name == edge[1]['sourceTaxonName']: 
                    print('F: ', edge[1]['sourceTaxonName'],edge[1]['targetTaxonName'])
                    G.add_edge(row2.name, edge[1]['sourceTaxonName'], label = edge[1]['interactionTypeName'])

# %%
print("Number of nodes = {0}".format(G.number_of_nodes()))
print("Number of edges = {0}".format(G.number_of_edges()))

# %% [markdown]
# ## Remove any nodes that have no edges.
# This happens because some of the linking nodes have few supporting observations and so have been weeded out

# %%
#for n in G.nodes:
#    if G.degree(n) == 0:
#        G.remove_node(n)
        
G.remove_nodes_from(list(nx.isolates(G)))

# %%
len(G.nodes)

# %% [markdown]
# ## Remove any selfloop edges

# %%
for e in G.selfloop_edges(data=False):
    G.remove_edge(e[0],e[1])

# %% [markdown]
# ## A network of all the interacting taxa

# %%
plt.figure(figsize=(15,15))
edge_labels = nx.get_edge_attributes(G,'label')

pos = nx.spring_layout(G, iterations=50, k=50) 
#pos = nx.spring_layout(G)
#pos = nx.random_layout(G)
#pos = nx.circular_layout(G)
#pos = nx.spectral_layout(G)
#pos = nx.shell_layout(G, scale=1)

nodeColors = nx.get_node_attributes(G,'color')

nx.draw_networkx_edge_labels(G,pos, edge_labels = edge_labels, font_size=10, font_color='blue')

#nx.draw_networkx_nodes(G, pos, node_color=nodeColors.values())

nx.draw_networkx(G, pos, with_labels=True, node_size = 12, node_color='b', alpha= 1, arrows=True, 
                    linewidths=1, font_color="black", font_size=10, style = 'dashed')

plt.axis('off')
plt.tight_layout()
plt.show()

# %%
with open(taxon+country+".html", "w") as file:
    file.write(" \
<!DOCTYPE html> \
<html> \
<head> \
<script src='../../../GitHub\cytoscape.js\dist\cytoscape.min.js'></script> \
<script src='https://unpkg.com/layout-base/layout-base.js'></script> \
<script src='https://unpkg.com/cose-base/cose-base.js'></script> \
<script src='../../../GitHub\cytoscape.js-cose-bilkent\cytoscape-cose-bilkent.js'></script> \
</head> \
<style>#cy {width: 90%; height: 90%; position: absolute; top: 50px; left: 150px;}\
body {font-family: 'times; font-size: 6px;}\
</style> \
<body> \
<h1><em font-style: italic;>"+taxon+"</em></h1>")

# %% [markdown]
# ### Write out the details of the species

# %%
with open(taxon+country+".html", "a") as file:
    file.write("<table align='left' style='margin-left: 0px'><tbody><tr><td width='20%'>")
    file.write("<table><th>Species</th>")

# %%
species = G.nodes
with open(taxon+country+".html", "a") as file:
    for n in species:
        file.write("<tr><td><a target='_blank' href=https://www.gbif.org/species/"+str(nx.get_node_attributes(G, 'gbifkey')[n])+">"+n+"</a></td>\n")
        #file.write("<a href=https://www.gbif.org/species/"+str(nx.get_node_attributes(G, 'gbifkey')[n])+">"+n+"</a>, "+str(dictOfNodeSizes[n])+"\n")

# %%
with open(taxon+country+".html", "a") as file:
    file.write("</table>")
    file.write("</td><td='80%'>")
file.close()

# %%
with open(taxon+country+".html", "a") as file:
    file.write(" \
<div id='cy'></div> \
<script> \
var cy = cytoscape({ \
  container: document.getElementById('cy'), \n \
  elements: [ \
")

# %% [markdown]
# ### Write nodes to file

# %%
file = open(taxon+country+".html", "a")
for n in species:
    file.write("{ data: { id: '"+n+"', href: 'https://www.gbif.org/species/"+str(nx.get_node_attributes(G, 'gbifkey')[n])+"', occnum: 2 }, },\n")
file.close()

# %% [markdown]
# ### Write edges to file

# %%
file = open(taxon+country+".html", "a")
for edge in G.edges:
    file.write("{data: {id: '"+edge[0]+edge[1]+"', source: '"+edge[0]+"', target: '"+edge[1]+"', label: '"+nx.get_edge_attributes(G, 'label')[edge]+"'}},\n")
file.close()

# %%
with open(taxon+country+".html", "a") as file:
    file.write("], \
style: [ \n\
        { \n\
            selector: 'node', \n\
            style: { \n\
                shape: 'circle', \n\
                'background-color': 'darkgreen', \n\
                label: 'data(id)', \n\
                'font-family': 'helvetica', \n\
                'font-style': 'italic', \n\
                'font-size': '8px', \n\
                'width': 'mapData(occnum, 0, 400, 3, 150)', \n\
                'height': 'mapData(occnum, 0, 400, 3, 150)' \n\
            } \n\
        },  \n\
        {  \n\
            selector: 'edge',  \n\
            style: {  \n\
                label: 'data(label)', \n\
                'font-family': 'helvetica', \n\
                'font-size': '8px', \n\
                'color': 'blue', \n\
                'curve-style': 'bezier', \n\
                'target-arrow-shape': 'triangle',  \n\
                'width': '1' \n\
                } \n\
            },  \n\
            {  \n\
              selector: ':selected',   \n\
              css: {  \n\
                'line-color': 'red',  \n\
                'background-color': 'red'  \n\
            }  \n\
        }], \n\
layout:  { \n\
            name: 'circle', padding: 10, animate: true, gravity: 30, animationDuration: 1000 \n\
     } \n\
} \n\
); \n\
cy.userZoomingEnabled( true ); \n\
</script> \n\
")

# %%
with open(taxon+country+".html", "a") as file:
    file.write("</td></tr></tbody></table>\n")
    file.write("<h2>References</h2><ul>\n")

# %%
citations = cleanInteractDataTaxon['sourceCitation'].unique()
file = open(taxon+country+".html", "a")
for ref in citations:
    file.write("<li>"+str(ref)+"</li>\n")
file.close()

# %%
with open(taxon+country+".html", "a") as file:
    file.write("</ul> \
        </body> \
        </html>")

# %% [markdown]
# ## Output a CSV file for import into Gephi

# %%
for node in G.edges:
    print(node[1])

# %%
with open(taxon+"_nodes.csv", "w") as file:
    file.write("Id,Label,Category")
    for node in G.nodes:
        file.write("'"+edge[0]+edge[1]+"','"+edge[0]+"','"+edge[1]+"','"+nx.get_edge_attributes(G, 'label')[edge]+"'\n")
file.close()

# %%
with open(taxon+"edges.csv", "w") as file:
    file.write("Id,Label,Category")
    for node in G.nodes:
        file.write("'"+edge[0]+edge[1]+"','"+edge[0]+"','"+edge[1]+"','"+nx.get_edge_attributes(G, 'label')[edge]+"'\n")
file.close()

# %%
#with open(taxon+".csv", "w") as file:
write_dot(G, taxon+".dot")
